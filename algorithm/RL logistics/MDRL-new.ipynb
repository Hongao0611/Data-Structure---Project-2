# %%
from data_gen import *
import heapq

#generate stations, centers, packages.
data = data_gen()
station_pos = data['station_pos']
station_prop = data['station_prop']
center_pos = data['center_pos']
center_prop = data['center_prop']
edges = data['edges']
packets = data['packets']
moneycost=data["money cost"]
timecost=data["time cost"]
class Node:
    def __init__(self, id, pos, throughput, delay, cost, is_station=False):
        self.id = id
        self.pos = pos
        self.throughput = throughput
        self.delay = delay  # This delay should be updated based on the queue length and throughput
        self.cost = cost
        self.is_station = is_station
        self.packages = []  # Use a list for packages
        heapq.heapify(self.packages)  # Convert the list to a heap
        self.package_indices = {}  # 辅助字典用于快速查找包裹的索引

    def add_package(self, package):
        heapq.heappush(self.packages, (-package.delay, package))
        package.delay = self.delay
        self.package_indices[package.id] = len(self.packages) - 1  # 更新辅助字典
        print(f"Pack added to Node: {self.id};")

    def remove_package(self, package_id):
        if package_id in self.package_indices:
            index = self.package_indices.pop(package_id)
            # 直接移除指定索引的元素，并重新构建堆
            del self.packages[index]
            heapq.heapify(self.packages)
            self.package_indices = {pkg.id: i for i, (_, pkg) in enumerate(self.packages)}
            print(f"package: {package_id} removed from Node: {self.id}.")

    def __str__(self):
        # 获取所有包裹的 ID
        package_ids = [pkg.id for _, pkg in self.packages]
        # 将包裹 ID 转换为字符串并附加到节点信息中
        return f"Node({self.id}, {self.pos}, Throughput: {self.throughput}, Delay: {self.delay}, Cost: {self.cost}, Packages: {package_ids})"

class Route:
    def __init__(self, src, dst, time, cost):
        self.src = src
        self.dst = dst
        self.time = time
        self.cost = cost
        self.packages = []  # Use a list for packages on the route
        heapq.heapify(self.packages)  # Convert the list to a heap
        self.package_indices = {}  # 辅助字典用于快速查找包裹的索引

    def add_package(self, package):
        package.delay = self.time
        heapq.heappush(self.packages, (-package.delay, package))
        self.package_indices[package.id] = len(self.packages) - 1  # 更新辅助字典
        print(f"Pack added to Route: {self.src}->{self.dst};")

    def remove_package(self, package_id):
        if package_id in self.package_indices:
            index = self.package_indices.pop(package_id)
            # 直接移除指定索引的元素，并重新构建堆
            del self.packages[index]
            heapq.heapify(self.packages)
            self.package_indices = {pkg.id: i for i, (_, pkg) in enumerate(self.packages)}
            print(f"package: {package_id} removed from Route: {self.src}->{self.dst}.")

    def __str__(self):
        return f"Route({self.src}->{self.dst}, Time: {self.time}, Cost: {self.cost})"

class Package:
    def __init__(self, id, time_created, src, dst, category):
        self.id = id
        self.time_created = time_created
        self.src = src
        self.dst = dst
        self.curr = src
        self.category = category  # 'Express' or 'Standard'
        self.history = []  # List of nodes visited with timestamps
        self.path = []  # List of nodes on the expected path
        self.delay = 0  # Remaining delay before processing
        self.done = False
        self.reward = 0.0  # Current Reward/cost for this package

    def update_path(self, next_node):
        self.path.append(next_node)

    def mark_done(self):
        self.done = True

    def __lt__(self, other):
        # Ensure other is also a Package object
        if not isinstance(other, Package):
            return False

        # Define comparison for priority queue
        # Express packages have higher priority 
        if self.category == 'Express' and other.category != 'Express':
            return True
        if self.category != 'Express' and other.category == 'Express':
            return False
        # Otherwise, compare based on time created
        return self.time_created < other.time_created

    def __eq__(self, other):
        # Ensure other is also a Package object
        if not isinstance(other, Package):
            return False

        # Define comparison for priority queue
        # Express packages have higher priority
        if self.category == 'Express' and other.category != 'Express':
            return True
        if self.category != 'Express' and other.category == 'Express':
            return False
        # Otherwise, compare based on time created
        return self.time_created == other.time_created

    def __str__(self):
        return f"Package({self.id}, TimeCreated: {self.time_created}, Src: {self.src}, Dst: {self.dst}, Category: {self.category})"

class LogisticsEnv:
    def __init__(self):
        self.nodes = {}  # Dictionary of nodes
        self.routes = {}  # Dictionary of routes
        self.packages = {}  # Dictionary of packages
        self.min_delay = float('inf')  # Minimum delay for all packages
        self.TimeTick = 0.0  # Current time tick
        self.done = False
        self.moneycost=moneycost
        self.timecost=timecost


    def reset(self):
        self.nodes = {}  # Dictionary of nodes
        self.routes = {}  # Dictionary of routes
        self.packages = {}  # Dictionary of packages

        # Initialize nodes, routes, and packages
        # Add stations as nodes
        for i in range(len(station_pos)):
            p = self.add_node(f"s{i}", station_pos[i], *station_prop[i], is_station=True)
            #print(f"Center({p.id}, {p.pos}, Throughput: {p.throughput}, Delay: {p.delay}, Cost: {p.cost}), is_station: {p.is_station}")

        # Add centers as nodes
        for i in range(len(center_pos)):
            p = self.add_node(f"c{i}", center_pos[i], *center_prop[i])
            #print(f"Center({p.id}, {p.pos}, Throughput: {p.throughput}, Delay: {p.delay}, Cost: {p.cost}), is_station: {p.is_station}")

        # Add edges as routes
        for edge in edges:
            p = self.add_route(edge[0], edge[1], edge[2], edge[3])
            #print(f"Route({p.src}->{p.dst}, Time: {p.time}, Cost: {p.cost})")

        # Add packets as packages
        for packet in packets:
            p = self.add_package(uuid.uuid4(), *packet)
            print(f"Package {p.id} added, delay={p.delay}, src={p.src}, curr={p.curr}, dst={p.dst}, done={p.done}, path={p.path}")
        
        for package in self.packages.values():
            self.min_delay = package.delay if self.min_delay>package.delay and package.delay>0 else self.min_delay
        for node in self.nodes.values():
            print(node)
        self.TimeTick = 0.0  # Current time tick
        print(f"Env reset. min_delay={self.min_delay}, TimeTick={self.TimeTick}")
        self.moneycost=moneycost
        self.timecost=timecost

        return self.get_state()

    def add_node(self, id, pos, throughput, delay, cost, is_station=False):
        self.nodes[id] = Node(id, pos, throughput, delay, cost, is_station)
        return self.nodes[id]

    def add_route(self, src, dst, time, cost):
        self.routes[(src, dst)] = Route(src, dst, time, cost)
        return self.routes[(src, dst)]

    def add_package(self, id, time_created, src, dst, category):
        package = Package(id, time_created, src, dst, category)
        
        # Calculate the initial optimal路径 based on the package's category
        if category == 'Express':
            # 对于Express包裹，找到最短的总时间路径
            optimal_path = self.find_shortest_time_path(src, dst)
        else:
            # 对于Standard包裹，找到最低的总成本路径
            optimal_path = self.find_lowest_cost_path(src, dst)
        
        package.path = optimal_path  # 将最优路径初始化为包裹的路径
        self.packages[id] = package
        self.nodes[src].add_package(package)  # 添加到优先队列中
        return package
   
    def find_shortest_time_path(self, src, dst):
        if src[0]=='s':
            if len(src)==2:
                a=int(src[1])*2+10
            else:
                a=int(src[1:])*2+10
        else:
            a=int(src[1])*2
        if dst[0]=='s':
            if len(dst)==2:
                b=int(dst[1])*2+10
            else:
                b=int(dst[1:])*2+10
        else:
            b=int(dst[1])*2

        n=len(self.timecost)#ordre du graphe
        Delta=[np. Infinity]*n#étape 1
        Chemins=[[]]*n# liste des listes des plus courts chemins
        Delta[a]=0  #étape 1
        Chemins[a]=[a] #plus court chemin de s0 à s0
        for k in range(n-1): #étape 2
            for i in range(n): #étape 3
                for j in range(n): #étape 3
                    if self.timecost[ i ][ j]!=0 and Delta[ i]+self.timecost[ i ][ j]<Delta[ j ]: #ét. 4
                        Delta[ j]=Delta[ i]+self.timecost[ i ][ j ] #étape 4
                        Chemins[ j]=Chemins[ i ]+[j ] #chemin plus court
        d=Chemins
        path=[]
        for i in range(int((len(d[b])+1)/2)):
            if d[b][2*i]>9:
                path.append('s'+str((d[b][2*i]-10)/2))
            else :
                path.append('c'+str(d[b][2*i]/2)) 
        return path 
    
        
    
    def find_lowest_cost_path(self,src, dst):
        if src[0]=='s':
            if len(src)==2:
                a=int(src[1])*2+10
            else:
                a=int(src[1:])*2+10
        else:
            a=int(src[1])*2
        if dst[0]=='s':
            if len(dst)==2:
                b=int(dst[1])*2+10
            else:
                b=int(dst[1:])*2+10
        else:
            b=int(dst[1])*2

        n=len(self.moneycost)#ordre du graphe
        Delta=[np. Infinity]*n#étape 1
        Chemins=[[]]*n# liste des listes des plus courts chemins
        Delta[a]=0  #étape 1
        Chemins[a]=[a] #plus court chemin de s0 à s0
        for k in range(n-1): #étape 2
            for i in range(n): #étape 3
                for j in range(n): #étape 3
                    if self.moneycost[ i ][ j]!=0 and Delta[ i]+self.moneycost[ i ][ j]<Delta[ j ]: #ét. 4
                        Delta[ j]=Delta[ i]+self.moneycost[ i ][ j ] #étape 4
                        Chemins[ j]=Chemins[ i ]+[j ] #chemin plus court
        d=Chemins
        path=[]
        for i in range(int((len(d[b])+1)/2)):
            if d[b][2*i]>9:
                path.append('s'+str(int((d[b][2*i]-10)/2)))
            else :
                path.append('c'+str(int(d[b][2*i]/2))) 
        return path 

    def get_policy(self, package):
        if package.category == 'Express':
            # For Express packages, find the shortest total time path
            return self.find_shortest_time_path(package.curr, package.dst)
        else:
            # For Standard packages, find the lowest total cost path
            return self.find_lowest_cost_path(package.curr, package.dst)

    def step(self, actions):
        self.TimeTick += self.min_delay  # 更新时间
        # 更新所有包裹的延迟
        for package in self.packages.values():
            package.delay -= self.min_delay
        # 遍历所有动作
        for package_id, action in actions.items():
            print(f"STEP:::PacakgeID={package_id}, Action={action}")
            package = self.packages[package_id]  # 使用 package_id 获取包裹
            if package.done:
                package.reward = 0
                continue
            elif package.delay <= 0:  # 包裹准备好转移状态
                if action is not None:
                    node = self.nodes[action[0]]
                    next_node = self.nodes[action[1]]
                    route = self.routes[(action[0], action[1])]
                    if package_id in node.package_indices:  # 包裹位于Node
                        print(f"is in Node: {node.id},")
                        node.remove_package(package_id)
                        route.add_package(package)
                        # 更新包裹的历史、当前所在的节点
                        package.history.append((self.TimeTick, package.curr))
                        package.curr = node.id
                        # 计算包裹的reward
                        if package.category == 'Express':
                            package.reward -= self.min_delay
                        else:
                            package.reward -= node.cost
                    elif package_id in route.package_indices:  # 包裹位于Route TODO debug, it is likely to occur here!!! Check if the package at the end of the Route will be correctly updated to the next node.
                        print(f"is on Route: {route.src}->{route.dst},")
                        if len(node.packages) < node.throughput:
                            route.remove_package(package_id)
                            next_node.add_package(package)
                            # 更新包裹的历史、Route起点的节点
                            package.history.append((self.TimeTick, package.curr))
                            package.curr = next_node.id
                            # 计算包裹的reward
                            if package.category == 'Express':
                                package.reward -= self.min_delay
                            else:
                                package.reward -= route.cost
                        else: # 包裹滞留在当前Route无法进站
                            print(f"waiting..., Node: {route.dst} full")
                            if package.category == 'Express':
                                package.reward -= self.min_delay
                    else:
                        print("Error! Undone package is neither on route or in node!")
                        return 0
                else:  # 包裹准备好转移状态，但动作是None
                    print(f"This should not happen! Package: {package_id} is ready but action is None.")
                    if package.category == 'Express':
                        package.reward -= self.min_delay
            else:
                print(f"Package: {package_id} processing...")
                # package正在Route或者Node中处理
                if package.category == 'Express':
                    package.reward -= self.min_delay
        #判断是否有新的package变成done,顺便计算当前的reward,顺便判断是否done
        self.done = True
        curr_reward = 0
        self.min_delay = float('inf')
        for package in self.packages.values():
            if not package.done: #对于之前没有done的package
                curr_reward +=package.reward #累加reward
                if package.curr == package.dst: #该节点是否刚到done
                    package.history.append((self.TimeTick, package.curr))
                    next_node.remove_package(package_id)
                    package.done = True
                    package.delay = float('inf')
                else:
                    self.done = False #如果还有undone package，那么整个环境就没有done
                    #print(f"undone package {package.id} at {package.curr} has delay: {package.delay}")
                    self.min_delay = package.delay if package.delay>0 and (package.delay < self.min_delay) else self.min_delay
        print(f"the new min_delay: {self.min_delay}")
        return self.get_state(), curr_reward, self.done

    def get_reward(self, package):
        # Calculate the reward based on package category and time passed
        if package.category == 'Express':
            reward = package.time_created - self.TimeTick #TODO re-scale the reward to be compatible with the route cost
        else:
            # Calculate the cost based on package history and node/route costs
            total_cost = 0
            for timestamp,node_id in package.history:
                total_cost += self.nodes[node_id].cost
            for route in package.path:
                total_cost += self.routes[route].cost
            reward = -total_cost  # Negative cost as a reward for minimizing costs

        # If the package has reached its destination, update its delay to zero and mark it as done
        if package.src == package.dst:
            package.delay = 0
            package.mark_done()

        return reward
    
    def get_state(self):
        # Create a state representation that includes relevant information for decision-making
        state = {
            'package_positions': self.get_package_positions(),
            'package_destinations': self.get_package_destinations(),
            'package_categories': self.get_package_categories(),
            'queue_lengths': self.get_queue_lengths(),
            'route_loads': self.get_route_loads(),
            'node_loads' : self.get_node_loads(),
            'current_time_tick': self.TimeTick,
            'money_cost':self.moneycost,
            'time_cost':self.timecost
        }
        return state

    def get_package_positions(self):
        # Return a dictionary with package IDs as keys and their current node IDs as values
        positions = {pkg_id: pkg.src for pkg_id, pkg in self.packages.items()}
        return positions

    def get_package_destinations(self):
        # Return a dictionary with package IDs as keys and their destination node IDs as values
        destinations = {pkg_id: pkg.dst for pkg_id, pkg in self.packages.items()}
        return destinations

    def get_package_categories(self):
        # Return a dictionary with package IDs as keys and their categories as values
        categories = {pkg_id: pkg.category for pkg_id, pkg in self.packages.items()}
        return categories

    def get_queue_lengths(self):
        # Return a dictionary with node IDs as keys and the number of packages in their queues as values
        queue_lengths = {node_id: len(node.packages) for node_id, node in self.nodes.items()}
        return queue_lengths

    def get_route_loads(self):
        # Return a dictionary with route tuples (src, dst) as keys and the number of packages on the route as values
        route_loads = {route_tuple: len(route.packages) for route_tuple, route in self.routes.items()}
        return route_loads
    
    def get_node_loads(self):
        # 创建一个字典来存储每个站点的包裹数量
        stations_packages_number = {}
        # 遍历所有节点
        for node_id, node in self.nodes.items():
            # 计算每个节点的包裹数量
            stations_packages_number[node_id] = len(node.packages)
        # 返回包含每个站点包裹数量的字典
        return stations_packages_number
    
    def route(self,package_id):
        package = self.packages[package_id]
        stations_base = self.nodes
        stations_packages_number = self.get_node_loads()
        routes_packages_number = self.get_route_loads()
        package_from = package.src #最初的起点。如果学长想要的是当前位置，可以用package.curr
        package_to = package.dst
        package_priority = 0 if package.category is "Standard" else "Express"

        route = {
            stations_base,
            stations_packages_number,
            routes_packages_number,
            package_from,
            package_to,
            package_priority
        }

        return route

class Agent:
    def __init__(self, env):
        self.env = env
        self.state = None
        self.total_reward = 0.0
        self.action_history = []

    def reset(self):
        self.state = None
        self.total_reward = 0.0
        self.action_history = []

    def choose_action(self):
        actions = {}
        for package_id, package in self.env.packages.items():
            if package.delay > self.env.min_delay:
                # If the package's delay is positive, do nothing
                actions[package_id] = None
            else:
                # Call the get_policy method to get the next node in the optimal path
                next_node = self.env.get_policy(package)
                # Select the neighboring node to be the destination
                if next_node and next_node != package.src and next_node != package.dst:
                    actions[package_id] = next_node[:2]
                else:
                    actions[package_id] = None  # No valid action found
            #print(f"action for {package_id} is {actions[package_id]}.")
        return actions
# Out:
# Stations:
# s0 (79, 78) (20, 1, 0.8)
# s1 (71, 49) (15, 2, 0.6)
# s2 (0, 12) (15, 2, 0.6)
# s3 (15, 5) (25, 1, 0.9)
# s4 (90, 99) (10, 2, 0.5)
# s5 (30, 85) (10, 2, 0.5)
# s6 (82, 75) (10, 2, 0.5)
# s7 (74, 8) (20, 1, 0.8)
# s8 (91, 39) (15, 2, 0.6)
# s9 (0, 31) (10, 2, 0.5)
# s10 (37, 24) (10, 2, 0.5)
# s11 (91, 89) (20, 1, 0.8)
# s12 (98, 70) (10, 2, 0.5)
# s13 (85, 30) (15, 2, 0.6)
# s14 (8, 12) (25, 1, 0.9)
# s15 (0, 29) (15, 2, 0.6)
# s16 (24, 69) (15, 2, 0.6)
# s17 (76, 70) (10, 2, 0.5)
# s18 (95, 26) (20, 1, 0.8)
# s19 (7, 71) (15, 2, 0.6)
# s20 (85, 78) (15, 2, 0.6)
# s21 (67, 2) (25, 1, 0.9)
# s22 (45, 0) (10, 2, 0.5)
# s23 (6, 16) (10, 2, 0.5)
# s24 (10, 12) (10, 2, 0.5)
# Centers:
# c0 (9, 17) (100, 2, 0.5)
# c1 (85, 79) (150, 2, 0.5)
# c2 (62, 3) (125, 1, 0.5)
# c3 (20, 75) (175, 1, 0.5)
# c4 (85, 36) (150, 2, 0.5)
# Edges (center to center):
# ('c0', 'c1', 24.520399670478458, 19.616319736382767)
# ('c1', 'c0', 24.520399670478458, 19.616319736382767)
# ('c0', 'c2', 13.704470073665746, 10.963576058932597)
# ('c2', 'c0', 13.704470073665746, 10.963576058932597)
# ('c0', 'c3', 14.758472143145442, 11.806777714516354)
# ('c3', 'c0', 14.758472143145442, 11.806777714516354)
# ('c0', 'c4', 19.584751721683887, 15.66780137734711)
# ('c4', 'c0', 19.584751721683887, 15.66780137734711)
# ('c1', 'c2', 19.851007531105317, 15.880806024884254)
# ('c2', 'c1', 19.851007531105317, 15.880806024884254)
# ('c1', 'c3', 16.280740155164935, 13.02459212413195)
# ('c3', 'c1', 16.280740155164935, 13.02459212413195)
# ('c1', 'c4', 10.75, 8.6)
# ('c4', 'c1', 10.75, 8.6)
# ('c2', 'c3', 20.838665984174707, 16.670932787339765)
# ('c3', 'c2', 20.838665984174707, 16.670932787339765)
# ('c2', 'c4', 10.056092680559383, 8.044874144447506)
# ('c4', 'c2', 10.056092680559383, 8.044874144447506)
# ('c3', 'c4', 18.950593658247225, 15.16047492659778)
# ('c4', 'c3', 18.950593658247225, 15.16047492659778)
# Edges (center to station):
# ('c0', 's2', 6.1773780845922, 1.23547561691844)
# ('s2', 'c0', 6.1773780845922, 1.23547561691844)
# ('c0', 's3', 8.049844718999243, 1.6099689437998486)
# ('s3', 'c0', 8.049844718999243, 1.6099689437998486)
# ('c0', 's9', 9.985990186255943, 1.9971980372511886)
# ('s9', 'c0', 9.985990186255943, 1.9971980372511886)
# ('c0', 's10', 17.317043627594174, 3.4634087255188346)
# ('s10', 'c0', 17.317043627594174, 3.4634087255188346)
# ('c0', 's14', 3.0594117081556704, 0.6118823416311341)
# ('s14', 'c0', 3.0594117081556704, 0.6118823416311341)
# ('c0', 's15', 9.0, 1.7999999999999998)
# ('s15', 'c0', 9.0, 1.7999999999999998)
# ('c0', 's23', 1.8973665961010275, 0.37947331922020555)
# ('s23', 'c0', 1.8973665961010275, 0.37947331922020555)
# ('c0', 's24', 3.0594117081556704, 0.6118823416311341)
# ('s24', 'c0', 3.0594117081556704, 0.6118823416311341)
# ('c1', 's0', 3.6496575181789312, 0.7299315036357863)
# ('s0', 'c1', 3.6496575181789312, 0.7299315036357863)
# ('c1', 's4', 12.369316876852983, 2.4738633753705965)
# ('s4', 'c1', 12.369316876852983, 2.4738633753705965)
# ('c1', 's6', 3.0, 0.6)
# ('s6', 'c1', 3.0, 0.6)
# ('c1', 's11', 6.997142273814361, 1.3994284547628721)
# ('s11', 'c1', 6.997142273814361, 1.3994284547628721)
# ('c1', 's12', 9.486832980505138, 1.8973665961010275)
# ('s12', 'c1', 9.486832980505138, 1.8973665961010275)
# ('c1', 's17', 7.636753236814712, 1.5273506473629426)
# ('s17', 'c1', 7.636753236814712, 1.5273506473629426)
# ('c1', 's20', 0.6, 0.12)
# ('s20', 'c1', 0.6, 0.12)
# ('c2', 's7', 7.8, 1.56)
# ('s7', 'c2', 7.8, 1.56)
# ('c2', 's21', 3.0594117081556704, 0.6118823416311341)
# ('s21', 'c2', 3.0594117081556704, 0.6118823416311341)
# ('c2', 's22', 10.357605900979241, 2.071521180195848)
# ('s22', 'c2', 10.357605900979241, 2.071521180195848)
# ('c3', 's5', 8.48528137423857, 1.697056274847714)
# ('s5', 'c3', 8.48528137423857, 1.697056274847714)
# ('c3', 's16', 4.326661530556787, 0.8653323061113574)
# ('s16', 'c3', 4.326661530556787, 0.8653323061113574)
# ('c3', 's19', 8.160882305241266, 1.6321764610482532)
# ('s19', 'c3', 8.160882305241266, 1.6321764610482532)
# ('c4', 's1', 11.462983904725679, 2.2925967809451357)
# ('s1', 'c4', 11.462983904725679, 2.2925967809451357)
# ('c4', 's8', 4.024922359499621, 0.8049844718999243)
# ('s8', 'c4', 4.024922359499621, 0.8049844718999243)
# ('c4', 's13', 3.5999999999999996, 0.72)
# ('s13', 'c4', 3.5999999999999996, 0.72)
# ('c4', 's18', 8.48528137423857, 1.697056274847714)
# ('s18', 'c4', 8.48528137423857, 1.697056274847714)
# Edges (station to station):
# ('s3', 's2', 13.242356285797479, 1.1587061750072796)
# ('s2', 's3', 13.242356285797479, 1.1587061750072796)
# ('s4', 's0', 18.965231345807517, 1.6594577427581578)
# ('s0', 's4', 18.965231345807517, 1.6594577427581578)
# ('s6', 's0', 3.394112549695428, 0.29698484809834996)
# ('s0', 's6', 3.394112549695428, 0.29698484809834996)
# ('s6', 's1', 22.58495074158897, 1.9761831898890347)
# ('s1', 's6', 22.58495074158897, 1.9761831898890347)
# ('s6', 's4', 20.238577025077632, 1.7708754896942926)
# ('s4', 's6', 20.238577025077632, 1.7708754896942926)
# ('s8', 's1', 17.88854381999832, 1.565247584249853)
# ('s1', 's8', 17.88854381999832, 1.565247584249853)
# ('s9', 's2', 15.200000000000001, 1.33)
# ('s2', 's9', 15.200000000000001, 1.33)
# ('s10', 's3', 23.255106965997815, 2.034821859524809)
# ('s3', 's10', 23.255106965997815, 2.034821859524809)
# ('s11', 's0', 13.023056476879766, 1.1395174417269796)
# ('s0', 's11', 13.023056476879766, 1.1395174417269796)
# ('s11', 's4', 8.039900496896712, 0.7034912934784624)
# ('s4', 's11', 8.039900496896712, 0.7034912934784624)
# ('s11', 's6', 13.314653581674591, 1.165032188396527)
# ('s6', 's11', 13.314653581674591, 1.165032188396527)
# ('s12', 's0', 16.492422502470642, 1.4430869689661814)
# ('s0', 's12', 16.492422502470642, 1.4430869689661814)
# ('s12', 's6', 13.41044369139217, 1.173413822996815)
# ('s6', 's12', 13.41044369139217, 1.173413822996815)
# ('s12', 's11', 16.19876538505327, 1.4173919711921612)
# ('s11', 's12', 16.19876538505327, 1.4173919711921612)
# ('s13', 's1', 18.880677953929517, 1.6520593209688328)
# ('s1', 's13', 18.880677953929517, 1.6520593209688328)
# ('s13', 's7', 19.67739820199815, 1.7217723426748384)
# ('s7', 's13', 19.67739820199815, 1.7217723426748384)
# ('s13', 's8', 8.653323061113575, 0.7571657678474378)
# ('s8', 's13', 8.653323061113575, 0.7571657678474378)
# ('s14', 's2', 6.4, 0.56)
# ('s2', 's14', 6.4, 0.56)
# ('s14', 's3', 7.919595949289333, 0.6929646455628167)
# ('s3', 's14', 7.919595949289333, 0.6929646455628167)
# ('s14', 's9', 16.492422502470642, 1.4430869689661814)
# ('s9', 's14', 16.492422502470642, 1.4430869689661814)
# ('s15', 's2', 13.600000000000001, 1.1900000000000002)
# ('s2', 's15', 13.600000000000001, 1.1900000000000002)
# ('s15', 's3', 22.64155471693585, 1.981136037731887)
# ('s3', 's15', 22.64155471693585, 1.981136037731887)
# ('s15', 's9', 1.6, 0.14)
# ('s9', 's15', 1.6, 0.14)
# ('s15', 's14', 15.03063538244475, 1.3151805959639156)
# ('s14', 's15', 15.03063538244475, 1.3151805959639156)
# ('s16', 's5', 13.67040599250805, 1.1961605243444544)
# ('s5', 's16', 13.67040599250805, 1.1961605243444544)
# ('s17', 's0', 6.835202996254025, 0.5980802621722272)
# ('s0', 's17', 6.835202996254025, 0.5980802621722272)
# ('s17', 's1', 17.269626515938324, 1.5110923201446034)
# ('s1', 's17', 17.269626515938324, 1.5110923201446034)
# ('s17', 's6', 6.248199740725323, 0.5467174773134659)
# ('s6', 's17', 6.248199740725323, 0.5467174773134659)
# ('s17', 's11', 19.365949499056327, 1.6945205811674289)
# ('s11', 's17', 19.365949499056327, 1.6945205811674289)
# ('s17', 's12', 17.6, 1.54)
# ('s12', 's17', 17.6, 1.54)
# ('s18', 's7', 22.126906697502932, 1.9361043360315064)
# ('s7', 's18', 22.126906697502932, 1.9361043360315064)
# ('s18', 's8', 10.881176406988356, 0.9521029356114812)
# ('s8', 's18', 10.881176406988356, 0.9521029356114812)
# ('s18', 's13', 8.616263691415206, 0.7539230729988305)
# ('s13', 's18', 8.616263691415206, 0.7539230729988305)
# ('s19', 's5', 21.54065922853802, 1.8848076824970765)
# ('s5', 's19', 21.54065922853802, 1.8848076824970765)
# ('s19', 's16', 13.693794214898952, 1.1982069938036584)
# ('s16', 's19', 13.693794214898952, 1.1982069938036584)
# ('s20', 's0', 4.800000000000001, 0.42000000000000004)
# ('s0', 's20', 4.800000000000001, 0.42000000000000004)
# ('s20', 's4', 17.269626515938324, 1.5110923201446034)
# ('s4', 's20', 17.269626515938324, 1.5110923201446034)
# ('s20', 's6', 3.394112549695428, 0.29698484809834996)
# ('s6', 's20', 3.394112549695428, 0.29698484809834996)
# ('s20', 's11', 10.023971268913336, 0.8770974860299168)
# ('s11', 's20', 10.023971268913336, 0.8770974860299168)
# ('s20', 's12', 12.211470017978998, 1.0685036265731624)
# ('s12', 's20', 12.211470017978998, 1.0685036265731624)
# ('s20', 's17', 9.633275663033837, 0.8429116205154608)
# ('s17', 's20', 9.633275663033837, 0.8429116205154608)
# ('s21', 's7', 7.37563556583431, 0.6453681120105021)
# ('s7', 's21', 7.37563556583431, 0.6453681120105021)
# ('s22', 's10', 20.238577025077632, 1.7708754896942926)
# ('s10', 's22', 20.238577025077632, 1.7708754896942926)
# ('s22', 's21', 17.672577627499617, 1.5463505424062167)
# ('s21', 's22', 17.672577627499617, 1.5463505424062167)
# ('s23', 's2', 5.768882040742383, 0.5047771785649585)
# ('s2', 's23', 5.768882040742383, 0.5047771785649585)
# ('s23', 's3', 11.370136322841518, 0.9948869282486328)
# ('s3', 's23', 11.370136322841518, 0.9948869282486328)
# ('s23', 's9', 12.924395537122809, 1.1308846094982459)
# ('s9', 's23', 12.924395537122809, 1.1308846094982459)
# ('s23', 's14', 3.577708763999664, 0.3130495168499706)
# ('s14', 's23', 3.577708763999664, 0.3130495168499706)
# ('s23', 's15', 11.454256850621084, 1.0022474744293448)
# ('s15', 's23', 11.454256850621084, 1.0022474744293448)
# ('s24', 's2', 8.0, 0.7000000000000001)
# ('s2', 's24', 8.0, 0.7000000000000001)
# ('s24', 's3', 6.881860213634102, 0.6021627686929839)
# ('s3', 's24', 6.881860213634102, 0.6021627686929839)
# ('s24', 's9', 17.176728442867113, 1.5029637387508723)
# ('s9', 's24', 17.176728442867113, 1.5029637387508723)
# ('s24', 's10', 23.637258724310655, 2.068260138377182)
# ('s10', 's24', 23.637258724310655, 2.068260138377182)
# ('s24', 's14', 1.6, 0.14)
# ('s14', 's24', 1.6, 0.14)
# ('s24', 's15', 15.778466338652818, 1.3806158046321215)
# ('s15', 's24', 15.778466338652818, 1.3806158046321215)
# ('s24', 's23', 4.525483399593905, 0.39597979746446665)
# ('s23', 's24', 4.525483399593905, 0.39597979746446665)
# Packets:
# e75b410c-5f4f-4650-9e49-2db20b4c7393 (0.7206614693065001, 's20', 's9', 0)
# c190ce0d-183d-4a3f-be41-e058437dcdd1 (0.7393935030183618, 's17', 's6', 0)
# 6fe69d45-859b-4fda-a1e5-af919fe4eb85 (1.0105325288019067, 's15', 's18', 0)
# b5fee6f1-749f-4b42-a5d5-8d22425ba790 (1.0449427133263947, 's12', 's1', 1)
# 2a3ebdc1-2786-451a-86be-d394d0db2f5b (1.5393667225067666, 's7', 's8', 0)
# 19b70194-3daa-402f-9ec6-898d21eb4826 (2.552129570362847, 's23', 's0', 1)
# 17ab90ed-6b80-491c-a07b-75b69d4dcc78 (2.858664729251152, 's0', 's15', 0)
# b8bbb985-5a1b-4927-a7fa-85c9b4e15649 (3.7209829052483223, 's2', 's4', 1)
# 84e4165e-b7de-4780-800b-bedcfdfca395 (4.890799646899097, 's22', 's16', 0)
# acf50cc5-fc0d-4b3e-9cd3-b84d22020787 (5.116658636467135, 's17', 's5', 0)
# 075a8baa-c34d-4aaa-9e57-d1b9d68641e9 (6.948122908215138, 's7', 's1', 0)
# 5ce38f91-29ac-4366-a2c6-f4063d18b31d (7.09329012967059, 's21', 's6', 0)
# 0d2f74e6-fd5a-4c1a-b826-958d958e32c7 (7.346733675265715, 's12', 's14', 0)
# a20db49a-7972-42c5-bfb1-687541a16bbf (8.30241652877054, 's0', 's7', 0)
# 97cf6ad1-67b3-4bb2-811b-b9e3f3de99df (8.696427407081934, 's3', 's10', 0)
# cc704149-58b0-48fd-b52a-8b5b02080d43 (8.863430602147758, 's15', 's1', 0)
# e2c4e56d-6435-45f3-b624-489ecc869e3a (10.071958402583157, 's7', 's14', 0)
# 1ff3b1f8-1da1-41dc-9a21-ce8acf9db8d7 (11.473959237699965, 's10', 's8', 1)
# d8e8006d-a848-480e-9864-0b6bb42db806 (11.500605677927986, 's7', 's1', 0)
# a4a400ff-d7bd-4e68-ae80-6c99345676cc (11.67420894955822, 's23', 's13', 0)

# %%
env = LogisticsEnv()
state = env.reset()

# 创建代理
agent = Agent(env)

# 模拟几个时间步
i=0
done = False
while (not done):
    i+=1
    print(f"------------------------------------------------------STEP{i}------------------------------------------------------")
    actions = agent.choose_action()
    next_state, reward, done = env.step(actions)
    print(f"Time tick: {env.TimeTick}, Total reward: {reward}")

# 检查所有包是否已到达目的地
for package_id in env.packages:
    package = env.packages[package_id]
    if not package.done:
        print(f"Package {package_id} did not reach the destination.")
        break
else:
    print("All packages have reached the destination.")
# Out:
# Pack added to Node: s20;
# Package 81f450b7-e5c9-474d-bb0a-5fb5219aa597 added, delay=2, src=s20, curr=s20, dst=s9, done=False, path=['s20', 'c1', 'c0', 's9']
# Pack added to Node: s17;
# Package d6854a38-4e0d-405d-b866-95289480761f added, delay=2, src=s17, curr=s17, dst=s6, done=False, path=['s17', 's6']
# Pack added to Node: s15;
# Package 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 added, delay=2, src=s15, curr=s15, dst=s18, done=False, path=['s15', 'c0', 'c4', 's18']
# Pack added to Node: s12;
# Package 4d17cd12-56c7-43f5-9a35-5ceaf21173bb added, delay=2, src=s12, curr=s12, dst=s1, done=False, path=['s12', 'c1', 'c4', 's1']
# Pack added to Node: s7;
# Package e4c1f6dc-bb29-4b69-859c-7303e2e51a74 added, delay=1, src=s7, curr=s7, dst=s8, done=False, path=['s7', 'c2', 'c4', 's8']
# Pack added to Node: s23;
# Package 0baf0031-d0e7-49d5-983a-b6e799401ab1 added, delay=2, src=s23, curr=s23, dst=s0, done=False, path=['s23', 'c0', 'c1', 's0']
# Pack added to Node: s0;
# Package 290f656e-a2e8-4fc7-b7a9-952775a33df6 added, delay=1, src=s0, curr=s0, dst=s15, done=False, path=['s0', 'c1', 'c0', 's15']
# Pack added to Node: s2;
# Package 13bda056-7613-46ce-b47e-b27cd53fe4d0 added, delay=2, src=s2, curr=s2, dst=s4, done=False, path=['s2', 'c0', 'c1', 's4']
# Pack added to Node: s22;
# Package ee2f990f-be62-4924-8d9c-6337d0c3b168 added, delay=2, src=s22, curr=s22, dst=s16, done=False, path=['s22', 'c2', 'c3', 's16']
# Pack added to Node: s17;
# Package a1c5777f-7d75-4f29-95b2-840f009f08d2 added, delay=2, src=s17, curr=s17, dst=s5, done=False, path=['s17', 'c1', 'c3', 's5']
# Pack added to Node: s7;
# Package 35ac2d84-1bda-4fcb-a664-daedd078c07f added, delay=1, src=s7, curr=s7, dst=s1, done=False, path=['s7', 'c2', 'c4', 's1']
# Pack added to Node: s21;
# Package ff429487-b892-4aa8-91e8-712ada7801c4 added, delay=1, src=s21, curr=s21, dst=s6, done=False, path=['s21', 'c2', 'c1', 's6']
# Pack added to Node: s12;
# Package 9ea773f8-4f84-44fb-ba21-52d7f0969e4c added, delay=2, src=s12, curr=s12, dst=s14, done=False, path=['s12', 'c1', 'c0', 's14']
# Pack added to Node: s0;
# Package 79e8f322-07ae-4bb6-bd00-fd4b1c57539a added, delay=1, src=s0, curr=s0, dst=s7, done=False, path=['s0', 'c1', 'c2', 's7']
# Pack added to Node: s3;
# Package c32f86a3-8284-4f3a-ae6e-e03f7a4b152b added, delay=1, src=s3, curr=s3, dst=s10, done=False, path=['s3', 's10']
# Pack added to Node: s15;
# Package bb428ff3-7cfc-40e1-912f-9b9d4fc20219 added, delay=2, src=s15, curr=s15, dst=s1, done=False, path=['s15', 'c0', 'c4', 's1']
# Pack added to Node: s7;
# Package dcfe77e9-23be-4c9d-bdf9-0816b3d7434c added, delay=1, src=s7, curr=s7, dst=s14, done=False, path=['s7', 'c2', 'c0', 's14']
# Pack added to Node: s10;
# Package f2f845ff-9606-449c-adf3-05c3494048c0 added, delay=2, src=s10, curr=s10, dst=s8, done=False, path=['s10', 'c0', 'c4', 's8']
# Pack added to Node: s7;
# Package c90a8ce9-648b-4e47-acbe-da18a2da24be added, delay=1, src=s7, curr=s7, dst=s1, done=False, path=['s7', 'c2', 'c4', 's1']
# Pack added to Node: s23;
# Package f7a2dd36-1050-48a3-ba39-a7e327c843c2 added, delay=2, src=s23, curr=s23, dst=s13, done=False, path=['s23', 'c0', 'c4', 's13']
# Node(s0, (79, 78), Throughput: 20, Delay: 1, Cost: 0.8, Packages: [UUID('290f656e-a2e8-4fc7-b7a9-952775a33df6'), UUID('79e8f322-07ae-4bb6-bd00-fd4b1c57539a')])
# Node(s1, (71, 49), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [])
# Node(s2, (0, 12), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [UUID('13bda056-7613-46ce-b47e-b27cd53fe4d0')])
# Node(s3, (15, 5), Throughput: 25, Delay: 1, Cost: 0.9, Packages: [UUID('c32f86a3-8284-4f3a-ae6e-e03f7a4b152b')])
# Node(s4, (90, 99), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [])
# Node(s5, (30, 85), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [])
# Node(s6, (82, 75), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [])
# Node(s7, (74, 8), Throughput: 20, Delay: 1, Cost: 0.8, Packages: [UUID('e4c1f6dc-bb29-4b69-859c-7303e2e51a74'), UUID('35ac2d84-1bda-4fcb-a664-daedd078c07f'), UUID('dcfe77e9-23be-4c9d-bdf9-0816b3d7434c'), UUID('c90a8ce9-648b-4e47-acbe-da18a2da24be')])
# Node(s8, (91, 39), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [])
# Node(s9, (0, 31), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [])
# Node(s10, (37, 24), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [UUID('f2f845ff-9606-449c-adf3-05c3494048c0')])
# Node(s11, (91, 89), Throughput: 20, Delay: 1, Cost: 0.8, Packages: [])
# Node(s12, (98, 70), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [UUID('4d17cd12-56c7-43f5-9a35-5ceaf21173bb'), UUID('9ea773f8-4f84-44fb-ba21-52d7f0969e4c')])
# Node(s13, (85, 30), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [])
# Node(s14, (8, 12), Throughput: 25, Delay: 1, Cost: 0.9, Packages: [])
# Node(s15, (0, 29), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [UUID('8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72'), UUID('bb428ff3-7cfc-40e1-912f-9b9d4fc20219')])
# Node(s16, (24, 69), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [])
# Node(s17, (76, 70), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [UUID('d6854a38-4e0d-405d-b866-95289480761f'), UUID('a1c5777f-7d75-4f29-95b2-840f009f08d2')])
# Node(s18, (95, 26), Throughput: 20, Delay: 1, Cost: 0.8, Packages: [])
# Node(s19, (7, 71), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [])
# Node(s20, (85, 78), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [UUID('81f450b7-e5c9-474d-bb0a-5fb5219aa597')])
# Node(s21, (67, 2), Throughput: 25, Delay: 1, Cost: 0.9, Packages: [UUID('ff429487-b892-4aa8-91e8-712ada7801c4')])
# Node(s22, (45, 0), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [UUID('ee2f990f-be62-4924-8d9c-6337d0c3b168')])
# Node(s23, (6, 16), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [UUID('0baf0031-d0e7-49d5-983a-b6e799401ab1'), UUID('f7a2dd36-1050-48a3-ba39-a7e327c843c2')])
# Node(s24, (10, 12), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [])
# Node(c0, (9, 17), Throughput: 100, Delay: 2, Cost: 0.5, Packages: [])
# Node(c1, (85, 79), Throughput: 150, Delay: 2, Cost: 0.5, Packages: [])
# Node(c2, (62, 3), Throughput: 125, Delay: 1, Cost: 0.5, Packages: [])
# Node(c3, (20, 75), Throughput: 175, Delay: 1, Cost: 0.5, Packages: [])
# Node(c4, (85, 36), Throughput: 150, Delay: 2, Cost: 0.5, Packages: [])
# Env reset. min_delay=1, TimeTick=0.0
# ------------------------------------------------------STEP1------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=None
# Package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 processing...
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# Package: d6854a38-4e0d-405d-b866-95289480761f processing...
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=None
# Package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb processing...
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=['s7', 'c2']
# is in Node: s7,
# package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 removed from Node: s7.
# Pack added to Route: s7->c2;
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=None
# Package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 processing...
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=['s0', 'c1']
# is in Node: s0,
# package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 removed from Node: s0.
# Pack added to Route: s0->c1;
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=None
# Package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 processing...
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=None
# Package: ee2f990f-be62-4924-8d9c-6337d0c3b168 processing...
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=None
# Package: a1c5777f-7d75-4f29-95b2-840f009f08d2 processing...
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=['s7', 'c2']
# is in Node: s7,
# package: 35ac2d84-1bda-4fcb-a664-daedd078c07f removed from Node: s7.
# Pack added to Route: s7->c2;
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=['s21', 'c2']
# is in Node: s21,
# package: ff429487-b892-4aa8-91e8-712ada7801c4 removed from Node: s21.
# Pack added to Route: s21->c2;
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=None
# Package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c processing...
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=['s0', 'c1']
# is in Node: s0,
# package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a removed from Node: s0.
# Pack added to Route: s0->c1;
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=['s3', 's10']
# is in Node: s3,
# package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b removed from Node: s3.
# Pack added to Route: s3->s10;
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=None
# Package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 processing...
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=['s7', 'c2']
# is in Node: s7,
# package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c removed from Node: s7.
# Pack added to Route: s7->c2;
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=['s7', 'c2']
# is in Node: s7,
# package: c90a8ce9-648b-4e47-acbe-da18a2da24be removed from Node: s7.
# Pack added to Route: s7->c2;
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=None
# Package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 processing...
# the new min_delay: 1
# Time tick: 1.0, Total reward: -6.6000000000000005
# ------------------------------------------------------STEP2------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=['s20', 'c1']
# is in Node: s20,
# package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 removed from Node: s20.
# Pack added to Route: s20->c1;
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=['s17', 's6']
# is in Node: s17,
# package: d6854a38-4e0d-405d-b866-95289480761f removed from Node: s17.
# Pack added to Route: s17->s6;
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=['s15', 'c0']
# is in Node: s15,
# package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 removed from Node: s15.
# Pack added to Route: s15->c0;
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=['s12', 'c1']
# is in Node: s12,
# package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb removed from Node: s12.
# Pack added to Route: s12->c1;
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=None
# Package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 processing...
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=['s23', 'c0']
# is in Node: s23,
# package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 removed from Node: s23.
# Pack added to Route: s23->c0;
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=None
# Package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 processing...
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=['s2', 'c0']
# is in Node: s2,
# package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 removed from Node: s2.
# Pack added to Route: s2->c0;
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=['s22', 'c2']
# is in Node: s22,
# package: ee2f990f-be62-4924-8d9c-6337d0c3b168 removed from Node: s22.
# Pack added to Route: s22->c2;
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=['s17', 'c1']
# is in Node: s17,
# package: a1c5777f-7d75-4f29-95b2-840f009f08d2 removed from Node: s17.
# Pack added to Route: s17->c1;
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=None
# Package: 35ac2d84-1bda-4fcb-a664-daedd078c07f processing...
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=None
# Package: ff429487-b892-4aa8-91e8-712ada7801c4 processing...
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=['s12', 'c1']
# is in Node: s12,
# package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c removed from Node: s12.
# Pack added to Route: s12->c1;
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=None
# Package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a processing...
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=['s15', 'c0']
# is in Node: s15,
# package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 removed from Node: s15.
# Pack added to Route: s15->c0;
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=None
# Package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c processing...
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=['s10', 'c0']
# is in Node: s10,
# package: f2f845ff-9606-449c-adf3-05c3494048c0 removed from Node: s10.
# Pack added to Route: s10->c0;
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=None
# Package: c90a8ce9-648b-4e47-acbe-da18a2da24be processing...
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=['s23', 'c0']
# is in Node: s23,
# package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 removed from Node: s23.
# Pack added to Route: s23->c0;
# the new min_delay: 0.6
# Time tick: 2.0, Total reward: -13.000000000000002
# ------------------------------------------------------STEP3------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=['s20', 'c1']
# is on Route: s20->c1,
# package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 removed from Route: s20->c1.
# Pack added to Node: c1;
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# Package: d6854a38-4e0d-405d-b866-95289480761f processing...
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=None
# Package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb processing...
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=None
# Package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 processing...
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=None
# Package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 processing...
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=None
# Package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 processing...
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=None
# Package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 processing...
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=None
# Package: ee2f990f-be62-4924-8d9c-6337d0c3b168 processing...
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=None
# Package: a1c5777f-7d75-4f29-95b2-840f009f08d2 processing...
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=None
# Package: 35ac2d84-1bda-4fcb-a664-daedd078c07f processing...
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=None
# Package: ff429487-b892-4aa8-91e8-712ada7801c4 processing...
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=None
# Package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c processing...
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=None
# Package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a processing...
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=None
# Package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 processing...
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=None
# Package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c processing...
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=None
# Package: c90a8ce9-648b-4e47-acbe-da18a2da24be processing...
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=None
# Package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 processing...
# the new min_delay: 1.2973665961010274
# Time tick: 2.6, Total reward: -13.120000000000001
# ------------------------------------------------------STEP4------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=None
# Package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 processing...
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# Package: d6854a38-4e0d-405d-b866-95289480761f processing...
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=None
# Package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb processing...
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=None
# Package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 processing...
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=['s23', 'c0']
# is on Route: s23->c0,
# package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 removed from Route: s23->c0.
# Pack added to Node: c0;
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=None
# Package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 processing...
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=None
# Package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 processing...
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=None
# Package: ee2f990f-be62-4924-8d9c-6337d0c3b168 processing...
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=None
# Package: a1c5777f-7d75-4f29-95b2-840f009f08d2 processing...
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=None
# Package: 35ac2d84-1bda-4fcb-a664-daedd078c07f processing...
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=None
# Package: ff429487-b892-4aa8-91e8-712ada7801c4 processing...
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=None
# Package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c processing...
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=None
# Package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a processing...
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=None
# Package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 processing...
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=None
# Package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c processing...
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=None
# Package: c90a8ce9-648b-4e47-acbe-da18a2da24be processing...
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=['s23', 'c0']
# is on Route: s23->c0,
# package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 removed from Route: s23->c0.
# Pack added to Node: c0;
# the new min_delay: 0.1620451120546429
# Time tick: 3.8973665961010275, Total reward: -13.878946638440413
# ------------------------------------------------------STEP5------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=None
# Package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 processing...
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# Package: d6854a38-4e0d-405d-b866-95289480761f processing...
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=None
# Package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb processing...
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=None
# Package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 processing...
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=None
# Package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 processing...
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=None
# Package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 processing...
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=None
# Package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 processing...
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=None
# Package: ee2f990f-be62-4924-8d9c-6337d0c3b168 processing...
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=None
# Package: a1c5777f-7d75-4f29-95b2-840f009f08d2 processing...
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=None
# Package: 35ac2d84-1bda-4fcb-a664-daedd078c07f processing...
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=['s21', 'c2']
# is on Route: s21->c2,
# package: ff429487-b892-4aa8-91e8-712ada7801c4 removed from Route: s21->c2.
# Pack added to Node: c2;
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=None
# Package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c processing...
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=None
# Package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a processing...
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=None
# Package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 processing...
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=None
# Package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c processing...
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=None
# Package: c90a8ce9-648b-4e47-acbe-da18a2da24be processing...
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=None
# Package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 processing...
# the new min_delay: 0.5405882918443297
# Time tick: 4.05941170815567, Total reward: -14.490828980071546
# ------------------------------------------------------STEP6------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=['c1', 'c0']
# is in Node: c1,
# package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 removed from Node: c1.
# Pack added to Route: c1->c0;
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# Package: d6854a38-4e0d-405d-b866-95289480761f processing...
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=None
# Package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb processing...
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=None
# Package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 processing...
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=None
# Package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 processing...
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=None
# Package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 processing...
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=None
# Package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 processing...
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=None
# Package: ee2f990f-be62-4924-8d9c-6337d0c3b168 processing...
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=None
# Package: a1c5777f-7d75-4f29-95b2-840f009f08d2 processing...
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=None
# Package: 35ac2d84-1bda-4fcb-a664-daedd078c07f processing...
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=None
# Package: ff429487-b892-4aa8-91e8-712ada7801c4 processing...
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=None
# Package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c processing...
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=None
# Package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a processing...
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=None
# Package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 processing...
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=None
# Package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c processing...
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=None
# Package: c90a8ce9-648b-4e47-acbe-da18a2da24be processing...
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=None
# Package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 processing...
# the new min_delay: 0.04965751817893116
# Time tick: 4.6, Total reward: -14.990828980071546
# ------------------------------------------------------STEP7------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=None
# Package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 processing...
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# Package: d6854a38-4e0d-405d-b866-95289480761f processing...
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=None
# Package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb processing...
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=None
# Package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 processing...
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=None
# Package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 processing...
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=['s0', 'c1']
# is on Route: s0->c1,
# package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 removed from Route: s0->c1.
# Pack added to Node: c1;
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=None
# Package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 processing...
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=None
# Package: ee2f990f-be62-4924-8d9c-6337d0c3b168 processing...
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=None
# Package: a1c5777f-7d75-4f29-95b2-840f009f08d2 processing...
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=None
# Package: 35ac2d84-1bda-4fcb-a664-daedd078c07f processing...
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=None
# Package: ff429487-b892-4aa8-91e8-712ada7801c4 processing...
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=None
# Package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c processing...
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=['s0', 'c1']
# is on Route: s0->c1,
# package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a removed from Route: s0->c1.
# Pack added to Node: c1;
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=None
# Package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 processing...
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=None
# Package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c processing...
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=None
# Package: c90a8ce9-648b-4e47-acbe-da18a2da24be processing...
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=None
# Package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 processing...
# the new min_delay: 0.4097541899767392
# Time tick: 4.64965751817893, Total reward: -16.45069198734312
# ------------------------------------------------------STEP8------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=None
# Package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 processing...
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# Package: d6854a38-4e0d-405d-b866-95289480761f processing...
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=None
# Package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb processing...
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=None
# Package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 processing...
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=None
# Package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 processing...
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=None
# Package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 processing...
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=None
# Package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 processing...
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=None
# Package: ee2f990f-be62-4924-8d9c-6337d0c3b168 processing...
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=None
# Package: a1c5777f-7d75-4f29-95b2-840f009f08d2 processing...
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=None
# Package: 35ac2d84-1bda-4fcb-a664-daedd078c07f processing...
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=['c2', 'c1']
# is in Node: c2,
# package: ff429487-b892-4aa8-91e8-712ada7801c4 removed from Node: c2.
# Pack added to Route: c2->c1;
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=None
# Package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c processing...
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=None
# Package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a processing...
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=None
# Package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 processing...
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=None
# Package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c processing...
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=None
# Package: c90a8ce9-648b-4e47-acbe-da18a2da24be processing...
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=None
# Package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 processing...
# the new min_delay: 0.8379548879453571
# Time tick: 5.05941170815567, Total reward: -16.95069198734312
# ------------------------------------------------------STEP9------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=None
# Package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 processing...
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# Package: d6854a38-4e0d-405d-b866-95289480761f processing...
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=None
# Package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb processing...
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=None
# Package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 processing...
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=['c0', 'c1']
# is in Node: c0,
# package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 removed from Node: c0.
# Pack added to Route: c0->c1;
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=None
# Package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 processing...
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=None
# Package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 processing...
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=None
# Package: ee2f990f-be62-4924-8d9c-6337d0c3b168 processing...
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=None
# Package: a1c5777f-7d75-4f29-95b2-840f009f08d2 processing...
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=None
# Package: 35ac2d84-1bda-4fcb-a664-daedd078c07f processing...
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=None
# Package: ff429487-b892-4aa8-91e8-712ada7801c4 processing...
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=None
# Package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c processing...
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=None
# Package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a processing...
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=None
# Package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 processing...
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=None
# Package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c processing...
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=None
# Package: c90a8ce9-648b-4e47-acbe-da18a2da24be processing...
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=['c0', 'c4']
# is in Node: c0,
# package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 removed from Node: c0.
# Pack added to Route: c0->c4;
# the new min_delay: 0.7522909220779037
# Time tick: 5.897366596101027, Total reward: -17.95069198734312
# ------------------------------------------------------STEP10------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=None
# Package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 processing...
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# Package: d6854a38-4e0d-405d-b866-95289480761f processing...
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=None
# Package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb processing...
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=None
# Package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 processing...
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=None
# Package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 processing...
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=['c1', 'c0']
# is in Node: c1,
# package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 removed from Node: c1.
# Pack added to Route: c1->c0;
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=None
# Package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 processing...
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=None
# Package: ee2f990f-be62-4924-8d9c-6337d0c3b168 processing...
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=None
# Package: a1c5777f-7d75-4f29-95b2-840f009f08d2 processing...
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=None
# Package: 35ac2d84-1bda-4fcb-a664-daedd078c07f processing...
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=None
# Package: ff429487-b892-4aa8-91e8-712ada7801c4 processing...
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=None
# Package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c processing...
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=['c1', 'c2']
# is in Node: c1,
# package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a removed from Node: c1.
# Pack added to Route: c1->c2;
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=None
# Package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 processing...
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=None
# Package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c processing...
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=None
# Package: c90a8ce9-648b-4e47-acbe-da18a2da24be processing...
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=None
# Package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 processing...
# the new min_delay: 1.5277205664132691
# Time tick: 6.64965751817893, Total reward: -18.95069198734312
# ------------------------------------------------------STEP11------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=None
# Package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 processing...
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# Package: d6854a38-4e0d-405d-b866-95289480761f processing...
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=None
# Package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb processing...
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=None
# Package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 processing...
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=None
# Package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 processing...
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=None
# Package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 processing...
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=['s2', 'c0']
# is on Route: s2->c0,
# package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 removed from Route: s2->c0.
# Pack added to Node: c0;
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=None
# Package: ee2f990f-be62-4924-8d9c-6337d0c3b168 processing...
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=None
# Package: a1c5777f-7d75-4f29-95b2-840f009f08d2 processing...
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=None
# Package: 35ac2d84-1bda-4fcb-a664-daedd078c07f processing...
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=None
# Package: ff429487-b892-4aa8-91e8-712ada7801c4 processing...
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=None
# Package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c processing...
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=None
# Package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a processing...
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=None
# Package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 processing...
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=None
# Package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c processing...
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=None
# Package: c90a8ce9-648b-4e47-acbe-da18a2da24be processing...
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=None
# Package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 processing...
# the new min_delay: 0.07082165613312341
# Time tick: 8.177378084592199, Total reward: -20.186167604261563
# ------------------------------------------------------STEP12------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=None
# Package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 processing...
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=['s17', 's6']
# is on Route: s17->s6,
# package: d6854a38-4e0d-405d-b866-95289480761f removed from Route: s17->s6.
# Pack added to Node: s6;
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=None
# Package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb processing...
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=None
# Package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 processing...
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=None
# Package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 processing...
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=None
# Package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 processing...
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=None
# Package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 processing...
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=None
# Package: ee2f990f-be62-4924-8d9c-6337d0c3b168 processing...
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=None
# Package: a1c5777f-7d75-4f29-95b2-840f009f08d2 processing...
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=None
# Package: 35ac2d84-1bda-4fcb-a664-daedd078c07f processing...
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=None
# Package: ff429487-b892-4aa8-91e8-712ada7801c4 processing...
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=None
# Package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c processing...
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=None
# Package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a processing...
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=None
# Package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 processing...
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=None
# Package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c processing...
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=None
# Package: c90a8ce9-648b-4e47-acbe-da18a2da24be processing...
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=None
# Package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 processing...
# the new min_delay: 0.551800259274676
# Time tick: 8.248199740725322, Total reward: -20.73288508157503
# ------------------------------------------------------STEP13------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=None
# Package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 processing...
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=None
# Package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb processing...
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=['s7', 'c2']
# is on Route: s7->c2,
# package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 removed from Route: s7->c2.
# Pack added to Node: c2;
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=None
# Package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 processing...
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=None
# Package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 processing...
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=None
# Package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 processing...
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=None
# Package: ee2f990f-be62-4924-8d9c-6337d0c3b168 processing...
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=None
# Package: a1c5777f-7d75-4f29-95b2-840f009f08d2 processing...
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=['s7', 'c2']
# is on Route: s7->c2,
# package: 35ac2d84-1bda-4fcb-a664-daedd078c07f removed from Route: s7->c2.
# Pack added to Node: c2;
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=None
# Package: ff429487-b892-4aa8-91e8-712ada7801c4 processing...
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=None
# Package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c processing...
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=None
# Package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a processing...
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=None
# Package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 processing...
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=['s7', 'c2']
# is on Route: s7->c2,
# package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c removed from Route: s7->c2.
# Pack added to Node: c2;
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=['s7', 'c2']
# is on Route: s7->c2,
# package: c90a8ce9-648b-4e47-acbe-da18a2da24be removed from Route: s7->c2.
# Pack added to Node: c2;
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=None
# Package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 processing...
# the new min_delay: 0.836753236814713
# Time tick: 8.799999999999999, Total reward: -25.926167604261558
# ------------------------------------------------------STEP14------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=None
# Package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 processing...
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=None
# Package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb processing...
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=None
# Package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 processing...
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=None
# Package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 processing...
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=None
# Package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 processing...
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=None
# Package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 processing...
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=None
# Package: ee2f990f-be62-4924-8d9c-6337d0c3b168 processing...
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=['s17', 'c1']
# is on Route: s17->c1,
# package: a1c5777f-7d75-4f29-95b2-840f009f08d2 removed from Route: s17->c1.
# Pack added to Node: c1;
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=None
# Package: 35ac2d84-1bda-4fcb-a664-daedd078c07f processing...
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=None
# Package: ff429487-b892-4aa8-91e8-712ada7801c4 processing...
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=None
# Package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c processing...
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=None
# Package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a processing...
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=None
# Package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 processing...
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=None
# Package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c processing...
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=None
# Package: c90a8ce9-648b-4e47-acbe-da18a2da24be processing...
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=None
# Package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 processing...
# the new min_delay: 0.16324676318528697
# Time tick: 9.636753236814712, Total reward: -27.453518251624498
# ------------------------------------------------------STEP15------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=None
# Package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 processing...
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=None
# Package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb processing...
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=['c2', 'c4']
# is in Node: c2,
# package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 removed from Node: c2.
# Pack added to Route: c2->c4;
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=None
# Package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 processing...
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=None
# ...
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=['s15', 'c0']
# is on Route: s15->c0,
# package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 removed from Route: s15->c0.
# Pack added to Node: c0;
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=None
# Package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c processing...
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=None
# Package: c90a8ce9-648b-4e47-acbe-da18a2da24be processing...
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=None
# Package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 processing...
# the new min_delay: 0.4868329805051381
# Time tick: 11.0, Total reward: -33.553518251624496
# ------------------------------------------------------STEP18------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=None
# Package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 processing...
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=['s12', 'c1']
# is on Route: s12->c1,
# package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb removed from Route: s12->c1.
# Pack added to Node: c1;
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=None
# Package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 processing...
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=None
# Package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 processing...
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=None
# Package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 processing...
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=None
# Package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 processing...
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=None
# Package: ee2f990f-be62-4924-8d9c-6337d0c3b168 processing...
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=None
# Package: a1c5777f-7d75-4f29-95b2-840f009f08d2 processing...
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=None
# Package: 35ac2d84-1bda-4fcb-a664-daedd078c07f processing...
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=None
# Package: ff429487-b892-4aa8-91e8-712ada7801c4 processing...
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=['s12', 'c1']
# is on Route: s12->c1,
# package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c removed from Route: s12->c1.
# Pack added to Node: c1;
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=None
# Package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a processing...
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=None
# Package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 processing...
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=None
# Package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c processing...
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=None
# Package: c90a8ce9-648b-4e47-acbe-da18a2da24be processing...
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=None
# Package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 processing...
# the new min_delay: 0.14992025630957384
# Time tick: 11.486832980505138, Total reward: -37.34825144382655
# ------------------------------------------------------STEP19------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=None
# Package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 processing...
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=None
# Package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb processing...
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=None
# Package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 processing...
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=None
# Package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 processing...
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=None
# Package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 processing...
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=None
# Package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 processing...
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=None
# Package: ee2f990f-be62-4924-8d9c-6337d0c3b168 processing...
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=['c1', 'c3']
# is in Node: c1,
# package: a1c5777f-7d75-4f29-95b2-840f009f08d2 removed from Node: c1.
# Pack added to Route: c1->c3;
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=None
# Package: 35ac2d84-1bda-4fcb-a664-daedd078c07f processing...
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=None
# Package: ff429487-b892-4aa8-91e8-712ada7801c4 processing...
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=None
# Package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c processing...
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=None
# Package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a processing...
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=None
# Package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 processing...
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=None
# Package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c processing...
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=None
# Package: c90a8ce9-648b-4e47-acbe-da18a2da24be processing...
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=None
# Package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 processing...
# the new min_delay: 0.7208526641645312
# Time tick: 11.636753236814712, Total reward: -37.84825144382655
# ------------------------------------------------------STEP20------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=None
# Package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 processing...
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=None
# Package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb processing...
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=None
# Package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 processing...
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=None
# Package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 processing...
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=None
# Package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 processing...
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=None
# Package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 processing...
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=['s22', 'c2']
# is on Route: s22->c2,
# package: ee2f990f-be62-4924-8d9c-6337d0c3b168 removed from Route: s22->c2.
# Pack added to Node: c2;
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=None
# Package: a1c5777f-7d75-4f29-95b2-840f009f08d2 processing...
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=None
# Package: 35ac2d84-1bda-4fcb-a664-daedd078c07f processing...
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=None
# Package: ff429487-b892-4aa8-91e8-712ada7801c4 processing...
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=None
# Package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c processing...
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=None
# Package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a processing...
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=None
# Package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 processing...
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=None
# Package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c processing...
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=None
# Package: c90a8ce9-648b-4e47-acbe-da18a2da24be processing...
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=None
# Package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 processing...
# the new min_delay: 0.6423940990207568
# Time tick: 12.357605900979244, Total reward: -39.9197726240224
# ------------------------------------------------------STEP21------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=None
# Package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 processing...
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=['c0', 'c4']
# is in Node: c0,
# package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 removed from Node: c0.
# Pack added to Route: c0->c4;
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=None
# Package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb processing...
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=None
# Package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 processing...
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=None
# Package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 processing...
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=None
# Package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 processing...
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=None
# Package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 processing...
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=None
# Package: ee2f990f-be62-4924-8d9c-6337d0c3b168 processing...
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=None
# Package: a1c5777f-7d75-4f29-95b2-840f009f08d2 processing...
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=None
# Package: 35ac2d84-1bda-4fcb-a664-daedd078c07f processing...
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=None
# Package: ff429487-b892-4aa8-91e8-712ada7801c4 processing...
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=None
# Package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c processing...
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=None
# Package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a processing...
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=['c0', 'c4']
# is in Node: c0,
# package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 removed from Node: c0.
# Pack added to Route: c0->c4;
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=None
# Package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c processing...
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=None
# Package: c90a8ce9-648b-4e47-acbe-da18a2da24be processing...
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=None
# Package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 processing...
# the new min_delay: 0.35760590097924316
# Time tick: 13.000000000000002, Total reward: -40.9197726240224
# ------------------------------------------------------STEP22------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=None
# Package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 processing...
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=None
# Package: 4d17cd12-56c7-43f5-9a35-5ceaf21173bb processing...
# STEP:::PacakgeID=e4c1f6dc-bb29-4b69-859c-7303e2e51a74, Action=None
# Package: e4c1f6dc-bb29-4b69-859c-7303e2e51a74 processing...
# STEP:::PacakgeID=0baf0031-d0e7-49d5-983a-b6e799401ab1, Action=None
# Package: 0baf0031-d0e7-49d5-983a-b6e799401ab1 processing...
# STEP:::PacakgeID=290f656e-a2e8-4fc7-b7a9-952775a33df6, Action=None
# Package: 290f656e-a2e8-4fc7-b7a9-952775a33df6 processing...
# STEP:::PacakgeID=13bda056-7613-46ce-b47e-b27cd53fe4d0, Action=None
# Package: 13bda056-7613-46ce-b47e-b27cd53fe4d0 processing...
# STEP:::PacakgeID=ee2f990f-be62-4924-8d9c-6337d0c3b168, Action=['c2', 'c3']
# is in Node: c2,
# package: ee2f990f-be62-4924-8d9c-6337d0c3b168 removed from Node: c2.
# Pack added to Route: c2->c3;
# STEP:::PacakgeID=a1c5777f-7d75-4f29-95b2-840f009f08d2, Action=None
# Package: a1c5777f-7d75-4f29-95b2-840f009f08d2 processing...
# STEP:::PacakgeID=35ac2d84-1bda-4fcb-a664-daedd078c07f, Action=None
# Package: 35ac2d84-1bda-4fcb-a664-daedd078c07f processing...
# STEP:::PacakgeID=ff429487-b892-4aa8-91e8-712ada7801c4, Action=None
# Package: ff429487-b892-4aa8-91e8-712ada7801c4 processing...
# STEP:::PacakgeID=9ea773f8-4f84-44fb-ba21-52d7f0969e4c, Action=None
# Package: 9ea773f8-4f84-44fb-ba21-52d7f0969e4c processing...
# STEP:::PacakgeID=79e8f322-07ae-4bb6-bd00-fd4b1c57539a, Action=None
# Package: 79e8f322-07ae-4bb6-bd00-fd4b1c57539a processing...
# STEP:::PacakgeID=c32f86a3-8284-4f3a-ae6e-e03f7a4b152b, Action=None
# Package: c32f86a3-8284-4f3a-ae6e-e03f7a4b152b processing...
# STEP:::PacakgeID=bb428ff3-7cfc-40e1-912f-9b9d4fc20219, Action=None
# Package: bb428ff3-7cfc-40e1-912f-9b9d4fc20219 processing...
# STEP:::PacakgeID=dcfe77e9-23be-4c9d-bdf9-0816b3d7434c, Action=None
# Package: dcfe77e9-23be-4c9d-bdf9-0816b3d7434c processing...
# STEP:::PacakgeID=f2f845ff-9606-449c-adf3-05c3494048c0, Action=None
# Package: f2f845ff-9606-449c-adf3-05c3494048c0 processing...
# STEP:::PacakgeID=c90a8ce9-648b-4e47-acbe-da18a2da24be, Action=None
# Package: c90a8ce9-648b-4e47-acbe-da18a2da24be processing...
# STEP:::PacakgeID=f7a2dd36-1050-48a3-ba39-a7e327c843c2, Action=None
# Package: f7a2dd36-1050-48a3-ba39-a7e327c843c2 processing...
# the new min_delay: 0.12922707952589496
# Time tick: 13.357605900979244, Total reward: -41.4197726240224
# ------------------------------------------------------STEP23------------------------------------------------------
# STEP:::PacakgeID=81f450b7-e5c9-474d-bb0a-5fb5219aa597, Action=None
# Package: 81f450b7-e5c9-474d-bb0a-5fb5219aa597 processing...
# STEP:::PacakgeID=d6854a38-4e0d-405d-b866-95289480761f, Action=None
# STEP:::PacakgeID=8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72, Action=None
# Package: 8a31ef19-cf44-4ff2-9813-4c2f4b7b1b72 processing...
# STEP:::PacakgeID=4d17cd12-56c7-43f5-9a35-5ceaf21173bb, Action=['c1', 'c4']
# Error! Undone package is neither on route or in node!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 14
#      12     print(f"------------------------------------------------------STEP{i}------------------------------------------------------")
#      13     actions = agent.choose_action()
# ---> 14     next_state, reward, done = env.step(actions)
#      15     print(f"Time tick: {env.TimeTick}, Total reward: {reward}")
#      17 # 检查所有包是否已到达目的地
#
# TypeError: cannot unpack non-iterable int object
