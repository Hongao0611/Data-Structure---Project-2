# %%
import data_gen
import uuid
import heapq

#generate stations, centers, packages.
data = data_gen.data_gen()
station_pos = data['station_pos']
station_prop = data['station_prop']
center_pos = data['center_pos']
center_prop = data['center_prop']
edges = data['edges']
packets = data['packets']

class Node:
    def __init__(self, id, pos, throughput, delay, cost, is_station=False):
        self.id = id
        self.pos = pos
        self.throughput = throughput
        self.delay = delay  # This delay should be updated based on the queue length and throughput
        self.cost = cost
        self.is_station = is_station
        self.packages = []  # Use a list for packages
        heapq.heapify(self.packages)  # Convert the list to a heap
        self.package_indices = {}  # 辅助字典用于快速查找包裹的索引

    def add_package(self, package):
        heapq.heappush(self.packages, (-package.delay, package))
        package.delay = self.delay
        self.package_indices[package.id] = len(self.packages) - 1  # 更新辅助字典
        print(f"Pack added to Node: {self.id};")

    def remove_package(self, package_id):
        if package_id in self.package_indices:
            index = self.package_indices.pop(package_id)
            # 直接移除指定索引的元素，并重新构建堆
            del self.packages[index]
            heapq.heapify(self.packages)
            self.package_indices = {pkg.id: i for i, (_, pkg) in enumerate(self.packages)}
            print(f"package: {package_id} removed from Node: {self.id}.")

    def __str__(self):
        # 获取所有包裹的 ID
        package_ids = [pkg.id for _, pkg in self.packages]
        # 将包裹 ID 转换为字符串并附加到节点信息中
        return f"Node({self.id}, {self.pos}, Throughput: {self.throughput}, Delay: {self.delay}, Cost: {self.cost}, Packages: {package_ids})"

class Route:
    def __init__(self, src, dst, time, cost):
        self.src = src
        self.dst = dst
        self.time = time
        self.cost = cost
        self.packages = []  # Use a list for packages on the route
        heapq.heapify(self.packages)  # Convert the list to a heap
        self.package_indices = {}  # 辅助字典用于快速查找包裹的索引

    def add_package(self, package):
        package.delay = self.time
        heapq.heappush(self.packages, (-package.delay, package))
        self.package_indices[package.id] = len(self.packages) - 1  # 更新辅助字典
        print(f"Pack added to Route: {self.src}->{self.dst};")

    def remove_package(self, package_id):
        if package_id in self.package_indices:
            index = self.package_indices.pop(package_id)
            # 直接移除指定索引的元素，并重新构建堆
            del self.packages[index]
            heapq.heapify(self.packages)
            self.package_indices = {pkg.id: i for i, (_, pkg) in enumerate(self.packages)}
            print(f"package: {package_id} removed from Route: {self.src}->{self.dst}.")

    def __str__(self):
        return f"Route({self.src}->{self.dst}, Time: {self.time}, Cost: {self.cost})"

class Package:
    def __init__(self, id, time_created, src, dst, category):
        self.id = id
        self.time_created = time_created
        self.src = src
        self.dst = dst
        self.curr = src
        self.category = category  # 'Express' or 'Standard'
        self.history = []  # List of nodes visited with timestamps
        self.path = []  # List of nodes on the expected path
        self.delay = 0  # Remaining delay before processing
        self.done = False
        self.reward = 0.0  # Current Reward/cost for this package

    def update_path(self, next_node):
        self.path.append(next_node)

    def mark_done(self):
        self.done = True

    def __lt__(self, other):
        # Ensure other is also a Package object
        if not isinstance(other, Package):
            return False

        # Define comparison for priority queue
        # Express packages have higher priority
        if self.category == 'Express' and other.category != 'Express':
            return True
        if self.category != 'Express' and other.category == 'Express':
            return False
        # Otherwise, compare based on time created
        return self.time_created < other.time_created

    def __eq__(self, other):
        # Ensure other is also a Package object
        if not isinstance(other, Package):
            return False

        # Define comparison for priority queue
        # Express packages have higher priority
        if self.category == 'Express' and other.category != 'Express':
            return True
        if self.category != 'Express' and other.category == 'Express':
            return False
        # Otherwise, compare based on time created
        return self.time_created == other.time_created

    def __str__(self):
        return f"Package({self.id}, TimeCreated: {self.time_created}, Src: {self.src}, Dst: {self.dst}, Category: {self.category})"

class LogisticsEnv:
    def __init__(self):
        self.nodes = {}  # Dictionary of nodes
        self.routes = {}  # Dictionary of routes
        self.packages = {}  # Dictionary of packages
        self.min_delay = float('inf')  # Minimum delay for all packages
        self.TimeTick = 0.0  # Current time tick
        self.done = False

    def reset(self):
        self.nodes = {}  # Dictionary of nodes
        self.routes = {}  # Dictionary of routes
        self.packages = {}  # Dictionary of packages

        # Initialize nodes, routes, and packages
        # Add stations as nodes
        for i in range(len(station_pos)):
            p = self.add_node(f"s{i}", station_pos[i], *station_prop[i], is_station=True)
            #print(f"Center({p.id}, {p.pos}, Throughput: {p.throughput}, Delay: {p.delay}, Cost: {p.cost}), is_station: {p.is_station}")

        # Add centers as nodes
        for i in range(len(center_pos)):
            p = self.add_node(f"c{i}", center_pos[i], *center_prop[i])
            #print(f"Center({p.id}, {p.pos}, Throughput: {p.throughput}, Delay: {p.delay}, Cost: {p.cost}), is_station: {p.is_station}")

        # Add edges as routes
        for edge in edges:
            p = self.add_route(edge[0], edge[1], edge[2], edge[3])
            #print(f"Route({p.src}->{p.dst}, Time: {p.time}, Cost: {p.cost})")

        # Add packets as packages
        for packet in packets:
            p = self.add_package(uuid.uuid4(), *packet)
            print(f"Package {p.id} added, delay={p.delay}, src={p.src}, curr={p.curr}, dst={p.dst}, done={p.done}, path={p.path}")
        
        for package in self.packages.values():
            self.min_delay = package.delay if self.min_delay>package.delay and package.delay>0 else self.min_delay
        for node in self.nodes.values():
            print(node)
        self.TimeTick = 0.0  # Current time tick
        print(f"Env reset. min_delay={self.min_delay}, TimeTick={self.TimeTick}")

        return self.get_state()

    def add_node(self, id, pos, throughput, delay, cost, is_station=False):
        self.nodes[id] = Node(id, pos, throughput, delay, cost, is_station)
        return self.nodes[id]

    def add_route(self, src, dst, time, cost):
        self.routes[(src, dst)] = Route(src, dst, time, cost)
        return self.routes[(src, dst)]

    def add_package(self, id, time_created, src, dst, category):
        package = Package(id, time_created, src, dst, category)
        
        # Calculate the initial optimal路径 based on the package's category
        if category == 'Express':
            # 对于Express包裹，找到最短的总时间路径
            optimal_path = self.find_shortest_time_path(src, dst)
        else:
            # 对于Standard包裹，找到最低的总成本路径
            optimal_path = self.find_lowest_cost_path(src, dst)
        
        package.path = optimal_path  # 将最优路径初始化为包裹的路径
        self.packages[id] = package
        self.nodes[src].add_package(package)  # 添加到优先队列中
        return package

    def find_shortest_time_path(self, src, dst):
        # Initialize distances and visited nodes
        distances = {node: float('inf') for node in self.nodes}  # Use a very large number instead of infinity
        distances[src] = 0
        visited = set()

        # Initialize priority queue with the source node
        pq = [(0, src, 0)]  # (distance, current_node, total_time)

        while pq:
            current_distance, current_node, current_time = heapq.heappop(pq)

            # If the node has already been visited, skip it
            if current_node in visited:
                continue

            visited.add(current_node)

            # Check neighbors of the current node
            for route in self.routes.values():
                if route.src == current_node and route.dst not in visited:
                    # Calculate the new distance and time
                    new_distance = current_distance + route.time
                    new_time = current_time + route.time + self.nodes[current_node].delay

                    # If this is a shorter path, update the distances and add to the priority queue
                    if new_distance < distances[route.dst]:
                        distances[route.dst] = new_distance
                        heapq.heappush(pq, (new_distance, route.dst, new_time))

        # Construct the path from the source to the destination
        path = []
        current_node = dst
        while current_node != src:
            path.append(current_node)
            # 选择下一个节点，不检查是否已经在路径中
            # 使用 self.routes 来获取当前节点的实际对象
            current_node = min(
                [route.dst for route in self.routes.values() if route.src == current_node],
                key=lambda x: distances[x],
                default=None
            )
            if current_node is None:
                # No path found
                return []
        path.append(src)
        path.reverse()

        return path
    
    def find_lowest_cost_path(self, src, dst):
        # Initialize distances and visited nodes
        distances = {node: float('infinity') for node in self.nodes}
        distances[src] = 0
        visited = set()

        # Initialize priority queue with the source node
        pq = [(0, src)]  # (distance, current_node)

        while pq:
            current_distance, current_node = heapq.heappop(pq)

            # If the node has already been visited, skip it
            if current_node in visited:
                continue

            visited.add(current_node)

            # Check neighbors of the current node
            for route in self.routes.values():
                if route.src == current_node and route.dst not in visited:
                    # Calculate the new distance
                    new_distance = current_distance + route.cost + self.nodes[current_node].cost

                    # If this is a lower distance, update the distances and add to the priority queue
                    if new_distance < distances[route.dst]:
                        distances[route.dst] = new_distance
                        heapq.heappush(pq, (new_distance, route.dst))

        # Construct the path from the source to the destination
        path = []
        current_node = dst
        while current_node != src:
            path.append(current_node)
            # 选择下一个节点，使用 (current_node, neighbor) 来检查路由是否存在
            previous_node = min(
                [route.dst for route in self.routes.values() if route.src == current_node],
                key=lambda x: distances[x],
                default=None
            )
            if previous_node is None:
                # No path found
                return []
            current_node = previous_node

        path.append(src)
        path.reverse()

        return path

    def get_policy(self, package):
        if package.category == 'Express':
            # For Express packages, find the shortest total time path
            return self.find_shortest_time_path(package.curr, package.dst)
        else:
            # For Standard packages, find the lowest total cost path
            return self.find_lowest_cost_path(package.curr, package.dst)

    def step(self, actions):
        self.TimeTick += self.min_delay  # 更新时间
        # 更新所有包裹的延迟
        for package in self.packages.values():
            package.delay -= self.min_delay
        # 遍历所有动作
        for package_id, action in actions.items():
            print(f"STEP:::PacakgeID={package_id}, Action={action}")
            package = self.packages[package_id]  # 使用 package_id 获取包裹
            if package.done:
                package.reward = 0
                continue
            elif package.delay <= 0:  # 包裹准备好转移状态
                if action is not None:
                    node = self.nodes[action[0]]
                    next_node = self.nodes[action[1]]
                    route = self.routes[(action[0], action[1])]
                    if package_id in node.package_indices:  # 包裹位于Node
                        print(f"is in Node: {node.id},")
                        node.remove_package(package_id)
                        route.add_package(package)
                        # 更新包裹的历史、当前所在的节点
                        package.history.append((self.TimeTick, package.curr))
                        package.curr = node.id
                        # 计算包裹的reward
                        if package.category == 'Express':
                            package.reward -= self.min_delay
                        else:
                            package.reward -= node.cost
                    elif package_id in route.package_indices:  # 包裹位于Route TODO debug, it is likely to occur here!!! Check if the package at the end of the Route will be correctly updated to the next node.
                        print(f"is on Route: {route.src}->{route.dst},")
                        if len(node.packages) < node.throughput:
                            route.remove_package(package_id)
                            next_node.add_package(package)
                            # 更新包裹的历史、Route起点的节点
                            package.history.append((self.TimeTick, package.curr))
                            package.curr = next_node.id
                            # 计算包裹的reward
                            if package.category == 'Express':
                                package.reward -= self.min_delay
                            else:
                                package.reward -= route.cost
                        else: # 包裹滞留在当前Route无法进站
                            print(f"waiting..., Node: {route.dst} full")
                            if package.category == 'Express':
                                package.reward -= self.min_delay
                    else:
                        print("Error! Undone package is neither on route or in node!")
                        return 0
                else:  # 包裹准备好转移状态，但动作是None
                    print(f"This should not happen! Package: {package_id} is ready but action is None.")
                    if package.category == 'Express':
                        package.reward -= self.min_delay
            else:
                print(f"Package: {package_id} processing...")
                # package正在Route或者Node中处理
                if package.category == 'Express':
                    package.reward -= self.min_delay
        #判断是否有新的package变成done,顺便计算当前的reward,顺便判断是否done
        self.done = True
        curr_reward = 0
        self.min_delay = float('inf')
        for package in self.packages.values():
            if not package.done: #对于之前没有done的package
                curr_reward +=package.reward #累加reward
                if package.curr == package.dst: #该节点是否刚到done
                    package.history.append((self.TimeTick, package.curr))
                    next_node.remove_package(package_id)
                    package.done = True
                    package.delay = float('inf')
                else:
                    self.done = False #如果还有undone package，那么整个环境就没有done
                    #print(f"undone package {package.id} at {package.curr} has delay: {package.delay}")
                    self.min_delay = package.delay if package.delay>0 and (package.delay < self.min_delay) else self.min_delay
        print(f"the new min_delay: {self.min_delay}")
        return self.get_state(), curr_reward, self.done

    def get_reward(self, package):
        # Calculate the reward based on package category and time passed
        if package.category == 'Express':
            reward = package.time_created - self.TimeTick #TODO re-scale the reward to be compatible with the route cost
        else:
            # Calculate the cost based on package history and node/route costs
            total_cost = 0
            for timestamp,node_id in package.history:
                total_cost += self.nodes[node_id].cost
            for route in package.path:
                total_cost += self.routes[route].cost
            reward = -total_cost  # Negative cost as a reward for minimizing costs

        # If the package has reached its destination, update its delay to zero and mark it as done
        if package.src == package.dst:
            package.delay = 0
            package.mark_done()

        return reward
    
    def get_state(self):
        # Create a state representation that includes relevant information for decision-making
        state = {
            'package_positions': self.get_package_positions(),
            'package_destinations': self.get_package_destinations(),
            'package_categories': self.get_package_categories(),
            'queue_lengths': self.get_queue_lengths(),
            'route_loads': self.get_route_loads(),
            'current_time_tick': self.TimeTick
        }
        return state

    def get_package_positions(self):
        # Return a dictionary with package IDs as keys and their current node IDs as values
        positions = {pkg_id: pkg.src for pkg_id, pkg in self.packages.items()}
        return positions

    def get_package_destinations(self):
        # Return a dictionary with package IDs as keys and their destination node IDs as values
        destinations = {pkg_id: pkg.dst for pkg_id, pkg in self.packages.items()}
        return destinations

    def get_package_categories(self):
        # Return a dictionary with package IDs as keys and their categories as values
        categories = {pkg_id: pkg.category for pkg_id, pkg in self.packages.items()}
        return categories

    def get_queue_lengths(self):
        # Return a dictionary with node IDs as keys and the number of packages in their queues as values
        queue_lengths = {node_id: len(node.packages) for node_id, node in self.nodes.items()}
        return queue_lengths

    def get_route_loads(self):
        # Return a dictionary with route tuples (src, dst) as keys and the number of packages on the route as values
        route_loads = {route_tuple: len(route.packages) for route_tuple, route in self.routes.items()}
        return route_loads

class Agent:
    def __init__(self, env):
        self.env = env
        self.state = None
        self.total_reward = 0.0
        self.action_history = []

    def reset(self):
        self.state = None
        self.total_reward = 0.0
        self.action_history = []

    def choose_action(self):
        actions = {}
        for package_id, package in self.env.packages.items():
            if package.delay > self.env.min_delay:
                # If the package's delay is positive, do nothing
                actions[package_id] = None
            else:
                # Call the get_policy method to get the next node in the optimal path
                next_node = self.env.get_policy(package)
                # Select the neighboring node to be the destination
                if next_node and next_node != package.src and next_node != package.dst:
                    actions[package_id] = next_node[:2]
                else:
                    actions[package_id] = None  # No valid action found
            #print(f"action for {package_id} is {actions[package_id]}.")
        return actions
# Out:
# Stations:
# s0 (57, 19) (10, 2, 0.5)
# s1 (67, 48) (15, 2, 0.6)
# s2 (93, 54) (20, 1, 0.8)
# s3 (21, 7) (10, 2, 0.5)
# s4 (25, 17) (10, 2, 0.5)
# s5 (88, 70) (10, 2, 0.5)
# s6 (47, 54) (20, 1, 0.8)
# s7 (47, 93) (25, 1, 0.9)
# s8 (93, 55) (25, 1, 0.9)
# s9 (64, 34) (10, 2, 0.5)
# s10 (81, 49) (15, 2, 0.6)
# s11 (28, 22) (25, 1, 0.9)
# s12 (4, 70) (10, 2, 0.5)
# s13 (4, 69) (10, 2, 0.5)
# s14 (35, 20) (15, 2, 0.6)
# s15 (84, 3) (15, 2, 0.6)
# s16 (27, 49) (25, 1, 0.9)
# s17 (94, 40) (25, 1, 0.9)
# s18 (8, 55) (10, 2, 0.5)
# s19 (51, 43) (20, 1, 0.8)
# s20 (25, 31) (25, 1, 0.9)
# s21 (98, 74) (10, 2, 0.5)
# s22 (75, 19) (10, 2, 0.5)
# s23 (64, 60) (20, 1, 0.8)
# s24 (16, 50) (15, 2, 0.6)
# Warning: Center moved
# Centers:
# c0 (91, 57) (175, 1, 0.5)
# c1 (26, 19) (150, 2, 0.5)
# c2 (11, 58) (150, 2, 0.5)
# c3 (63, 35) (150, 2, 0.5)
# c4 (48, 94) (125, 1, 0.5)
# Edges (center to center):
# ('c0', 'c1', 18.823190484081067, 15.058552387264854)
# ('c1', 'c0', 18.823190484081067, 15.058552387264854)
# ('c0', 'c2', 20.00156243896961, 16.00124995117569)
# ('c2', 'c0', 20.00156243896961, 16.00124995117569)
# ('c0', 'c3', 8.902246907382429, 7.121797525905944)
# ('c3', 'c0', 8.902246907382429, 7.121797525905944)
# ('c0', 'c4', 14.181854603682835, 11.345483682946268)
# ('c4', 'c0', 14.181854603682835, 11.345483682946268)
# ('c1', 'c2', 10.44629120788809, 8.357032966310472)
# ('c2', 'c1', 10.44629120788809, 8.357032966310472)
# ('c1', 'c3', 10.077822185373186, 8.06225774829855)
# ('c3', 'c1', 10.077822185373186, 8.06225774829855)
# ('c1', 'c4', 19.540023029669133, 15.632018423735307)
# ('c4', 'c1', 19.540023029669133, 15.632018423735307)
# ('c2', 'c3', 14.2148689758295, 11.3718951806636)
# ('c3', 'c2', 14.2148689758295, 11.3718951806636)
# ('c2', 'c4', 12.905909499140307, 10.324727599312247)
# ('c4', 'c2', 12.905909499140307, 10.324727599312247)
# ('c3', 'c4', 15.219231255224424, 12.175385004179539)
# ('c4', 'c3', 15.219231255224424, 12.175385004179539)
# Edges (center to station):
# ('c0', 's2', 2.1633307652783933, 0.4326661530556787)
# ('s2', 'c0', 2.1633307652783933, 0.4326661530556787)
# ('c0', 's5', 8.0049984384758, 1.60099968769516)
# ('s5', 'c0', 8.0049984384758, 1.60099968769516)
# ('c0', 's8', 1.697056274847714, 0.33941125496954283)
# ('s8', 'c0', 1.697056274847714, 0.33941125496954283)
# ('c0', 's10', 7.683749084919418, 1.5367498169838836)
# ('s10', 'c0', 7.683749084919418, 1.5367498169838836)
# ('c0', 's17', 10.357605900979241, 2.071521180195848)
# ('s17', 'c0', 10.357605900979241, 2.071521180195848)
# ('c0', 's21', 11.030865786510141, 2.206173157302028)
# ('s21', 'c0', 11.030865786510141, 2.206173157302028)
# ('c1', 's3', 7.8, 1.56)
# ('s3', 'c1', 7.8, 1.56)
# ('c1', 's4', 1.3416407864998738, 0.2683281572999748)
# ('s4', 'c1', 1.3416407864998738, 0.2683281572999748)
# ('c1', 's11', 2.1633307652783933, 0.4326661530556787)
# ('s11', 'c1', 2.1633307652783933, 0.4326661530556787)
# ('c1', 's14', 5.43323108288245, 1.08664621657649)
# ('s14', 'c1', 5.43323108288245, 1.08664621657649)
# ('c1', 's20', 7.224956747275377, 1.4449913494550755)
# ('s20', 'c1', 7.224956747275377, 1.4449913494550755)
# ('c2', 's12', 8.335466393669883, 1.6670932787339765)
# ('s12', 'c2', 8.335466393669883, 1.6670932787339765)
# ('c2', 's13', 7.8230428862431785, 1.5646085772486358)
# ('s13', 'c2', 7.8230428862431785, 1.5646085772486358)
# ('c2', 's16', 11.014535850411491, 2.202907170082298)
# ('s16', 'c2', 11.014535850411491, 2.202907170082298)
# ('c2', 's18', 2.545584412271571, 0.5091168824543142)
# ('s18', 'c2', 2.545584412271571, 0.5091168824543142)
# ('c2', 's24', 5.660388679233962, 1.1320777358467924)
# ('s24', 'c2', 5.660388679233962, 1.1320777358467924)
# ('c3', 's0', 10.252804494381037, 2.050560898876207)
# ('s0', 'c3', 10.252804494381037, 2.050560898876207)
# ('c3', 's1', 8.160882305241266, 1.6321764610482532)
# ('s1', 'c3', 8.160882305241266, 1.6321764610482532)
# ('c3', 's6', 14.903690818049064, 2.980738163609813)
# ('s6', 'c3', 14.903690818049064, 2.980738163609813)
# ('c3', 's9', 0.848528137423857, 0.16970562748477142)
# ('s9', 'c3', 0.848528137423857, 0.16970562748477142)
# ('c3', 's15', 22.965191050805565, 4.593038210161113)
# ('s15', 'c3', 22.965191050805565, 4.593038210161113)
# ('c3', 's19', 8.653323061113573, 1.7306646122227147)
# ('s19', 'c3', 8.653323061113573, 1.7306646122227147)
# ('c3', 's22', 12.0, 2.4)
# ('s22', 'c3', 12.0, 2.4)
# ('c3', 's23', 15.011995203836165, 3.0023990407672327)
# ('s23', 'c3', 15.011995203836165, 3.0023990407672327)
# ('c4', 's7', 0.848528137423857, 0.16970562748477142)
# ('s7', 'c4', 0.848528137423857, 0.16970562748477142)
# Edges (station to station):
# ('s2', 's1', 21.346662502602136, 1.867832968977687)
# ('s1', 's2', 21.346662502602136, 1.867832968977687)
# ('s4', 's3', 8.616263691415206, 0.7539230729988305)
# ('s3', 's4', 8.616263691415206, 0.7539230729988305)
# ('s5', 's2', 13.41044369139217, 1.173413822996815)
# ('s2', 's5', 13.41044369139217, 1.173413822996815)
# ('s6', 's1', 16.70449041425688, 1.4616429112474771)
# ('s1', 's6', 16.70449041425688, 1.4616429112474771)
# ('s8', 's1', 21.54065922853802, 1.8848076824970765)
# ('s1', 's8', 21.54065922853802, 1.8848076824970765)
# ('s8', 's2', 0.8, 0.07)
# ('s2', 's8', 0.8, 0.07)
# ('s8', 's5', 12.649110640673518, 1.1067971810589328)
# ('s5', 's8', 12.649110640673518, 1.1067971810589328)
# ('s9', 's0', 13.242356285797479, 1.1587061750072796)
# ('s0', 's9', 13.242356285797479, 1.1587061750072796)
# ('s9', 's1', 11.454256850621084, 1.0022474744293448)
# ('s1', 's9', 11.454256850621084, 1.0022474744293448)
# ('s9', 's6', 20.9990475974507, 1.8374166647769365)
# ('s6', 's9', 20.9990475974507, 1.8374166647769365)
# ('s10', 's1', 11.22853507809456, 0.982496819333274)
# ('s1', 's10', 11.22853507809456, 0.982496819333274)
# ('s10', 's2', 10.4, 0.9100000000000001)
# ('s2', 's10', 10.4, 0.9100000000000001)
# ('s10', 's5', 17.708754896942924, 1.5495160534825059)
# ('s5', 's10', 17.708754896942924, 1.5495160534825059)
# ('s10', 's8', 10.733126291998992, 0.9391485505499118)
# ('s8', 's10', 10.733126291998992, 0.9391485505499118)
# ('s10', 's9', 18.137254478007417, 1.5870097668256489)
# ('s9', 's10', 18.137254478007417, 1.5870097668256489)
# ('s11', 's0', 23.323807579381203, 2.040833163195855)
# ('s0', 's11', 23.323807579381203, 2.040833163195855)
# ('s11', 's3', 13.242356285797479, 1.1587061750072796)
# ('s3', 's11', 13.242356285797479, 1.1587061750072796)
# ('s11', 's4', 4.664761515876241, 0.4081666326391711)
# ('s4', 's11', 4.664761515876241, 0.4081666326391711)
# ('s13', 's12', 0.8, 0.07)
# ('s12', 's13', 0.8, 0.07)
# ('s14', 's0', 17.618172436436193, 1.5415900881881668)
# ('s0', 's14', 17.618172436436193, 1.5415900881881668)
# ('s14', 's3', 15.28397853963424, 1.3373481222179961)
# ('s3', 's14', 15.28397853963424, 1.3373481222179961)
# ('s14', 's4', 8.35224520712844, 0.7308214556237386)
# ('s4', 's14', 8.35224520712844, 0.7308214556237386)
# ('s14', 's11', 5.824087911424415, 0.5096076922496363)
# ('s11', 's14', 5.824087911424415, 0.5096076922496363)
# ('s16', 's6', 16.492422502470642, 1.4430869689661814)
# ('s6', 's16', 16.492422502470642, 1.4430869689661814)
# ('s16', 's11', 21.614809737770074, 1.8912958520548817)
# ('s11', 's16', 21.614809737770074, 1.8912958520548817)
# ('s17', 's1', 22.52820454452596, 1.9712178976460215)
# ('s1', 's17', 22.52820454452596, 1.9712178976460215)
# ('s17', 's2', 11.22853507809456, 0.982496819333274)
# ('s2', 's17', 11.22853507809456, 0.982496819333274)
# ('s17', 's8', 12.026637102698327, 1.0523307464861036)
# ('s8', 's17', 12.026637102698327, 1.0523307464861036)
# ('s17', 's10', 12.649110640673518, 1.1067971810589328)
# ('s10', 's17', 12.649110640673518, 1.1067971810589328)
# ('s18', 's12', 12.41933975700802, 1.0866922287382017)
# ('s12', 's18', 12.41933975700802, 1.0866922287382017)
# ('s18', 's13', 11.64817582284883, 1.0192153844992726)
# ('s13', 's18', 11.64817582284883, 1.0192153844992726)
# ('s18', 's16', 15.93988707613702, 1.3947401191619895)
# ('s16', 's18', 15.93988707613702, 1.3947401191619895)
# ('s19', 's0', 19.790907002964772, 1.7317043627594175)
# ('s0', 's19', 19.790907002964772, 1.7317043627594175)
# ('s19', 's1', 13.41044369139217, 1.173413822996815)
# ('s1', 's19', 13.41044369139217, 1.173413822996815)
# ('s19', 's6', 9.363759928575702, 0.8193289937503738)
# ('s6', 's19', 9.363759928575702, 0.8193289937503738)
# ('s19', 's9', 12.649110640673518, 1.1067971810589328)
# ('s9', 's19', 12.649110640673518, 1.1067971810589328)
# ('s19', 's14', 22.414281161795042, 1.9612496016570662)
# ('s14', 's19', 22.414281161795042, 1.9612496016570662)
# ('s19', 's16', 19.790907002964772, 1.7317043627594175)
# ('s16', 's19', 19.790907002964772, 1.7317043627594175)
# ('s20', 's3', 19.464840096954305, 1.7031735084835016)
# ('s3', 's20', 19.464840096954305, 1.7031735084835016)
# ('s20', 's4', 11.200000000000001, 0.9800000000000001)
# ('s4', 's20', 11.200000000000001, 0.9800000000000001)
# ('s20', 's11', 7.589466384404111, 0.6640783086353598)
# ('s11', 's20', 7.589466384404111, 0.6640783086353598)
# ('s20', 's14', 11.892854997854805, 1.0406248123122954)
# ('s14', 's20', 11.892854997854805, 1.0406248123122954)
# ('s20', 's16', 14.488616221019868, 1.2677539193392386)
# ('s16', 's20', 14.488616221019868, 1.2677539193392386)
# ('s20', 's18', 23.528705871764387, 2.0587617637793842)
# ('s18', 's20', 23.528705871764387, 2.0587617637793842)
# ('s20', 's19', 22.908513701242168, 2.0044949488586896)
# ('s19', 's20', 22.908513701242168, 2.0044949488586896)
# ('s21', 's2', 16.492422502470642, 1.4430869689661814)
# ('s2', 's21', 16.492422502470642, 1.4430869689661814)
# ('s21', 's5', 8.616263691415206, 0.7539230729988305)
# ('s5', 's21', 8.616263691415206, 0.7539230729988305)
# ('s21', 's8', 15.7175061635108, 1.3752817893071951)
# ('s8', 's21', 15.7175061635108, 1.3752817893071951)
# ('s22', 's0', 14.4, 1.2600000000000002)
# ('s0', 's22', 14.4, 1.2600000000000002)
# ('s22', 's9', 14.88086019019062, 1.3020752666416793)
# ('s9', 's22', 14.88086019019062, 1.3020752666416793)
# ('s22', 's15', 14.686047800548657, 1.2850291825480076)
# ('s15', 's22', 14.686047800548657, 1.2850291825480076)
# ('s22', 's17', 22.655683613610076, 1.9823723161908817)
# ('s17', 's22', 22.655683613610076, 1.9823723161908817)
# ('s23', 's1', 9.895453501482386, 0.8658521813797088)
# ('s1', 's23', 9.895453501482386, 0.8658521813797088)
# ('s23', 's2', 23.69134863193736, 2.072993005294519)
# ('s2', 's23', 23.69134863193736, 2.072993005294519)
# ('s23', 's5', 20.8, 1.8200000000000003)
# ('s5', 's23', 20.8, 1.8200000000000003)
# ('s23', 's6', 14.422205101855958, 1.2619429464123963)
# ('s6', 's23', 14.422205101855958, 1.2619429464123963)
# ('s23', 's8', 23.54230235129946, 2.0599514557387026)
# ('s8', 's23', 23.54230235129946, 2.0599514557387026)
# ('s23', 's9', 20.8, 1.8200000000000003)
# ('s9', 's23', 20.8, 1.8200000000000003)
# ('s23', 's10', 16.19876538505327, 1.4173919711921612)
# ('s10', 's23', 16.19876538505327, 1.4173919711921612)
# ('s23', 's19', 17.120747647226157, 1.4980654191322889)
# ('s19', 's23', 17.120747647226157, 1.4980654191322889)
# ('s24', 's12', 18.659046063504963, 1.6326665305566843)
# ('s12', 's24', 18.659046063504963, 1.6326665305566843)
# ('s24', 's13', 17.977764043395386, 1.5730543537970962)
# ('s13', 's24', 17.977764043395386, 1.5730543537970962)
# ('s24', 's16', 8.836288813749809, 0.7731752712031084)
# ('s16', 's24', 8.836288813749809, 0.7731752712031084)
# ('s24', 's18', 7.547184905645283, 0.6603786792439623)
# ('s18', 's24', 7.547184905645283, 0.6603786792439623)
# ('s24', 's20', 16.819036833302913, 1.4716657229140049)
# ('s20', 's24', 16.819036833302913, 1.4716657229140049)
# Packets:
# debdfe4c-683a-4b8e-8e05-dce6de9e328d (0.15464734002478053, 's17', 's19', 1)
# e2fabb93-182b-482d-af43-5dd21c20b06c (0.18649643377728298, 's8', 's17', 0)
# 67dc56b5-7f46-4253-9974-eb7b07291f3c (2.3865917347533645, 's17', 's11', 0)
# 86b40b00-5d6c-4ff3-b9a9-79ecf0c25dbc (3.0485138374258005, 's19', 's1', 1)
# 9961b0cb-2a08-46de-882b-5471a9b33203 (3.6511648939615986, 's9', 's4', 0)
# d44f7ce5-ca5c-4816-b898-4d3000ac5ccd (4.67903492768016, 's0', 's6', 1)
# d47b465c-d914-421b-90d6-8783034005b7 (6.279419546160762, 's3', 's24', 0)
# 6392f4d0-08dd-462a-8759-5418e7cdb404 (6.365433126232855, 's17', 's0', 1)
# 452c52e0-cad5-49b8-aadd-fb7bd1e8e4ab (7.1116292647900305, 's8', 's19', 0)
# 87b06a83-a0e0-4548-a86c-5a66cfd94554 (7.977225319008751, 's0', 's24', 1)
# 484c763b-b156-4a5f-832b-03c4cac8518f (8.265802385639898, 's6', 's20', 0)
# e1fa89de-9a21-4b97-820b-77f7c65668ed (8.610620583921468, 's18', 's21', 0)
# 2c7b7e92-ea6b-4947-9341-088f14ec1ab9 (8.900892514638684, 's6', 's0', 1)
# 7fc922de-93bc-4d53-9505-cc31fc9e44d9 (8.964265714067613, 's11', 's4', 0)
# be828824-d5b5-415b-bcc8-8120d0acb237 (9.092064628740332, 's6', 's10', 0)
# 757b0111-cfdc-4497-ba94-ac7856625a2b (9.159679416601882, 's6', 's14', 0)
# f23b398d-c4ec-4150-b1c8-f4c75eac9c96 (10.395006524894745, 's5', 's20', 1)
# 8a302b07-eb96-4df1-af60-3c145ddeb2f3 (10.873498067088546, 's24', 's0', 0)
# b1305cea-d081-4474-8a4a-576770ad2bf8 (11.286229884650712, 's6', 's22', 0)
# 0e62604c-6bf8-4ea7-8095-6bb2022c9f57 (11.417146766063194, 's19', 's21', 0)

# %%
env = LogisticsEnv()
state = env.reset()

# 创建代理
agent = Agent(env)

# 模拟几个时间步
i=0
done = False
while (not done):
    i+=1
    print(f"------------------------------------------------------STEP{i}------------------------------------------------------")
    actions = agent.choose_action()
    next_state, reward, done = env.step(actions)
    print(f"Time tick: {env.TimeTick}, Total reward: {reward}")

# 检查所有包是否已到达目的地
for package_id in env.packages:
    package = env.packages[package_id]
    if not package.done:
        print(f"Package {package_id} did not reach the destination.")
        break
else:
    print("All packages have reached the destination.")
# Out:
# Pack added to Node: s17;
# Package bbcc44cf-788d-459a-be0f-c840ff47189f added, delay=1, src=s17, curr=s17, dst=s19, done=False, path=['s17', 's1', 's19']
# Pack added to Node: s8;
# Package 7bf5d7dc-0961-4512-8d03-26f841401c81 added, delay=1, src=s8, curr=s8, dst=s17, done=False, path=['s8', 's17']
# Pack added to Node: s17;
# Package d23ec060-6535-4b38-8955-244434fe5d0f added, delay=1, src=s17, curr=s17, dst=s11, done=False, path=['s17', 's22', 's0', 's11']
# Pack added to Node: s19;
# Package 47206f87-02d3-4f53-92d4-45ad0f509eee added, delay=1, src=s19, curr=s19, dst=s1, done=False, path=['s19', 's1']
# Pack added to Node: s9;
# Package 0adfd765-393a-4a95-bd63-3893be5f26d0 added, delay=2, src=s9, curr=s9, dst=s4, done=False, path=['s9', 's19', 's14', 's4']
# Pack added to Node: s0;
# Package 933fa08f-98fb-4aa0-8d78-5cd3743bcb0c added, delay=2, src=s0, curr=s0, dst=s6, done=False, path=['s0', 's9', 's6']
# Pack added to Node: s3;
# Package 0385285b-1560-417d-93b2-b92932d79de7 added, delay=2, src=s3, curr=s3, dst=s24, done=False, path=['s3', 's20', 's24']
# Pack added to Node: s17;
# Package 742c697b-78b7-43ce-ab28-265e0aeb92fc added, delay=1, src=s17, curr=s17, dst=s0, done=False, path=['s17', 's22', 's0']
# Pack added to Node: s8;
# Package 45cef0ff-744f-4f62-81a8-d0103cae2869 added, delay=1, src=s8, curr=s8, dst=s19, done=False, path=['s8', 's1', 's19']
# Pack added to Node: s0;
# Package a422c0f6-876f-418d-b0a8-34841b266f2b added, delay=2, src=s0, curr=s0, dst=s24, done=False, path=['s0', 's14', 's20', 's24']
# Pack added to Node: s6;
# Package e14ad120-3c24-40de-a638-70af1e45e1aa added, delay=1, src=s6, curr=s6, dst=s20, done=False, path=['s6', 's19', 's20']
# Pack added to Node: s18;
# Package 74813b16-d1e9-4e94-b78a-983459689fdc added, delay=2, src=s18, curr=s18, dst=s21, done=False, path=['s18', 's16', 's6', 's23', 's5', 's21']
# Pack added to Node: s6;
# Package e3ef1fcf-23a3-45c6-8747-00d4e4854038 added, delay=1, src=s6, curr=s6, dst=s0, done=False, path=['s6', 's19', 's0']
# Pack added to Node: s11;
# Package bf1ac37b-ac08-4e64-b170-e3c0c27796c2 added, delay=1, src=s11, curr=s11, dst=s4, done=False, path=['s11', 's4']
# Pack added to Node: s6;
# Package 6703e9f2-d791-48a1-81f8-000ae95ec082 added, delay=1, src=s6, curr=s6, dst=s10, done=False, path=['s6', 's23', 's10']
# Pack added to Node: s6;
# Package 75ff6610-e7e8-4a41-8882-a1bd81b525b3 added, delay=1, src=s6, curr=s6, dst=s14, done=False, path=['s6', 's19', 's14']
# Pack added to Node: s5;
# Package e36514c4-24ae-41e8-9c71-57bc074d05fb added, delay=2, src=s5, curr=s5, dst=s20, done=False, path=['s5', 's23', 's19', 's20']
# Pack added to Node: s24;
# Package 6dc9e950-9189-4a9b-9ba2-4fb879e3995c added, delay=2, src=s24, curr=s24, dst=s0, done=False, path=['s24', 's16', 's11', 's0']
# Pack added to Node: s6;
# Package 27664dcb-051a-4bfb-9261-ae3c68341b46 added, delay=1, src=s6, curr=s6, dst=s22, done=False, path=['s6', 's9', 's22']
# Pack added to Node: s19;
# Package 28ffe2fb-320a-4779-b105-d72cf6b546e5 added, delay=1, src=s19, curr=s19, dst=s21, done=False, path=['s19', 's1', 's2', 's21']
# Node(s0, (57, 19), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [UUID('933fa08f-98fb-4aa0-8d78-5cd3743bcb0c'), UUID('a422c0f6-876f-418d-b0a8-34841b266f2b')])
# Node(s1, (67, 48), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [])
# Node(s2, (93, 54), Throughput: 20, Delay: 1, Cost: 0.8, Packages: [])
# Node(s3, (21, 7), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [UUID('0385285b-1560-417d-93b2-b92932d79de7')])
# Node(s4, (25, 17), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [])
# Node(s5, (88, 70), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [UUID('e36514c4-24ae-41e8-9c71-57bc074d05fb')])
# Node(s6, (47, 54), Throughput: 20, Delay: 1, Cost: 0.8, Packages: [UUID('e14ad120-3c24-40de-a638-70af1e45e1aa'), UUID('e3ef1fcf-23a3-45c6-8747-00d4e4854038'), UUID('6703e9f2-d791-48a1-81f8-000ae95ec082'), UUID('75ff6610-e7e8-4a41-8882-a1bd81b525b3'), UUID('27664dcb-051a-4bfb-9261-ae3c68341b46')])
# Node(s7, (47, 93), Throughput: 25, Delay: 1, Cost: 0.9, Packages: [])
# Node(s8, (93, 55), Throughput: 25, Delay: 1, Cost: 0.9, Packages: [UUID('7bf5d7dc-0961-4512-8d03-26f841401c81'), UUID('45cef0ff-744f-4f62-81a8-d0103cae2869')])
# Node(s9, (64, 34), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [UUID('0adfd765-393a-4a95-bd63-3893be5f26d0')])
# Node(s10, (81, 49), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [])
# Node(s11, (28, 22), Throughput: 25, Delay: 1, Cost: 0.9, Packages: [UUID('bf1ac37b-ac08-4e64-b170-e3c0c27796c2')])
# Node(s12, (4, 70), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [])
# Node(s13, (4, 69), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [])
# Node(s14, (35, 20), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [])
# Node(s15, (84, 3), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [])
# Node(s16, (27, 49), Throughput: 25, Delay: 1, Cost: 0.9, Packages: [])
# Node(s17, (94, 40), Throughput: 25, Delay: 1, Cost: 0.9, Packages: [UUID('bbcc44cf-788d-459a-be0f-c840ff47189f'), UUID('d23ec060-6535-4b38-8955-244434fe5d0f'), UUID('742c697b-78b7-43ce-ab28-265e0aeb92fc')])
# Node(s18, (8, 55), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [UUID('74813b16-d1e9-4e94-b78a-983459689fdc')])
# Node(s19, (51, 43), Throughput: 20, Delay: 1, Cost: 0.8, Packages: [UUID('47206f87-02d3-4f53-92d4-45ad0f509eee'), UUID('28ffe2fb-320a-4779-b105-d72cf6b546e5')])
# Node(s20, (25, 31), Throughput: 25, Delay: 1, Cost: 0.9, Packages: [])
# Node(s21, (98, 74), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [])
# Node(s22, (75, 19), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [])
# Node(s23, (64, 60), Throughput: 20, Delay: 1, Cost: 0.8, Packages: [])
# Node(s24, (16, 50), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [UUID('6dc9e950-9189-4a9b-9ba2-4fb879e3995c')])
# Node(c0, (91, 57), Throughput: 175, Delay: 1, Cost: 0.5, Packages: [])
# Node(c1, (26, 19), Throughput: 150, Delay: 2, Cost: 0.5, Packages: [])
# Node(c2, (11, 58), Throughput: 150, Delay: 2, Cost: 0.5, Packages: [])
# Node(c3, (63, 35), Throughput: 150, Delay: 2, Cost: 0.5, Packages: [])
# Node(c4, (48, 94), Throughput: 125, Delay: 1, Cost: 0.5, Packages: [])
# Env reset. min_delay=1, TimeTick=0.0
# ------------------------------------------------------STEP1------------------------------------------------------
# STEP:::PacakgeID=bbcc44cf-788d-459a-be0f-c840ff47189f, Action=['s17', 's1']
# is in Node: s17,
# package: bbcc44cf-788d-459a-be0f-c840ff47189f removed from Node: s17.
# Pack added to Route: s17->s1;
# STEP:::PacakgeID=7bf5d7dc-0961-4512-8d03-26f841401c81, Action=['s8', 's17']
# is in Node: s8,
# package: 7bf5d7dc-0961-4512-8d03-26f841401c81 removed from Node: s8.
# Pack added to Route: s8->s17;
# STEP:::PacakgeID=d23ec060-6535-4b38-8955-244434fe5d0f, Action=['s17', 's22']
# is in Node: s17,
# package: d23ec060-6535-4b38-8955-244434fe5d0f removed from Node: s17.
# Pack added to Route: s17->s22;
# STEP:::PacakgeID=47206f87-02d3-4f53-92d4-45ad0f509eee, Action=['s19', 's1']
# is in Node: s19,
# package: 47206f87-02d3-4f53-92d4-45ad0f509eee removed from Node: s19.
# Pack added to Route: s19->s1;
# STEP:::PacakgeID=0adfd765-393a-4a95-bd63-3893be5f26d0, Action=None
# Package: 0adfd765-393a-4a95-bd63-3893be5f26d0 processing...
# STEP:::PacakgeID=933fa08f-98fb-4aa0-8d78-5cd3743bcb0c, Action=None
# Package: 933fa08f-98fb-4aa0-8d78-5cd3743bcb0c processing...
# STEP:::PacakgeID=0385285b-1560-417d-93b2-b92932d79de7, Action=None
# Package: 0385285b-1560-417d-93b2-b92932d79de7 processing...
# STEP:::PacakgeID=742c697b-78b7-43ce-ab28-265e0aeb92fc, Action=['s17', 's22']
# is in Node: s17,
# package: 742c697b-78b7-43ce-ab28-265e0aeb92fc removed from Node: s17.
# Pack added to Route: s17->s22;
# STEP:::PacakgeID=45cef0ff-744f-4f62-81a8-d0103cae2869, Action=['s8', 's1']
# is in Node: s8,
# package: 45cef0ff-744f-4f62-81a8-d0103cae2869 removed from Node: s8.
# Pack added to Route: s8->s1;
# STEP:::PacakgeID=a422c0f6-876f-418d-b0a8-34841b266f2b, Action=None
# Package: a422c0f6-876f-418d-b0a8-34841b266f2b processing...
# STEP:::PacakgeID=e14ad120-3c24-40de-a638-70af1e45e1aa, Action=['s6', 's19']
# is in Node: s6,
# package: e14ad120-3c24-40de-a638-70af1e45e1aa removed from Node: s6.
# Pack added to Route: s6->s19;
# STEP:::PacakgeID=74813b16-d1e9-4e94-b78a-983459689fdc, Action=None
# Package: 74813b16-d1e9-4e94-b78a-983459689fdc processing...
# STEP:::PacakgeID=e3ef1fcf-23a3-45c6-8747-00d4e4854038, Action=['s6', 's19']
# is in Node: s6,
# package: e3ef1fcf-23a3-45c6-8747-00d4e4854038 removed from Node: s6.
# Pack added to Route: s6->s19;
# STEP:::PacakgeID=bf1ac37b-ac08-4e64-b170-e3c0c27796c2, Action=['s11', 's4']
# is in Node: s11,
# package: bf1ac37b-ac08-4e64-b170-e3c0c27796c2 removed from Node: s11.
# Pack added to Route: s11->s4;
# STEP:::PacakgeID=6703e9f2-d791-48a1-81f8-000ae95ec082, Action=['s6', 's23']
# is in Node: s6,
# package: 6703e9f2-d791-48a1-81f8-000ae95ec082 removed from Node: s6.
# Pack added to Route: s6->s23;
# STEP:::PacakgeID=75ff6610-e7e8-4a41-8882-a1bd81b525b3, Action=['s6', 's19']
# is in Node: s6,
# package: 75ff6610-e7e8-4a41-8882-a1bd81b525b3 removed from Node: s6.
# Pack added to Route: s6->s19;
# STEP:::PacakgeID=e36514c4-24ae-41e8-9c71-57bc074d05fb, Action=None
# Package: e36514c4-24ae-41e8-9c71-57bc074d05fb processing...
# STEP:::PacakgeID=6dc9e950-9189-4a9b-9ba2-4fb879e3995c, Action=None
# Package: 6dc9e950-9189-4a9b-9ba2-4fb879e3995c processing...
# STEP:::PacakgeID=27664dcb-051a-4bfb-9261-ae3c68341b46, Action=['s6', 's9']
# is in Node: s6,
# package: 27664dcb-051a-4bfb-9261-ae3c68341b46 removed from Node: s6.
# Pack added to Route: s6->s9;
# STEP:::PacakgeID=28ffe2fb-320a-4779-b105-d72cf6b546e5, Action=['s19', 's1']
# is in Node: s19,
# package: 28ffe2fb-320a-4779-b105-d72cf6b546e5 removed from Node: s19.
# Pack added to Route: s19->s1;
# the new min_delay: 1
# Time tick: 1.0, Total reward: -11.000000000000004
# ------------------------------------------------------STEP2------------------------------------------------------
# STEP:::PacakgeID=bbcc44cf-788d-459a-be0f-c840ff47189f, Action=None
# Package: bbcc44cf-788d-459a-be0f-c840ff47189f processing...
# STEP:::PacakgeID=7bf5d7dc-0961-4512-8d03-26f841401c81, Action=None
# Package: 7bf5d7dc-0961-4512-8d03-26f841401c81 processing...
# STEP:::PacakgeID=d23ec060-6535-4b38-8955-244434fe5d0f, Action=None
# Package: d23ec060-6535-4b38-8955-244434fe5d0f processing...
# STEP:::PacakgeID=47206f87-02d3-4f53-92d4-45ad0f509eee, Action=None
# Package: 47206f87-02d3-4f53-92d4-45ad0f509eee processing...
# STEP:::PacakgeID=0adfd765-393a-4a95-bd63-3893be5f26d0, Action=['s9', 's19']
# is in Node: s9,
# package: 0adfd765-393a-4a95-bd63-3893be5f26d0 removed from Node: s9.
# Pack added to Route: s9->s19;
# STEP:::PacakgeID=933fa08f-98fb-4aa0-8d78-5cd3743bcb0c, Action=['s0', 's9']
# is in Node: s0,
# package: 933fa08f-98fb-4aa0-8d78-5cd3743bcb0c removed from Node: s0.
# Pack added to Route: s0->s9;
# STEP:::PacakgeID=0385285b-1560-417d-93b2-b92932d79de7, Action=['s3', 's20']
# is in Node: s3,
# package: 0385285b-1560-417d-93b2-b92932d79de7 removed from Node: s3.
# Pack added to Route: s3->s20;
# STEP:::PacakgeID=742c697b-78b7-43ce-ab28-265e0aeb92fc, Action=None
# Package: 742c697b-78b7-43ce-ab28-265e0aeb92fc processing...
# STEP:::PacakgeID=45cef0ff-744f-4f62-81a8-d0103cae2869, Action=None
# Package: 45cef0ff-744f-4f62-81a8-d0103cae2869 processing...
# STEP:::PacakgeID=a422c0f6-876f-418d-b0a8-34841b266f2b, Action=['s0', 's14']
# is in Node: s0,
# package: a422c0f6-876f-418d-b0a8-34841b266f2b removed from Node: s0.
# Pack added to Route: s0->s14;
# STEP:::PacakgeID=e14ad120-3c24-40de-a638-70af1e45e1aa, Action=None
# Package: e14ad120-3c24-40de-a638-70af1e45e1aa processing...
# STEP:::PacakgeID=74813b16-d1e9-4e94-b78a-983459689fdc, Action=['s18', 's16']
# is in Node: s18,
# package: 74813b16-d1e9-4e94-b78a-983459689fdc removed from Node: s18.
# Pack added to Route: s18->s16;
# STEP:::PacakgeID=e3ef1fcf-23a3-45c6-8747-00d4e4854038, Action=None
# Package: e3ef1fcf-23a3-45c6-8747-00d4e4854038 processing...
# STEP:::PacakgeID=bf1ac37b-ac08-4e64-b170-e3c0c27796c2, Action=None
# Package: bf1ac37b-ac08-4e64-b170-e3c0c27796c2 processing...
# STEP:::PacakgeID=6703e9f2-d791-48a1-81f8-000ae95ec082, Action=None
# Package: 6703e9f2-d791-48a1-81f8-000ae95ec082 processing...
# STEP:::PacakgeID=75ff6610-e7e8-4a41-8882-a1bd81b525b3, Action=None
# Package: 75ff6610-e7e8-4a41-8882-a1bd81b525b3 processing...
# STEP:::PacakgeID=e36514c4-24ae-41e8-9c71-57bc074d05fb, Action=['s5', 's23']
# is in Node: s5,
# package: e36514c4-24ae-41e8-9c71-57bc074d05fb removed from Node: s5.
# Pack added to Route: s5->s23;
# STEP:::PacakgeID=6dc9e950-9189-4a9b-9ba2-4fb879e3995c, Action=['s24', 's16']
# is in Node: s24,
# package: 6dc9e950-9189-4a9b-9ba2-4fb879e3995c removed from Node: s24.
# Pack added to Route: s24->s16;
# STEP:::PacakgeID=27664dcb-051a-4bfb-9261-ae3c68341b46, Action=None
# Package: 27664dcb-051a-4bfb-9261-ae3c68341b46 processing...
# STEP:::PacakgeID=28ffe2fb-320a-4779-b105-d72cf6b546e5, Action=None
# Package: 28ffe2fb-320a-4779-b105-d72cf6b546e5 processing...
# the new min_delay: 3.6647615158762408
# Time tick: 2.0, Total reward: -14.600000000000005
# ------------------------------------------------------STEP3------------------------------------------------------
# STEP:::PacakgeID=bbcc44cf-788d-459a-be0f-c840ff47189f, Action=None
# Package: bbcc44cf-788d-459a-be0f-c840ff47189f processing...
# STEP:::PacakgeID=7bf5d7dc-0961-4512-8d03-26f841401c81, Action=None
# Package: 7bf5d7dc-0961-4512-8d03-26f841401c81 processing...
# STEP:::PacakgeID=d23ec060-6535-4b38-8955-244434fe5d0f, Action=None
# Package: d23ec060-6535-4b38-8955-244434fe5d0f processing...
# STEP:::PacakgeID=47206f87-02d3-4f53-92d4-45ad0f509eee, Action=None
# Package: 47206f87-02d3-4f53-92d4-45ad0f509eee processing...
# STEP:::PacakgeID=0adfd765-393a-4a95-bd63-3893be5f26d0, Action=None
# Package: 0adfd765-393a-4a95-bd63-3893be5f26d0 processing...
# STEP:::PacakgeID=933fa08f-98fb-4aa0-8d78-5cd3743bcb0c, Action=None
# Package: 933fa08f-98fb-4aa0-8d78-5cd3743bcb0c processing...
# STEP:::PacakgeID=0385285b-1560-417d-93b2-b92932d79de7, Action=None
# Package: 0385285b-1560-417d-93b2-b92932d79de7 processing...
# STEP:::PacakgeID=742c697b-78b7-43ce-ab28-265e0aeb92fc, Action=None
# Package: 742c697b-78b7-43ce-ab28-265e0aeb92fc processing...
# STEP:::PacakgeID=45cef0ff-744f-4f62-81a8-d0103cae2869, Action=None
# Package: 45cef0ff-744f-4f62-81a8-d0103cae2869 processing...
# STEP:::PacakgeID=a422c0f6-876f-418d-b0a8-34841b266f2b, Action=None
# Package: a422c0f6-876f-418d-b0a8-34841b266f2b processing...
# STEP:::PacakgeID=e14ad120-3c24-40de-a638-70af1e45e1aa, Action=None
# Package: e14ad120-3c24-40de-a638-70af1e45e1aa processing...
# STEP:::PacakgeID=74813b16-d1e9-4e94-b78a-983459689fdc, Action=None
# Package: 74813b16-d1e9-4e94-b78a-983459689fdc processing...
# STEP:::PacakgeID=e3ef1fcf-23a3-45c6-8747-00d4e4854038, Action=None
# Package: e3ef1fcf-23a3-45c6-8747-00d4e4854038 processing...
# STEP:::PacakgeID=bf1ac37b-ac08-4e64-b170-e3c0c27796c2, Action=['s11', 's4']
# is on Route: s11->s4,
# package: bf1ac37b-ac08-4e64-b170-e3c0c27796c2 removed from Route: s11->s4.
# Pack added to Node: s4;
# STEP:::PacakgeID=6703e9f2-d791-48a1-81f8-000ae95ec082, Action=None
# Package: 6703e9f2-d791-48a1-81f8-000ae95ec082 processing...
# STEP:::PacakgeID=75ff6610-e7e8-4a41-8882-a1bd81b525b3, Action=None
# Package: 75ff6610-e7e8-4a41-8882-a1bd81b525b3 processing...
# STEP:::PacakgeID=e36514c4-24ae-41e8-9c71-57bc074d05fb, Action=None
# Package: e36514c4-24ae-41e8-9c71-57bc074d05fb processing...
# STEP:::PacakgeID=6dc9e950-9189-4a9b-9ba2-4fb879e3995c, Action=None
# Package: 6dc9e950-9189-4a9b-9ba2-4fb879e3995c processing...
# STEP:::PacakgeID=27664dcb-051a-4bfb-9261-ae3c68341b46, Action=None
# Package: 27664dcb-051a-4bfb-9261-ae3c68341b46 processing...
# STEP:::PacakgeID=28ffe2fb-320a-4779-b105-d72cf6b546e5, Action=None
# Package: 28ffe2fb-320a-4779-b105-d72cf6b546e5 processing...
# the new min_delay: 4.698998412699461
# Time tick: 5.664761515876241, Total reward: -15.008166632639176
# ------------------------------------------------------STEP4------------------------------------------------------
# STEP:::PacakgeID=bbcc44cf-788d-459a-be0f-c840ff47189f, Action=None
# Package: bbcc44cf-788d-459a-be0f-c840ff47189f processing...
# STEP:::PacakgeID=7bf5d7dc-0961-4512-8d03-26f841401c81, Action=None
# Package: 7bf5d7dc-0961-4512-8d03-26f841401c81 processing...
# STEP:::PacakgeID=d23ec060-6535-4b38-8955-244434fe5d0f, Action=None
# Package: d23ec060-6535-4b38-8955-244434fe5d0f processing...
# STEP:::PacakgeID=47206f87-02d3-4f53-92d4-45ad0f509eee, Action=None
# Package: 47206f87-02d3-4f53-92d4-45ad0f509eee processing...
# STEP:::PacakgeID=0adfd765-393a-4a95-bd63-3893be5f26d0, Action=None
# Package: 0adfd765-393a-4a95-bd63-3893be5f26d0 processing...
# STEP:::PacakgeID=933fa08f-98fb-4aa0-8d78-5cd3743bcb0c, Action=None
# Package: 933fa08f-98fb-4aa0-8d78-5cd3743bcb0c processing...
# STEP:::PacakgeID=0385285b-1560-417d-93b2-b92932d79de7, Action=None
# Package: 0385285b-1560-417d-93b2-b92932d79de7 processing...
# STEP:::PacakgeID=742c697b-78b7-43ce-ab28-265e0aeb92fc, Action=None
# Package: 742c697b-78b7-43ce-ab28-265e0aeb92fc processing...
# STEP:::PacakgeID=45cef0ff-744f-4f62-81a8-d0103cae2869, Action=None
# Package: 45cef0ff-744f-4f62-81a8-d0103cae2869 processing...
# STEP:::PacakgeID=a422c0f6-876f-418d-b0a8-34841b266f2b, Action=None
# Package: a422c0f6-876f-418d-b0a8-34841b266f2b processing...
# STEP:::PacakgeID=e14ad120-3c24-40de-a638-70af1e45e1aa, Action=['s6', 's19']
# is on Route: s6->s19,
# package: e14ad120-3c24-40de-a638-70af1e45e1aa removed from Route: s6->s19.
# Pack added to Node: s19;
# STEP:::PacakgeID=74813b16-d1e9-4e94-b78a-983459689fdc, Action=None
# Package: 74813b16-d1e9-4e94-b78a-983459689fdc processing...
# STEP:::PacakgeID=e3ef1fcf-23a3-45c6-8747-00d4e4854038, Action=['s6', 's19']
# is on Route: s6->s19,
# package: e3ef1fcf-23a3-45c6-8747-00d4e4854038 removed from Route: s6->s19.
# Pack added to Node: s19;
# STEP:::PacakgeID=bf1ac37b-ac08-4e64-b170-e3c0c27796c2, Action=None
# STEP:::PacakgeID=6703e9f2-d791-48a1-81f8-000ae95ec082, Action=None
# Package: 6703e9f2-d791-48a1-81f8-000ae95ec082 processing...
# STEP:::PacakgeID=75ff6610-e7e8-4a41-8882-a1bd81b525b3, Action=['s6', 's19']
# is on Route: s6->s19,
# package: 75ff6610-e7e8-4a41-8882-a1bd81b525b3 removed from Route: s6->s19.
# Pack added to Node: s19;
# STEP:::PacakgeID=e36514c4-24ae-41e8-9c71-57bc074d05fb, Action=None
# Package: e36514c4-24ae-41e8-9c71-57bc074d05fb processing...
# STEP:::PacakgeID=6dc9e950-9189-4a9b-9ba2-4fb879e3995c, Action=None
# Package: 6dc9e950-9189-4a9b-9ba2-4fb879e3995c processing...
# STEP:::PacakgeID=27664dcb-051a-4bfb-9261-ae3c68341b46, Action=None
# Package: 27664dcb-051a-4bfb-9261-ae3c68341b46 processing...
# STEP:::PacakgeID=28ffe2fb-320a-4779-b105-d72cf6b546e5, Action=None
# Package: 28ffe2fb-320a-4779-b105-d72cf6b546e5 processing...
# the new min_delay: 0.47252888517410696
# Time tick: 10.363759928575702, Total reward: -16.157986981251124
# ------------------------------------------------------STEP5------------------------------------------------------
# STEP:::PacakgeID=bbcc44cf-788d-459a-be0f-c840ff47189f, Action=None
# Package: bbcc44cf-788d-459a-be0f-c840ff47189f processing...
# STEP:::PacakgeID=7bf5d7dc-0961-4512-8d03-26f841401c81, Action=None
# Package: 7bf5d7dc-0961-4512-8d03-26f841401c81 processing...
# STEP:::PacakgeID=d23ec060-6535-4b38-8955-244434fe5d0f, Action=None
# Package: d23ec060-6535-4b38-8955-244434fe5d0f processing...
# STEP:::PacakgeID=47206f87-02d3-4f53-92d4-45ad0f509eee, Action=None
# Package: 47206f87-02d3-4f53-92d4-45ad0f509eee processing...
# STEP:::PacakgeID=0adfd765-393a-4a95-bd63-3893be5f26d0, Action=None
# Package: 0adfd765-393a-4a95-bd63-3893be5f26d0 processing...
# STEP:::PacakgeID=933fa08f-98fb-4aa0-8d78-5cd3743bcb0c, Action=None
# Package: 933fa08f-98fb-4aa0-8d78-5cd3743bcb0c processing...
# STEP:::PacakgeID=0385285b-1560-417d-93b2-b92932d79de7, Action=None
# Package: 0385285b-1560-417d-93b2-b92932d79de7 processing...
# STEP:::PacakgeID=742c697b-78b7-43ce-ab28-265e0aeb92fc, Action=None
# Package: 742c697b-78b7-43ce-ab28-265e0aeb92fc processing...
# STEP:::PacakgeID=45cef0ff-744f-4f62-81a8-d0103cae2869, Action=None
# Package: 45cef0ff-744f-4f62-81a8-d0103cae2869 processing...
# STEP:::PacakgeID=a422c0f6-876f-418d-b0a8-34841b266f2b, Action=None
# Package: a422c0f6-876f-418d-b0a8-34841b266f2b processing...
# STEP:::PacakgeID=e14ad120-3c24-40de-a638-70af1e45e1aa, Action=None
# Package: e14ad120-3c24-40de-a638-70af1e45e1aa processing...
# STEP:::PacakgeID=74813b16-d1e9-4e94-b78a-983459689fdc, Action=None
# Package: 74813b16-d1e9-4e94-b78a-983459689fdc processing...
# STEP:::PacakgeID=e3ef1fcf-23a3-45c6-8747-00d4e4854038, Action=None
# Package: e3ef1fcf-23a3-45c6-8747-00d4e4854038 processing...
# STEP:::PacakgeID=bf1ac37b-ac08-4e64-b170-e3c0c27796c2, Action=None
# STEP:::PacakgeID=6703e9f2-d791-48a1-81f8-000ae95ec082, Action=None
# Package: 6703e9f2-d791-48a1-81f8-000ae95ec082 processing...
# STEP:::PacakgeID=75ff6610-e7e8-4a41-8882-a1bd81b525b3, Action=None
# Package: 75ff6610-e7e8-4a41-8882-a1bd81b525b3 processing...
# STEP:::PacakgeID=e36514c4-24ae-41e8-9c71-57bc074d05fb, Action=None
# Package: e36514c4-24ae-41e8-9c71-57bc074d05fb processing...
# STEP:::PacakgeID=6dc9e950-9189-4a9b-9ba2-4fb879e3995c, Action=['s24', 's16']
# is on Route: s24->s16,
# package: 6dc9e950-9189-4a9b-9ba2-4fb879e3995c removed from Route: s24->s16.
# Pack added to Node: s16;
# STEP:::PacakgeID=27664dcb-051a-4bfb-9261-ae3c68341b46, Action=None
# Package: 27664dcb-051a-4bfb-9261-ae3c68341b46 processing...
# STEP:::PacakgeID=28ffe2fb-320a-4779-b105-d72cf6b546e5, Action=None
# Package: 28ffe2fb-320a-4779-b105-d72cf6b546e5 processing...
# the new min_delay: 0.527471114825893
# Time tick: 10.836288813749809, Total reward: -16.931162252454232
# ------------------------------------------------------STEP6------------------------------------------------------
# STEP:::PacakgeID=bbcc44cf-788d-459a-be0f-c840ff47189f, Action=None
# Package: bbcc44cf-788d-459a-be0f-c840ff47189f processing...
# STEP:::PacakgeID=7bf5d7dc-0961-4512-8d03-26f841401c81, Action=None
# Package: 7bf5d7dc-0961-4512-8d03-26f841401c81 processing...
# STEP:::PacakgeID=d23ec060-6535-4b38-8955-244434fe5d0f, Action=None
# Package: d23ec060-6535-4b38-8955-244434fe5d0f processing...
# STEP:::PacakgeID=47206f87-02d3-4f53-92d4-45ad0f509eee, Action=None
# Package: 47206f87-02d3-4f53-92d4-45ad0f509eee processing...
# STEP:::PacakgeID=0adfd765-393a-4a95-bd63-3893be5f26d0, Action=None
# Package: 0adfd765-393a-4a95-bd63-3893be5f26d0 processing...
# STEP:::PacakgeID=933fa08f-98fb-4aa0-8d78-5cd3743bcb0c, Action=None
# Package: 933fa08f-98fb-4aa0-8d78-5cd3743bcb0c processing...
# STEP:::PacakgeID=0385285b-1560-417d-93b2-b92932d79de7, Action=None
# Package: 0385285b-1560-417d-93b2-b92932d79de7 processing...
# STEP:::PacakgeID=742c697b-78b7-43ce-ab28-265e0aeb92fc, Action=None
# Package: 742c697b-78b7-43ce-ab28-265e0aeb92fc processing...
# STEP:::PacakgeID=45cef0ff-744f-4f62-81a8-d0103cae2869, Action=None
# Package: 45cef0ff-744f-4f62-81a8-d0103cae2869 processing...
# STEP:::PacakgeID=a422c0f6-876f-418d-b0a8-34841b266f2b, Action=None
# Package: a422c0f6-876f-418d-b0a8-34841b266f2b processing...
# STEP:::PacakgeID=e14ad120-3c24-40de-a638-70af1e45e1aa, Action=['s19', 's20']
# is in Node: s19,
# package: e14ad120-3c24-40de-a638-70af1e45e1aa removed from Node: s19.
# Pack added to Route: s19->s20;
# STEP:::PacakgeID=74813b16-d1e9-4e94-b78a-983459689fdc, Action=None
# Package: 74813b16-d1e9-4e94-b78a-983459689fdc processing...
# STEP:::PacakgeID=e3ef1fcf-23a3-45c6-8747-00d4e4854038, Action=['s19', 's0']
# is in Node: s19,
# package: e3ef1fcf-23a3-45c6-8747-00d4e4854038 removed from Node: s19.
# Pack added to Route: s19->s0;
# STEP:::PacakgeID=bf1ac37b-ac08-4e64-b170-e3c0c27796c2, Action=None
# STEP:::PacakgeID=6703e9f2-d791-48a1-81f8-000ae95ec082, Action=None
# Package: 6703e9f2-d791-48a1-81f8-000ae95ec082 processing...
# STEP:::PacakgeID=75ff6610-e7e8-4a41-8882-a1bd81b525b3, Action=['s19', 's14']
# is in Node: s19,
# package: 75ff6610-e7e8-4a41-8882-a1bd81b525b3 removed from Node: s19.
# Pack added to Route: s19->s14;
# STEP:::PacakgeID=e36514c4-24ae-41e8-9c71-57bc074d05fb, Action=None
# Package: e36514c4-24ae-41e8-9c71-57bc074d05fb processing...
# STEP:::PacakgeID=6dc9e950-9189-4a9b-9ba2-4fb879e3995c, Action=None
# Package: 6dc9e950-9189-4a9b-9ba2-4fb879e3995c processing...
# STEP:::PacakgeID=27664dcb-051a-4bfb-9261-ae3c68341b46, Action=None
# Package: 27664dcb-051a-4bfb-9261-ae3c68341b46 processing...
# STEP:::PacakgeID=28ffe2fb-320a-4779-b105-d72cf6b546e5, Action=None
# Package: 28ffe2fb-320a-4779-b105-d72cf6b546e5 processing...
# the new min_delay: 0.47252888517410696
# Time tick: 11.363759928575702, Total reward: -19.33116225245423
# ------------------------------------------------------STEP7------------------------------------------------------
# STEP:::PacakgeID=bbcc44cf-788d-459a-be0f-c840ff47189f, Action=None
# Package: bbcc44cf-788d-459a-be0f-c840ff47189f processing...
# STEP:::PacakgeID=7bf5d7dc-0961-4512-8d03-26f841401c81, Action=None
# Package: 7bf5d7dc-0961-4512-8d03-26f841401c81 processing...
# STEP:::PacakgeID=d23ec060-6535-4b38-8955-244434fe5d0f, Action=None
# Package: d23ec060-6535-4b38-8955-244434fe5d0f processing...
# STEP:::PacakgeID=47206f87-02d3-4f53-92d4-45ad0f509eee, Action=None
# Package: 47206f87-02d3-4f53-92d4-45ad0f509eee processing...
# STEP:::PacakgeID=0adfd765-393a-4a95-bd63-3893be5f26d0, Action=None
# Package: 0adfd765-393a-4a95-bd63-3893be5f26d0 processing...
# STEP:::PacakgeID=933fa08f-98fb-4aa0-8d78-5cd3743bcb0c, Action=None
# Package: 933fa08f-98fb-4aa0-8d78-5cd3743bcb0c processing...
# STEP:::PacakgeID=0385285b-1560-417d-93b2-b92932d79de7, Action=None
# Package: 0385285b-1560-417d-93b2-b92932d79de7 processing...
# STEP:::PacakgeID=742c697b-78b7-43ce-ab28-265e0aeb92fc, Action=None
# Package: 742c697b-78b7-43ce-ab28-265e0aeb92fc processing...
# STEP:::PacakgeID=45cef0ff-744f-4f62-81a8-d0103cae2869, Action=None
# Package: 45cef0ff-744f-4f62-81a8-d0103cae2869 processing...
# STEP:::PacakgeID=a422c0f6-876f-418d-b0a8-34841b266f2b, Action=None
# Package: a422c0f6-876f-418d-b0a8-34841b266f2b processing...
# STEP:::PacakgeID=e14ad120-3c24-40de-a638-70af1e45e1aa, Action=None
# Package: e14ad120-3c24-40de-a638-70af1e45e1aa processing...
# STEP:::PacakgeID=74813b16-d1e9-4e94-b78a-983459689fdc, Action=None
# Package: 74813b16-d1e9-4e94-b78a-983459689fdc processing...
# STEP:::PacakgeID=e3ef1fcf-23a3-45c6-8747-00d4e4854038, Action=None
# Package: e3ef1fcf-23a3-45c6-8747-00d4e4854038 processing...
# STEP:::PacakgeID=bf1ac37b-ac08-4e64-b170-e3c0c27796c2, Action=None
# STEP:::PacakgeID=6703e9f2-d791-48a1-81f8-000ae95ec082, Action=None
# Package: 6703e9f2-d791-48a1-81f8-000ae95ec082 processing...
# STEP:::PacakgeID=75ff6610-e7e8-4a41-8882-a1bd81b525b3, Action=None
# Package: 75ff6610-e7e8-4a41-8882-a1bd81b525b3 processing...
# STEP:::PacakgeID=e36514c4-24ae-41e8-9c71-57bc074d05fb, Action=None
# Package: e36514c4-24ae-41e8-9c71-57bc074d05fb processing...
# STEP:::PacakgeID=6dc9e950-9189-4a9b-9ba2-4fb879e3995c, Action=['s16', 's19']
# is in Node: s16,
# package: 6dc9e950-9189-4a9b-9ba2-4fb879e3995c removed from Node: s16.
# Pack added to Route: s16->s19;
# STEP:::PacakgeID=27664dcb-051a-4bfb-9261-ae3c68341b46, Action=None
# Package: 27664dcb-051a-4bfb-9261-ae3c68341b46 processing...
# STEP:::PacakgeID=28ffe2fb-320a-4779-b105-d72cf6b546e5, Action=None
# Package: 28ffe2fb-320a-4779-b105-d72cf6b546e5 processing...
# the new min_delay: 1.1903482889485186
# Time tick: 11.836288813749809, Total reward: -20.23116225245423
# ------------------------------------------------------STEP8------------------------------------------------------
# STEP:::PacakgeID=bbcc44cf-788d-459a-be0f-c840ff47189f, Action=None
# Package: bbcc44cf-788d-459a-be0f-c840ff47189f processing...
# STEP:::PacakgeID=7bf5d7dc-0961-4512-8d03-26f841401c81, Action=['s8', 's17']
# is on Route: s8->s17,
# package: 7bf5d7dc-0961-4512-8d03-26f841401c81 removed from Route: s8->s17.
# Pack added to Node: s17;
# STEP:::PacakgeID=d23ec060-6535-4b38-8955-244434fe5d0f, Action=None
# Package: d23ec060-6535-4b38-8955-244434fe5d0f processing...
# STEP:::PacakgeID=47206f87-02d3-4f53-92d4-45ad0f509eee, Action=None
# Package: 47206f87-02d3-4f53-92d4-45ad0f509eee processing...
# STEP:::PacakgeID=0adfd765-393a-4a95-bd63-3893be5f26d0, Action=None
# Package: 0adfd765-393a-4a95-bd63-3893be5f26d0 processing...
# STEP:::PacakgeID=933fa08f-98fb-4aa0-8d78-5cd3743bcb0c, Action=None
# Package: 933fa08f-98fb-4aa0-8d78-5cd3743bcb0c processing...
# STEP:::PacakgeID=0385285b-1560-417d-93b2-b92932d79de7, Action=None
# Package: 0385285b-1560-417d-93b2-b92932d79de7 processing...
# STEP:::PacakgeID=742c697b-78b7-43ce-ab28-265e0aeb92fc, Action=None
# Package: 742c697b-78b7-43ce-ab28-265e0aeb92fc processing...
# STEP:::PacakgeID=45cef0ff-744f-4f62-81a8-d0103cae2869, Action=None
# Package: 45cef0ff-744f-4f62-81a8-d0103cae2869 processing...
# STEP:::PacakgeID=a422c0f6-876f-418d-b0a8-34841b266f2b, Action=None
# Package: a422c0f6-876f-418d-b0a8-34841b266f2b processing...
# STEP:::PacakgeID=e14ad120-3c24-40de-a638-70af1e45e1aa, Action=None
# Package: e14ad120-3c24-40de-a638-70af1e45e1aa processing...
# STEP:::PacakgeID=74813b16-d1e9-4e94-b78a-983459689fdc, Action=None
# Package: 74813b16-d1e9-4e94-b78a-983459689fdc processing...
# STEP:::PacakgeID=e3ef1fcf-23a3-45c6-8747-00d4e4854038, Action=None
# Package: e3ef1fcf-23a3-45c6-8747-00d4e4854038 processing...
# STEP:::PacakgeID=bf1ac37b-ac08-4e64-b170-e3c0c27796c2, Action=None
# STEP:::PacakgeID=6703e9f2-d791-48a1-81f8-000ae95ec082, Action=None
# Package: 6703e9f2-d791-48a1-81f8-000ae95ec082 processing...
# STEP:::PacakgeID=75ff6610-e7e8-4a41-8882-a1bd81b525b3, Action=None
# Package: 75ff6610-e7e8-4a41-8882-a1bd81b525b3 processing...
# STEP:::PacakgeID=e36514c4-24ae-41e8-9c71-57bc074d05fb, Action=None
# Package: e36514c4-24ae-41e8-9c71-57bc074d05fb processing...
# STEP:::PacakgeID=6dc9e950-9189-4a9b-9ba2-4fb879e3995c, Action=None
# Package: 6dc9e950-9189-4a9b-9ba2-4fb879e3995c processing...
# STEP:::PacakgeID=27664dcb-051a-4bfb-9261-ae3c68341b46, Action=None
# Package: 27664dcb-051a-4bfb-9261-ae3c68341b46 processing...
# STEP:::PacakgeID=28ffe2fb-320a-4779-b105-d72cf6b546e5, Action=None
# Package: 28ffe2fb-320a-4779-b105-d72cf6b546e5 processing...
# the new min_delay: 1.383806588693841
# Time tick: 13.026637102698327, Total reward: -21.283492998940332
# ------------------------------------------------------STEP9------------------------------------------------------
# STEP:::PacakgeID=bbcc44cf-788d-459a-be0f-c840ff47189f, Action=None
# Package: bbcc44cf-788d-459a-be0f-c840ff47189f processing...
# STEP:::PacakgeID=7bf5d7dc-0961-4512-8d03-26f841401c81, Action=None
# STEP:::PacakgeID=d23ec060-6535-4b38-8955-244434fe5d0f, Action=None
# Package: d23ec060-6535-4b38-8955-244434fe5d0f processing...
# STEP:::PacakgeID=47206f87-02d3-4f53-92d4-45ad0f509eee, Action=['s19', 's1']
# is on Route: s19->s1,
# package: 47206f87-02d3-4f53-92d4-45ad0f509eee removed from Route: s19->s1.
# Pack added to Node: s1;
# STEP:::PacakgeID=0adfd765-393a-4a95-bd63-3893be5f26d0, Action=None
# Package: 0adfd765-393a-4a95-bd63-3893be5f26d0 processing...
# STEP:::PacakgeID=933fa08f-98fb-4aa0-8d78-5cd3743bcb0c, Action=None
# Package: 933fa08f-98fb-4aa0-8d78-5cd3743bcb0c processing...
# STEP:::PacakgeID=0385285b-1560-417d-93b2-b92932d79de7, Action=None
# Package: 0385285b-1560-417d-93b2-b92932d79de7 processing...
# STEP:::PacakgeID=742c697b-78b7-43ce-ab28-265e0aeb92fc, Action=None
# Package: 742c697b-78b7-43ce-ab28-265e0aeb92fc processing...
# STEP:::PacakgeID=45cef0ff-744f-4f62-81a8-d0103cae2869, Action=None
# Package: 45cef0ff-744f-4f62-81a8-d0103cae2869 processing...
# STEP:::PacakgeID=a422c0f6-876f-418d-b0a8-34841b266f2b, Action=None
# Package: a422c0f6-876f-418d-b0a8-34841b266f2b processing...
# STEP:::PacakgeID=e14ad120-3c24-40de-a638-70af1e45e1aa, Action=None
# Package: e14ad120-3c24-40de-a638-70af1e45e1aa processing...
# STEP:::PacakgeID=74813b16-d1e9-4e94-b78a-983459689fdc, Action=None
# Package: 74813b16-d1e9-4e94-b78a-983459689fdc processing...
# STEP:::PacakgeID=e3ef1fcf-23a3-45c6-8747-00d4e4854038, Action=None
# Package: e3ef1fcf-23a3-45c6-8747-00d4e4854038 processing...
# STEP:::PacakgeID=bf1ac37b-ac08-4e64-b170-e3c0c27796c2, Action=None
# STEP:::PacakgeID=6703e9f2-d791-48a1-81f8-000ae95ec082, Action=None
# Package: 6703e9f2-d791-48a1-81f8-000ae95ec082 processing...
# STEP:::PacakgeID=75ff6610-e7e8-4a41-8882-a1bd81b525b3, Action=None
# Package: 75ff6610-e7e8-4a41-8882-a1bd81b525b3 processing...
# STEP:::PacakgeID=e36514c4-24ae-41e8-9c71-57bc074d05fb, Action=None
# Package: e36514c4-24ae-41e8-9c71-57bc074d05fb processing...
# STEP:::PacakgeID=6dc9e950-9189-4a9b-9ba2-4fb879e3995c, Action=None
# Package: 6dc9e950-9189-4a9b-9ba2-4fb879e3995c processing...
# STEP:::PacakgeID=27664dcb-051a-4bfb-9261-ae3c68341b46, Action=None
# Package: 27664dcb-051a-4bfb-9261-ae3c68341b46 processing...
# STEP:::PacakgeID=28ffe2fb-320a-4779-b105-d72cf6b546e5, Action=['s19', 's1']
# is on Route: s19->s1,
# package: 28ffe2fb-320a-4779-b105-d72cf6b546e5 removed from Route: s19->s1.
# Pack added to Node: s1;
# package: 28ffe2fb-320a-4779-b105-d72cf6b546e5 removed from Node: s1.
# the new min_delay: 0.2386669492813489
# Time tick: 14.410443691392167, Total reward: -21.67798989844786
# ------------------------------------------------------STEP10------------------------------------------------------
# STEP:::PacakgeID=bbcc44cf-788d-459a-be0f-c840ff47189f, Action=None
# Package: bbcc44cf-788d-459a-be0f-c840ff47189f processing...
# STEP:::PacakgeID=7bf5d7dc-0961-4512-8d03-26f841401c81, Action=None
# STEP:::PacakgeID=d23ec060-6535-4b38-8955-244434fe5d0f, Action=None
# Package: d23ec060-6535-4b38-8955-244434fe5d0f processing...
# STEP:::PacakgeID=47206f87-02d3-4f53-92d4-45ad0f509eee, Action=None
# STEP:::PacakgeID=0adfd765-393a-4a95-bd63-3893be5f26d0, Action=['s9', 's19']
# is on Route: s9->s19,
# package: 0adfd765-393a-4a95-bd63-3893be5f26d0 removed from Route: s9->s19.
# Pack added to Node: s19;
# STEP:::PacakgeID=933fa08f-98fb-4aa0-8d78-5cd3743bcb0c, Action=None
# Package: 933fa08f-98fb-4aa0-8d78-5cd3743bcb0c processing...
# STEP:::PacakgeID=0385285b-1560-417d-93b2-b92932d79de7, Action=None
# Package: 0385285b-1560-417d-93b2-b92932d79de7 processing...
# STEP:::PacakgeID=742c697b-78b7-43ce-ab28-265e0aeb92fc, Action=None
# Package: 742c697b-78b7-43ce-ab28-265e0aeb92fc processing...
# STEP:::PacakgeID=45cef0ff-744f-4f62-81a8-d0103cae2869, Action=None
# Package: 45cef0ff-744f-4f62-81a8-d0103cae2869 processing...
# STEP:::PacakgeID=a422c0f6-876f-418d-b0a8-34841b266f2b, Action=None
# Package: a422c0f6-876f-418d-b0a8-34841b266f2b processing...
# STEP:::PacakgeID=e14ad120-3c24-40de-a638-70af1e45e1aa, Action=None
# Package: e14ad120-3c24-40de-a638-70af1e45e1aa processing...
# STEP:::PacakgeID=74813b16-d1e9-4e94-b78a-983459689fdc, Action=None
# Package: 74813b16-d1e9-4e94-b78a-983459689fdc processing...
# STEP:::PacakgeID=e3ef1fcf-23a3-45c6-8747-00d4e4854038, Action=None
# Package: e3ef1fcf-23a3-45c6-8747-00d4e4854038 processing...
# STEP:::PacakgeID=bf1ac37b-ac08-4e64-b170-e3c0c27796c2, Action=None
# STEP:::PacakgeID=6703e9f2-d791-48a1-81f8-000ae95ec082, Action=None
# Package: 6703e9f2-d791-48a1-81f8-000ae95ec082 processing...
# STEP:::PacakgeID=75ff6610-e7e8-4a41-8882-a1bd81b525b3, Action=None
# Package: 75ff6610-e7e8-4a41-8882-a1bd81b525b3 processing...
# STEP:::PacakgeID=e36514c4-24ae-41e8-9c71-57bc074d05fb, Action=None
# Package: e36514c4-24ae-41e8-9c71-57bc074d05fb processing...
# STEP:::PacakgeID=6dc9e950-9189-4a9b-9ba2-4fb879e3995c, Action=None
# Package: 6dc9e950-9189-4a9b-9ba2-4fb879e3995c processing...
# STEP:::PacakgeID=27664dcb-051a-4bfb-9261-ae3c68341b46, Action=None
# Package: 27664dcb-051a-4bfb-9261-ae3c68341b46 processing...
# STEP:::PacakgeID=28ffe2fb-320a-4779-b105-d72cf6b546e5, Action=None
# Package: 28ffe2fb-320a-4779-b105-d72cf6b546e5 processing...
# the new min_delay: 0.5932456451239609
# Time tick: 14.649110640673516, Total reward: -20.811373256509977
# ------------------------------------------------------STEP11------------------------------------------------------
# STEP:::PacakgeID=bbcc44cf-788d-459a-be0f-c840ff47189f, Action=None
# Package: bbcc44cf-788d-459a-be0f-c840ff47189f processing...
# STEP:::PacakgeID=7bf5d7dc-0961-4512-8d03-26f841401c81, Action=None
# STEP:::PacakgeID=d23ec060-6535-4b38-8955-244434fe5d0f, Action=None
# Package: d23ec060-6535-4b38-8955-244434fe5d0f processing...
# STEP:::PacakgeID=47206f87-02d3-4f53-92d4-45ad0f509eee, Action=None
# STEP:::PacakgeID=0adfd765-393a-4a95-bd63-3893be5f26d0, Action=None
# Package: 0adfd765-393a-4a95-bd63-3893be5f26d0 processing...
# STEP:::PacakgeID=933fa08f-98fb-4aa0-8d78-5cd3743bcb0c, Action=['s0', 's9']
# is on Route: s0->s9,
# package: 933fa08f-98fb-4aa0-8d78-5cd3743bcb0c removed from Route: s0->s9.
# Pack added to Node: s9;
# STEP:::PacakgeID=0385285b-1560-417d-93b2-b92932d79de7, Action=None
# Package: 0385285b-1560-417d-93b2-b92932d79de7 processing...
# STEP:::PacakgeID=742c697b-78b7-43ce-ab28-265e0aeb92fc, Action=None
# Package: 742c697b-78b7-43ce-ab28-265e0aeb92fc processing...
# STEP:::PacakgeID=45cef0ff-744f-4f62-81a8-d0103cae2869, Action=None
# Package: 45cef0ff-744f-4f62-81a8-d0103cae2869 processing...
# STEP:::PacakgeID=a422c0f6-876f-418d-b0a8-34841b266f2b, Action=None
# Package: a422c0f6-876f-418d-b0a8-34841b266f2b processing...
# STEP:::PacakgeID=e14ad120-3c24-40de-a638-70af1e45e1aa, Action=None
# Package: e14ad120-3c24-40de-a638-70af1e45e1aa processing...
# STEP:::PacakgeID=74813b16-d1e9-4e94-b78a-983459689fdc, Action=None
# Package: 74813b16-d1e9-4e94-b78a-983459689fdc processing...
# STEP:::PacakgeID=e3ef1fcf-23a3-45c6-8747-00d4e4854038, Action=None
# Package: e3ef1fcf-23a3-45c6-8747-00d4e4854038 processing...
# STEP:::PacakgeID=bf1ac37b-ac08-4e64-b170-e3c0c27796c2, Action=None
# STEP:::PacakgeID=6703e9f2-d791-48a1-81f8-000ae95ec082, Action=None
# Package: 6703e9f2-d791-48a1-81f8-000ae95ec082 processing...
# STEP:::PacakgeID=75ff6610-e7e8-4a41-8882-a1bd81b525b3, Action=None
# Package: 75ff6610-e7e8-4a41-8882-a1bd81b525b3 processing...
# STEP:::PacakgeID=e36514c4-24ae-41e8-9c71-57bc074d05fb, Action=None
# Package: e36514c4-24ae-41e8-9c71-57bc074d05fb processing...
# STEP:::PacakgeID=6dc9e950-9189-4a9b-9ba2-4fb879e3995c, Action=None
# Package: 6dc9e950-9189-4a9b-9ba2-4fb879e3995c processing...
# STEP:::PacakgeID=27664dcb-051a-4bfb-9261-ae3c68341b46, Action=None
# Package: 27664dcb-051a-4bfb-9261-ae3c68341b46 processing...
# STEP:::PacakgeID=28ffe2fb-320a-4779-b105-d72cf6b546e5, Action=None
# Package: 28ffe2fb-320a-4779-b105-d72cf6b546e5 processing...
# the new min_delay: 0.17984881605848102
# Time tick: 15.242356285797477, Total reward: -21.970079431517256
# ------------------------------------------------------STEP12------------------------------------------------------
# STEP:::PacakgeID=bbcc44cf-788d-459a-be0f-c840ff47189f, Action=None
# Package: bbcc44cf-788d-459a-be0f-c840ff47189f processing...
# STEP:::PacakgeID=7bf5d7dc-0961-4512-8d03-26f841401c81, Action=None
# STEP:::PacakgeID=d23ec060-6535-4b38-8955-244434fe5d0f, Action=None
# Package: d23ec060-6535-4b38-8955-244434fe5d0f processing...
# STEP:::PacakgeID=47206f87-02d3-4f53-92d4-45ad0f509eee, Action=None
# STEP:::PacakgeID=0adfd765-393a-4a95-bd63-3893be5f26d0, Action=None
# Package: 0adfd765-393a-4a95-bd63-3893be5f26d0 processing...
# STEP:::PacakgeID=933fa08f-98fb-4aa0-8d78-5cd3743bcb0c, Action=None
# Package: 933fa08f-98fb-4aa0-8d78-5cd3743bcb0c processing...
# STEP:::PacakgeID=0385285b-1560-417d-93b2-b92932d79de7, Action=None
# Package: 0385285b-1560-417d-93b2-b92932d79de7 processing...
# STEP:::PacakgeID=742c697b-78b7-43ce-ab28-265e0aeb92fc, Action=None
# Package: 742c697b-78b7-43ce-ab28-265e0aeb92fc processing...
# STEP:::PacakgeID=45cef0ff-744f-4f62-81a8-d0103cae2869, Action=None
# Package: 45cef0ff-744f-4f62-81a8-d0103cae2869 processing...
# STEP:::PacakgeID=a422c0f6-876f-418d-b0a8-34841b266f2b, Action=None
# Package: a422c0f6-876f-418d-b0a8-34841b266f2b processing...
# STEP:::PacakgeID=e14ad120-3c24-40de-a638-70af1e45e1aa, Action=None
# Package: e14ad120-3c24-40de-a638-70af1e45e1aa processing...
# STEP:::PacakgeID=74813b16-d1e9-4e94-b78a-983459689fdc, Action=None
# Package: 74813b16-d1e9-4e94-b78a-983459689fdc processing...
# STEP:::PacakgeID=e3ef1fcf-23a3-45c6-8747-00d4e4854038, Action=None
# Package: e3ef1fcf-23a3-45c6-8747-00d4e4854038 processing...
# STEP:::PacakgeID=bf1ac37b-ac08-4e64-b170-e3c0c27796c2, Action=None
# STEP:::PacakgeID=6703e9f2-d791-48a1-81f8-000ae95ec082, Action=['s6', 's23']
# is on Route: s6->s23,
# package: 6703e9f2-d791-48a1-81f8-000ae95ec082 removed from Route: s6->s23.
# Pack added to Node: s23;
# STEP:::PacakgeID=75ff6610-e7e8-4a41-8882-a1bd81b525b3, Action=None
# Package: 75ff6610-e7e8-4a41-8882-a1bd81b525b3 processing...
# STEP:::PacakgeID=e36514c4-24ae-41e8-9c71-57bc074d05fb, Action=None
# Package: e36514c4-24ae-41e8-9c71-57bc074d05fb processing...
# STEP:::PacakgeID=6dc9e950-9189-4a9b-9ba2-4fb879e3995c, Action=None
# Package: 6dc9e950-9189-4a9b-9ba2-4fb879e3995c processing...
# STEP:::PacakgeID=27664dcb-051a-4bfb-9261-ae3c68341b46, Action=None
# Package: 27664dcb-051a-4bfb-9261-ae3c68341b46 processing...
# STEP:::PacakgeID=28ffe2fb-320a-4779-b105-d72cf6b546e5, Action=None
# Package: 28ffe2fb-320a-4779-b105-d72cf6b546e5 processing...
# the new min_delay: 0.22690553881755804
# Time tick: 15.422205101855958, Total reward: -23.232022377929653
# ------------------------------------------------------STEP13------------------------------------------------------
# STEP:::PacakgeID=bbcc44cf-788d-459a-be0f-c840ff47189f, Action=None
# Package: bbcc44cf-788d-459a-be0f-c840ff47189f processing...
# STEP:::PacakgeID=7bf5d7dc-0961-4512-8d03-26f841401c81, Action=None
# STEP:::PacakgeID=d23ec060-6535-4b38-8955-244434fe5d0f, Action=None
# Package: d23ec060-6535-4b38-8955-244434fe5d0f processing...
# STEP:::PacakgeID=47206f87-02d3-4f53-92d4-45ad0f509eee, Action=None
# STEP:::PacakgeID=0adfd765-393a-4a95-bd63-3893be5f26d0, Action=['s19', 's14']
# is in Node: s19,
# package: 0adfd765-393a-4a95-bd63-3893be5f26d0 removed from Node: s19.
# Pack added to Route: s19->s14;
# STEP:::PacakgeID=933fa08f-98fb-4aa0-8d78-5cd3743bcb0c, Action=None
# Package: 933fa08f-98fb-4aa0-8d78-5cd3743bcb0c processing...
# STEP:::PacakgeID=0385285b-1560-417d-93b2-b92932d79de7, Action=None
# Package: 0385285b-1560-417d-93b2-b92932d79de7 processing...
# STEP:::PacakgeID=742c697b-78b7-43ce-ab28-265e0aeb92fc, Action=None
# Package: 742c697b-78b7-43ce-ab28-265e0aeb92fc processing...
# STEP:::PacakgeID=45cef0ff-744f-4f62-81a8-d0103cae2869, Action=None
# Package: 45cef0ff-744f-4f62-81a8-d0103cae2869 processing...
# STEP:::PacakgeID=a422c0f6-876f-418d-b0a8-34841b266f2b, Action=None
# Package: a422c0f6-876f-418d-b0a8-34841b266f2b processing...
# STEP:::PacakgeID=e14ad120-3c24-40de-a638-70af1e45e1aa, Action=None
# Package: e14ad120-3c24-40de-a638-70af1e45e1aa processing...
# STEP:::PacakgeID=74813b16-d1e9-4e94-b78a-983459689fdc, Action=None
# Package: 74813b16-d1e9-4e94-b78a-983459689fdc processing...
# STEP:::PacakgeID=e3ef1fcf-23a3-45c6-8747-00d4e4854038, Action=None
# Package: e3ef1fcf-23a3-45c6-8747-00d4e4854038 processing...
# STEP:::PacakgeID=bf1ac37b-ac08-4e64-b170-e3c0c27796c2, Action=None
# STEP:::PacakgeID=6703e9f2-d791-48a1-81f8-000ae95ec082, Action=None
# Package: 6703e9f2-d791-48a1-81f8-000ae95ec082 processing...
# STEP:::PacakgeID=75ff6610-e7e8-4a41-8882-a1bd81b525b3, Action=None
# Package: 75ff6610-e7e8-4a41-8882-a1bd81b525b3 processing...
# STEP:::PacakgeID=e36514c4-24ae-41e8-9c71-57bc074d05fb, Action=None
# Package: e36514c4-24ae-41e8-9c71-57bc074d05fb processing...
# STEP:::PacakgeID=6dc9e950-9189-4a9b-9ba2-4fb879e3995c, Action=None
# Package: 6dc9e950-9189-4a9b-9ba2-4fb879e3995c processing...
# STEP:::PacakgeID=27664dcb-051a-4bfb-9261-ae3c68341b46, Action=None
# Package: 27664dcb-051a-4bfb-9261-ae3c68341b46 processing...
# STEP:::PacakgeID=28ffe2fb-320a-4779-b105-d72cf6b546e5, Action=None
# Package: 28ffe2fb-320a-4779-b105-d72cf6b546e5 processing...
# the new min_delay: 0.7613330507186511
# Time tick: 15.649110640673516, Total reward: -24.032022377929653
# ------------------------------------------------------STEP14------------------------------------------------------
# STEP:::PacakgeID=bbcc44cf-788d-459a-be0f-c840ff47189f, Action=None
# Package: bbcc44cf-788d-459a-be0f-c840ff47189f processing...
# STEP:::PacakgeID=7bf5d7dc-0961-4512-8d03-26f841401c81, Action=None
# STEP:::PacakgeID=d23ec060-6535-4b38-8955-244434fe5d0f, Action=None
# Package: d23ec060-6535-4b38-8955-244434fe5d0f processing...
# STEP:::PacakgeID=47206f87-02d3-4f53-92d4-45ad0f509eee, Action=None
# STEP:::PacakgeID=0adfd765-393a-4a95-bd63-3893be5f26d0, Action=None
# Package: 0adfd765-393a-4a95-bd63-3893be5f26d0 processing...
# STEP:::PacakgeID=933fa08f-98fb-4aa0-8d78-5cd3743bcb0c, Action=None
# Package: 933fa08f-98fb-4aa0-8d78-5cd3743bcb0c processing...
# STEP:::PacakgeID=0385285b-1560-417d-93b2-b92932d79de7, Action=None
# Package: 0385285b-1560-417d-93b2-b92932d79de7 processing...
# STEP:::PacakgeID=742c697b-78b7-43ce-ab28-265e0aeb92fc, Action=None
# Package: 742c697b-78b7-43ce-ab28-265e0aeb92fc processing...
# STEP:::PacakgeID=45cef0ff-744f-4f62-81a8-d0103cae2869, Action=None
# Package: 45cef0ff-744f-4f62-81a8-d0103cae2869 processing...
# STEP:::PacakgeID=a422c0f6-876f-418d-b0a8-34841b266f2b, Action=None
# Package: a422c0f6-876f-418d-b0a8-34841b266f2b processing...
# STEP:::PacakgeID=e14ad120-3c24-40de-a638-70af1e45e1aa, Action=None
# Package: e14ad120-3c24-40de-a638-70af1e45e1aa processing...
# STEP:::PacakgeID=74813b16-d1e9-4e94-b78a-983459689fdc, Action=None
# Package: 74813b16-d1e9-4e94-b78a-983459689fdc processing...
# STEP:::PacakgeID=e3ef1fcf-23a3-45c6-8747-00d4e4854038, Action=None
# Package: e3ef1fcf-23a3-45c6-8747-00d4e4854038 processing...
# STEP:::PacakgeID=bf1ac37b-ac08-4e64-b170-e3c0c27796c2, Action=None
# STEP:::PacakgeID=6703e9f2-d791-48a1-81f8-000ae95ec082, Action=None
# Package: 6703e9f2-d791-48a1-81f8-000ae95ec082 processing...
# STEP:::PacakgeID=75ff6610-e7e8-4a41-8882-a1bd81b525b3, Action=None
# Package: 75ff6610-e7e8-4a41-8882-a1bd81b525b3 processing...
# STEP:::PacakgeID=e36514c4-24ae-41e8-9c71-57bc074d05fb, Action=None
# Package: e36514c4-24ae-41e8-9c71-57bc074d05fb processing...
# STEP:::PacakgeID=6dc9e950-9189-4a9b-9ba2-4fb879e3995c, Action=None
# Package: 6dc9e950-9189-4a9b-9ba2-4fb879e3995c processing...
# STEP:::PacakgeID=27664dcb-051a-4bfb-9261-ae3c68341b46, Action=None
# Package: 27664dcb-051a-4bfb-9261-ae3c68341b46 processing...
# STEP:::PacakgeID=28ffe2fb-320a-4779-b105-d72cf6b546e5, Action=['s1', 's2']
# Error! Undone package is neither on route or in node!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 14
#      12     print(f"------------------------------------------------------STEP{i}------------------------------------------------------")
#      13     actions = agent.choose_action()
# ---> 14     next_state, reward, done = env.step(actions)
#      15     print(f"Time tick: {env.TimeTick}, Total reward: {reward}")
#      17 # 检查所有包是否已到达目的地
#
# TypeError: cannot unpack non-iterable int object
