# %%
import data_gen
import uuid
import heapq

#generate stations, centers, packages.
data = data_gen.data_gen()
station_pos = data['station_pos']
station_prop = data['station_prop']
center_pos = data['center_pos']
center_prop = data['center_prop']
edges = data['edges']
packets = data['packets']

class Node:
    def __init__(self, id, pos, throughput, delay, cost, is_station=False):
        self.id = id
        self.pos = pos
        self.throughput = throughput
        self.delay = delay  # This delay should be updated based on the queue length and throughput
        self.cost = cost
        self.is_station = is_station
        self.packages = []  # Use a list for packages
        heapq.heapify(self.packages)  # Convert the list to a heap
        self.package_indices = {}  # 辅助字典用于快速查找包裹的索引

    def add_package(self, package):
        heapq.heappush(self.packages, (-package.delay, package))
        package.delay = self.delay
        self.package_indices[package.id] = len(self.packages) - 1  # 更新辅助字典
        print(f"Pack added to Node: {self.id};")

    def remove_package(self, package_id):
        if package_id in self.package_indices:
            index = self.package_indices.pop(package_id)
            # 直接移除指定索引的元素，并重新构建堆
            del self.packages[index]
            heapq.heapify(self.packages)
            self.package_indices = {pkg.id: i for i, (_, pkg) in enumerate(self.packages)}
            print(f"package: {package_id} removed from Node: {self.id}.")

    def __str__(self):
        # 获取所有包裹的 ID
        package_ids = [pkg.id for _, pkg in self.packages]
        # 将包裹 ID 转换为字符串并附加到节点信息中
        return f"Node({self.id}, {self.pos}, Throughput: {self.throughput}, Delay: {self.delay}, Cost: {self.cost}, Packages: {package_ids})"

class Route:
    def __init__(self, src, dst, time, cost):
        self.src = src
        self.dst = dst
        self.time = time
        self.cost = cost
        self.packages = []  # Use a list for packages on the route
        heapq.heapify(self.packages)  # Convert the list to a heap
        self.package_indices = {}  # 辅助字典用于快速查找包裹的索引

    def add_package(self, package):
        package.delay = self.time
        heapq.heappush(self.packages, (-package.delay, package))
        self.package_indices[package.id] = len(self.packages) - 1  # 更新辅助字典
        print(f"Pack added to Route: {self.src}->{self.dst};")

    def remove_package(self, package_id):
        if package_id in self.package_indices:
            index = self.package_indices.pop(package_id)
            # 直接移除指定索引的元素，并重新构建堆
            del self.packages[index]
            heapq.heapify(self.packages)
            self.package_indices = {pkg.id: i for i, (_, pkg) in enumerate(self.packages)}
            print(f"package: {package_id} removed from Route: {self.src}->{self.dst}.")

    def __str__(self):
        return f"Route({self.src}->{self.dst}, Time: {self.time}, Cost: {self.cost})"

class Package:
    def __init__(self, id, time_created, src, dst, category):
        self.id = id
        self.time_created = time_created
        self.src = src
        self.dst = dst
        self.curr = src
        self.category = category  # 'Express' or 'Standard'
        self.history = []  # List of nodes visited with timestamps
        self.path = []  # List of nodes on the expected path
        self.delay = 0  # Remaining delay before processing
        self.done = False
        self.reward = 0.0  # Current Reward/cost for this package

    def update_path(self, next_node):
        self.path.append(next_node)

    def mark_done(self):
        self.done = True

    def __lt__(self, other):
        # Ensure other is also a Package object
        if not isinstance(other, Package):
            return False

        # Define comparison for priority queue
        # Express packages have higher priority
        if self.category == 'Express' and other.category != 'Express':
            return True
        if self.category != 'Express' and other.category == 'Express':
            return False
        # Otherwise, compare based on time created
        return self.time_created < other.time_created

    def __eq__(self, other):
        # Ensure other is also a Package object
        if not isinstance(other, Package):
            return False

        # Define comparison for priority queue
        # Express packages have higher priority
        if self.category == 'Express' and other.category != 'Express':
            return True
        if self.category != 'Express' and other.category == 'Express':
            return False
        # Otherwise, compare based on time created
        return self.time_created == other.time_created

    def __str__(self):
        return f"Package({self.id}, TimeCreated: {self.time_created}, Src: {self.src}, Dst: {self.dst}, Category: {self.category})"

class LogisticsEnv:
    def __init__(self):
        self.nodes = {}  # Dictionary of nodes
        self.routes = {}  # Dictionary of routes
        self.packages = {}  # Dictionary of packages
        self.min_delay = float('inf')  # Minimum delay for all packages
        self.TimeTick = 0.0  # Current time tick
        self.done = False

    def reset(self):
        self.nodes = {}  # Dictionary of nodes
        self.routes = {}  # Dictionary of routes
        self.packages = {}  # Dictionary of packages

        # Initialize nodes, routes, and packages
        # Add stations as nodes
        for i in range(len(station_pos)):
            p = self.add_node(f"s{i}", station_pos[i], *station_prop[i], is_station=True)
            #print(f"Center({p.id}, {p.pos}, Throughput: {p.throughput}, Delay: {p.delay}, Cost: {p.cost}), is_station: {p.is_station}")

        # Add centers as nodes
        for i in range(len(center_pos)):
            p = self.add_node(f"c{i}", center_pos[i], *center_prop[i])
            #print(f"Center({p.id}, {p.pos}, Throughput: {p.throughput}, Delay: {p.delay}, Cost: {p.cost}), is_station: {p.is_station}")

        # Add edges as routes
        for edge in edges:
            p = self.add_route(edge[0], edge[1], edge[2], edge[3])
            #print(f"Route({p.src}->{p.dst}, Time: {p.time}, Cost: {p.cost})")

        # Add packets as packages
        for packet in packets:
            p = self.add_package(uuid.uuid4(), *packet)
            print(f"Package {p.id} added, delay={p.delay}, src={p.src}, curr={p.curr}, dst={p.dst}, done={p.done}, path={p.path}")
        
        for package in self.packages.values():
            self.min_delay = package.delay if self.min_delay>package.delay and package.delay>0 else self.min_delay
        for node in self.nodes.values():
            print(node)
        self.TimeTick = 0.0  # Current time tick
        print(f"Env reset. min_delay={self.min_delay}, TimeTick={self.TimeTick}")

        return self.get_state()

    def add_node(self, id, pos, throughput, delay, cost, is_station=False):
        self.nodes[id] = Node(id, pos, throughput, delay, cost, is_station)
        return self.nodes[id]

    def add_route(self, src, dst, time, cost):
        self.routes[(src, dst)] = Route(src, dst, time, cost)
        return self.routes[(src, dst)]

    def add_package(self, id, time_created, src, dst, category):
        package = Package(id, time_created, src, dst, category)
        
        # Calculate the initial optimal路径 based on the package's category
        if category == 'Express':
            # 对于Express包裹，找到最短的总时间路径
            optimal_path = self.find_shortest_time_path(src, dst)
        else:
            # 对于Standard包裹，找到最低的总成本路径
            optimal_path = self.find_lowest_cost_path(src, dst)
        
        package.path = optimal_path  # 将最优路径初始化为包裹的路径
        self.packages[id] = package
        self.nodes[src].add_package(package)  # 添加到优先队列中
        return package

    def find_shortest_time_path(self, src, dst):
        # Initialize distances and visited nodes
        distances = {node: float('inf') for node in self.nodes}  # Use a very large number instead of infinity
        distances[src] = 0
        visited = set()

        # Initialize priority queue with the source node
        pq = [(0, src, 0)]  # (distance, current_node, total_time)

        while pq:
            current_distance, current_node, current_time = heapq.heappop(pq)

            # If the node has already been visited, skip it
            if current_node in visited:
                continue

            visited.add(current_node)

            # Check neighbors of the current node
            for route in self.routes.values():
                if route.src == current_node and route.dst not in visited:
                    # Calculate the new distance and time
                    new_distance = current_distance + route.time
                    new_time = current_time + route.time + self.nodes[current_node].delay

                    # If this is a shorter path, update the distances and add to the priority queue
                    if new_distance < distances[route.dst]:
                        distances[route.dst] = new_distance
                        heapq.heappush(pq, (new_distance, route.dst, new_time))

        # Construct the path from the source to the destination
        path = []
        current_node = dst
        while current_node != src:
            path.append(current_node)
            # 选择下一个节点，不检查是否已经在路径中
            # 使用 self.routes 来获取当前节点的实际对象
            current_node = min(
                [route.dst for route in self.routes.values() if route.src == current_node],
                key=lambda x: distances[x],
                default=None
            )
            if current_node is None:
                # No path found
                return []
        path.append(src)
        path.reverse()

        return path
    
    def find_lowest_cost_path(self, src, dst):
        # Initialize distances and visited nodes
        distances = {node: float('infinity') for node in self.nodes}
        distances[src] = 0
        visited = set()

        # Initialize priority queue with the source node
        pq = [(0, src)]  # (distance, current_node)

        while pq:
            current_distance, current_node = heapq.heappop(pq)

            # If the node has already been visited, skip it
            if current_node in visited:
                continue

            visited.add(current_node)

            # Check neighbors of the current node
            for route in self.routes.values():
                if route.src == current_node and route.dst not in visited:
                    # Calculate the new distance
                    new_distance = current_distance + route.cost + self.nodes[current_node].cost

                    # If this is a lower distance, update the distances and add to the priority queue
                    if new_distance < distances[route.dst]:
                        distances[route.dst] = new_distance
                        heapq.heappush(pq, (new_distance, route.dst))

        # Construct the path from the source to the destination
        path = []
        current_node = dst
        while current_node != src:
            path.append(current_node)
            # 选择下一个节点，使用 (current_node, neighbor) 来检查路由是否存在
            previous_node = min(
                [route.dst for route in self.routes.values() if route.src == current_node],
                key=lambda x: distances[x],
                default=None
            )
            if previous_node is None:
                # No path found
                return []
            current_node = previous_node

        path.append(src)
        path.reverse()

        return path

    def get_policy(self, package):
        if package.category == 'Express':
            # For Express packages, find the shortest total time path
            return self.find_shortest_time_path(package.curr, package.dst)
        else:
            # For Standard packages, find the lowest total cost path
            return self.find_lowest_cost_path(package.curr, package.dst)

    def step(self, actions):
        self.TimeTick += self.min_delay  # 更新时间
        # 更新所有包裹的延迟
        for package in self.packages.values():
            package.delay -= self.min_delay
        # 遍历所有动作
        for package_id, action in actions.items():
            print(f"STEP:::PacakgeID={package_id}, Action={action}")
            package = self.packages[package_id]  # 使用 package_id 获取包裹
            if package.done:
                package.reward = 0
                continue
            elif package.delay <= 0:  # 包裹准备好转移状态
                if action is not None:
                    node = self.nodes[action[0]]
                    next_node = self.nodes[action[1]]
                    route = self.routes[(action[0], action[1])]
                    if package_id in node.package_indices:  # 包裹位于Node
                        print(f"is in Node: {node.id},")
                        node.remove_package(package_id)
                        route.add_package(package)
                        # 更新包裹的历史、当前所在的节点
                        package.history.append((self.TimeTick, package.curr))
                        package.curr = node.id
                        # 计算包裹的reward
                        if package.category == 'Express':
                            package.reward -= self.min_delay
                        else:
                            package.reward -= node.cost
                    elif package_id in route.package_indices:  # 包裹位于Route
                        print(f"is on Route: {route.src}->{route.dst},")
                        if len(node.packages) < node.throughput:
                            route.remove_package(package_id)
                            next_node.add_package(package)
                            # 更新包裹的历史、Route起点的节点
                            package.history.append((self.TimeTick, package.curr))
                            package.curr = next_node.id
                            # 计算包裹的reward
                            if package.category == 'Express':
                                package.reward -= self.min_delay
                            else:
                                package.reward -= route.cost
                        else: # 包裹滞留在当前Route无法进站
                            print(f"waiting..., Node: {route.dst} full")
                            if package.category == 'Express':
                                package.reward -= self.min_delay
                    else:
                        print("Error! Undone package is neither on route or in node!")
                        return 0
                else:  # 包裹准备好转移状态，但动作是None
                    print(f"This should not happen! Package: {package_id} is ready but action is None.")
                    if package.category == 'Express':
                        package.reward -= self.min_delay
            else:
                print(f"Package: {package_id} processing...")
                # package正在Route或者Node中处理
                if package.category == 'Express':
                    package.reward -= self.min_delay
        #判断是否有新的package变成done,顺便计算当前的reward,顺便判断是否done
        self.done = True
        curr_reward = 0
        self.min_delay = float('inf')
        for package in self.packages.values():
            if not package.done: #对于之前没有done的package
                curr_reward +=package.reward #累加reward
                if package.curr == package.dst: #该节点是否刚到done
                    package.history.append((self.TimeTick, package.curr))
                    next_node.remove_package(package_id)
                    package.done = True
                    package.delay = float('inf')
                else:
                    self.done = False #如果还有undone package，那么整个环境就没有done
                    #print(f"undone package {package.id} at {package.curr} has delay: {package.delay}")
                    self.min_delay = package.delay if package.delay>0 and (package.delay < self.min_delay) else self.min_delay
        print(f"the new min_delay: {self.min_delay}")
        return self.get_state(), curr_reward, self.done

    def get_reward(self, package):
        # Calculate the reward based on package category and time passed
        if package.category == 'Express':
            reward = package.time_created - self.TimeTick #TODO re-scale the reward to be compatible with the route cost
        else:
            # Calculate the cost based on package history and node/route costs
            total_cost = 0
            for timestamp,node_id in package.history:
                total_cost += self.nodes[node_id].cost
            for route in package.path:
                total_cost += self.routes[route].cost
            reward = -total_cost  # Negative cost as a reward for minimizing costs

        # If the package has reached its destination, update its delay to zero and mark it as done
        if package.src == package.dst:
            package.delay = 0
            package.mark_done()

        return reward
    
    def get_state(self):
        # Create a state representation that includes relevant information for decision-making
        state = {
            'package_positions': self.get_package_positions(),
            'package_destinations': self.get_package_destinations(),
            'package_categories': self.get_package_categories(),
            'queue_lengths': self.get_queue_lengths(),
            'route_loads': self.get_route_loads(),
            'current_time_tick': self.TimeTick
        }
        return state

    def get_package_positions(self):
        # Return a dictionary with package IDs as keys and their current node IDs as values
        positions = {pkg_id: pkg.src for pkg_id, pkg in self.packages.items()}
        return positions

    def get_package_destinations(self):
        # Return a dictionary with package IDs as keys and their destination node IDs as values
        destinations = {pkg_id: pkg.dst for pkg_id, pkg in self.packages.items()}
        return destinations

    def get_package_categories(self):
        # Return a dictionary with package IDs as keys and their categories as values
        categories = {pkg_id: pkg.category for pkg_id, pkg in self.packages.items()}
        return categories

    def get_queue_lengths(self):
        # Return a dictionary with node IDs as keys and the number of packages in their queues as values
        queue_lengths = {node_id: len(node.packages) for node_id, node in self.nodes.items()}
        return queue_lengths

    def get_route_loads(self):
        # Return a dictionary with route tuples (src, dst) as keys and the number of packages on the route as values
        route_loads = {route_tuple: len(route.packages) for route_tuple, route in self.routes.items()}
        return route_loads

class Agent:
    def __init__(self, env):
        self.env = env
        self.state = None
        self.total_reward = 0.0
        self.action_history = []

    def reset(self):
        self.state = None
        self.total_reward = 0.0
        self.action_history = []

    def choose_action(self):
        actions = {}
        for package_id, package in self.env.packages.items():
            if package.delay > self.env.min_delay:
                # If the package's delay is positive, do nothing
                actions[package_id] = None
            else:
                # Call the get_policy method to get the next node in the optimal path
                next_node = self.env.get_policy(package)
                # Select the neighboring node to be the destination
                if next_node and next_node != package.src and next_node != package.dst:
                    actions[package_id] = next_node[:2]
                else:
                    actions[package_id] = None  # No valid action found
            #print(f"action for {package_id} is {actions[package_id]}.")
        return actions
# Out:
# Stations:
# s0 (99, 33) (10, 2, 0.5)
# s1 (18, 96) (20, 1, 0.8)
# s2 (54, 43) (25, 1, 0.9)
# s3 (56, 19) (25, 1, 0.9)
# s4 (91, 47) (10, 2, 0.5)
# s5 (90, 44) (15, 2, 0.6)
# s6 (90, 41) (10, 2, 0.5)
# s7 (100, 67) (10, 2, 0.5)
# s8 (77, 26) (15, 2, 0.6)
# s9 (64, 38) (20, 1, 0.8)
# s10 (78, 64) (10, 2, 0.5)
# s11 (71, 36) (15, 2, 0.6)
# s12 (4, 32) (20, 1, 0.8)
# s13 (100, 91) (20, 1, 0.8)
# s14 (39, 63) (25, 1, 0.9)
# s15 (40, 9) (25, 1, 0.9)
# s16 (44, 92) (10, 2, 0.5)
# s17 (1, 73) (15, 2, 0.6)
# s18 (87, 93) (20, 1, 0.8)
# s19 (6, 47) (15, 2, 0.6)
# s20 (53, 63) (20, 1, 0.8)
# s21 (80, 64) (10, 2, 0.5)
# s22 (16, 6) (20, 1, 0.8)
# s23 (53, 72) (15, 2, 0.6)
# s24 (30, 69) (25, 1, 0.9)
# Centers:
# c0 (37, 11) (125, 1, 0.5)
# c1 (52, 55) (175, 1, 0.5)
# c2 (86, 46) (175, 1, 0.5)
# c3 (17, 68) (100, 2, 0.5)
# c4 (93, 92) (125, 1, 0.5)
# Edges (center to center):
# ('c0', 'c1', 11.621639299169459, 9.297311439335568)
# ('c1', 'c0', 11.621639299169459, 9.297311439335568)
# ('c0', 'c2', 15.054069217324598, 12.04325537385968)
# ('c2', 'c0', 15.054069217324598, 12.04325537385968)
# ('c0', 'c3', 15.101738310538956, 12.081390648431166)
# ('c3', 'c0', 15.101738310538956, 12.081390648431166)
# ('c0', 'c4', 24.618336661927426, 19.69466932954194)
# ('c4', 'c0', 24.618336661927426, 19.69466932954194)
# ('c1', 'c2', 8.792752697534487, 7.03420215802759)
# ('c2', 'c1', 8.792752697534487, 7.03420215802759)
# ('c1', 'c3', 9.334077351297235, 7.467261881037789)
# ('c3', 'c1', 9.334077351297235, 7.467261881037789)
# ('c1', 'c4', 13.806701271484076, 11.045361017187261)
# ('c4', 'c1', 13.806701271484076, 11.045361017187261)
# ('c2', 'c3', 18.105593058499906, 14.484474446799926)
# ('c3', 'c2', 18.105593058499906, 14.484474446799926)
# ('c2', 'c4', 11.632390124131842, 9.305912099305473)
# ('c4', 'c2', 11.632390124131842, 9.305912099305473)
# ('c3', 'c4', 19.924858845171276, 15.93988707613702)
# ('c4', 'c3', 19.924858845171276, 15.93988707613702)
# Edges (center to station):
# ('c0', 's3', 12.369316876852983, 2.4738633753705965)
# ('s3', 'c0', 12.369316876852983, 2.4738633753705965)
# ('c0', 's15', 2.1633307652783933, 0.4326661530556787)
# ('s15', 'c0', 2.1633307652783933, 0.4326661530556787)
# ('c0', 's22', 12.95221988695374, 2.590443977390748)
# ('s22', 'c0', 12.95221988695374, 2.590443977390748)
# ('c1', 's2', 7.2993150363578625, 1.4598630072715726)
# ('s2', 'c1', 7.2993150363578625, 1.4598630072715726)
# ('c1', 's9', 12.485191228010887, 2.4970382456021776)
# ('s9', 'c1', 12.485191228010887, 2.4970382456021776)
# ('c1', 's14', 9.158602513484247, 1.8317205026968495)
# ('s14', 'c1', 9.158602513484247, 1.8317205026968495)
# ('c1', 's20', 4.8373546489791295, 0.9674709297958258)
# ('s20', 'c1', 4.8373546489791295, 0.9674709297958258)
# ('c1', 's23', 10.21763181955584, 2.0435263639111683)
# ('s23', 'c1', 10.21763181955584, 2.0435263639111683)
# ('c2', 's0', 11.030865786510141, 2.206173157302028)
# ('s0', 'c2', 11.030865786510141, 2.206173157302028)
# ('c2', 's4', 3.0594117081556704, 0.6118823416311341)
# ('s4', 'c2', 3.0594117081556704, 0.6118823416311341)
# ('c2', 's5', 2.6832815729997477, 0.5366563145999496)
# ('s5', 'c2', 2.6832815729997477, 0.5366563145999496)
# ('c2', 's6', 3.841874542459709, 0.7683749084919418)
# ('s6', 'c2', 3.841874542459709, 0.7683749084919418)
# ('c2', 's7', 15.143315356948754, 3.028663071389751)
# ('s7', 'c2', 15.143315356948754, 3.028663071389751)
# ('c2', 's8', 13.159027319676785, 2.631805463935357)
# ('s8', 'c2', 13.159027319676785, 2.631805463935357)
# ('c2', 's10', 11.818629362155324, 2.363725872431065)
# ('s10', 'c2', 11.818629362155324, 2.363725872431065)
# ('c2', 's11', 10.816653826391967, 2.1633307652783933)
# ('s11', 'c2', 10.816653826391967, 2.1633307652783933)
# ('c2', 's21', 11.384199576606166, 2.276839915321233)
# ('s21', 'c2', 11.384199576606166, 2.276839915321233)
# ('c3', 's1', 16.81071087134628, 3.362142174269256)
# ('s1', 'c3', 16.81071087134628, 3.362142174269256)
# ('c3', 's12', 22.965191050805565, 4.593038210161113)
# ('s12', 'c3', 22.965191050805565, 4.593038210161113)
# ('c3', 's16', 21.67487024182613, 4.3349740483652255)
# ('s16', 'c3', 21.67487024182613, 4.3349740483652255)
# ('c3', 's17', 10.057832768544126, 2.011566553708825)
# ('s17', 'c3', 10.057832768544126, 2.011566553708825)
# ('c3', 's19', 14.223923509355636, 2.844784701871127)
# ('s19', 'c3', 14.223923509355636, 2.844784701871127)
# ('c3', 's24', 7.8230428862431785, 1.5646085772486358)
# ('s24', 'c3', 7.8230428862431785, 1.5646085772486358)
# ('c4', 's13', 4.242640687119285, 0.848528137423857)
# ('s13', 'c4', 4.242640687119285, 0.848528137423857)
# ('c4', 's18', 3.6496575181789312, 0.7299315036357863)
# ('s18', 'c4', 3.6496575181789312, 0.7299315036357863)
# Edges (station to station):
# ('s3', 's2', 19.266551326067674, 1.6858232410309215)
# ('s2', 's3', 19.266551326067674, 1.6858232410309215)
# ('s4', 's0', 12.899612397277679, 1.128716084761797)
# ('s0', 's4', 12.899612397277679, 1.128716084761797)
# ('s5', 's0', 11.370136322841518, 0.9948869282486328)
# ('s0', 's5', 11.370136322841518, 0.9948869282486328)
# ('s5', 's4', 2.529822128134704, 0.22135943621178658)
# ('s4', 's5', 2.529822128134704, 0.22135943621178658)
# ('s6', 's0', 9.633275663033837, 0.8429116205154608)
# ('s0', 's6', 9.633275663033837, 0.8429116205154608)
# ('s6', 's4', 4.866210024238576, 0.4257933771208754)
# ('s4', 's6', 4.866210024238576, 0.4257933771208754)
# ('s6', 's5', 2.4000000000000004, 0.21000000000000002)
# ('s5', 's6', 2.4000000000000004, 0.21000000000000002)
# ('s7', 's4', 17.54536975956905, 1.5352198539622917)
# ('s4', 's7', 17.54536975956905, 1.5352198539622917)
# ('s7', 's5', 20.063897926375127, 1.7555910685578235)
# ('s5', 's7', 20.063897926375127, 1.7555910685578235)
# ('s7', 's6', 22.285421243494593, 1.949974358805777)
# ('s6', 's7', 22.285421243494593, 1.949974358805777)
# ('s8', 's0', 18.469434208984314, 1.6160754932861277)
# ('s0', 's8', 18.469434208984314, 1.6160754932861277)
# ('s8', 's2', 22.880559433720148, 2.002048950450513)
# ('s2', 's8', 22.880559433720148, 2.002048950450513)
# ('s8', 's3', 17.708754896942924, 1.5495160534825059)
# ('s3', 's8', 17.708754896942924, 1.5495160534825059)
# ('s8', 's4', 20.19108714259834, 1.766720124977355)
# ('s4', 's8', 20.19108714259834, 1.766720124977355)
# ('s8', 's5', 17.762882648939616, 1.5542522317822165)
# ('s5', 's8', 17.762882648939616, 1.5542522317822165)
# ('s8', 's6', 15.879546593023367, 1.3894603268895447)
# ('s6', 's8', 15.879546593023367, 1.3894603268895447)
# ('s9', 's2', 8.94427190999916, 0.7826237921249265)
# ('s2', 's9', 8.94427190999916, 0.7826237921249265)
# ('s9', 's3', 16.492422502470642, 1.4430869689661814)
# ('s3', 's9', 16.492422502470642, 1.4430869689661814)
# ('s9', 's4', 22.768399153212332, 1.9922349259060792)
# ('s4', 's9', 22.768399153212332, 1.9922349259060792)
# ('s9', 's5', 21.346662502602136, 1.867832968977687)
# ('s5', 's9', 21.346662502602136, 1.867832968977687)
# ('s9', 's6', 20.938003725283842, 1.8320753259623361)
# ('s6', 's9', 20.938003725283842, 1.8320753259623361)
# ('s9', 's8', 14.153444810363306, 1.2384264209067892)
# ('s8', 's9', 14.153444810363306, 1.2384264209067892)
# ('s10', 's4', 17.120747647226157, 1.4980654191322889)
# ('s4', 's10', 17.120747647226157, 1.4980654191322889)
# ('s10', 's5', 18.659046063504963, 1.6326665305566843)
# ('s5', 's10', 18.659046063504963, 1.6326665305566843)
# ('s10', 's6', 20.753794833716555, 1.8159570479501987)
# ('s6', 's10', 20.753794833716555, 1.8159570479501987)
# ('s10', 's7', 17.762882648939616, 1.5542522317822165)
# ('s7', 's10', 17.762882648939616, 1.5542522317822165)
# ('s10', 's9', 23.62371689637344, 2.0670752284326763)
# ('s9', 's10', 23.62371689637344, 2.0670752284326763)
# ('s11', 's0', 22.52820454452596, 1.9712178976460215)
# ('s0', 's11', 22.52820454452596, 1.9712178976460215)
# ('s11', 's2', 14.707821048680188, 1.2869343417595165)
# ('s2', 's11', 14.707821048680188, 1.2869343417595165)
# ('s11', 's3', 18.137254478007417, 1.5870097668256489)
# ('s3', 's11', 18.137254478007417, 1.5870097668256489)
# ('s11', 's4', 18.260339536821323, 1.597779709471866)
# ('s4', 's11', 18.260339536821323, 1.597779709471866)
# ('s11', 's5', 16.492422502470642, 1.4430869689661814)
# ('s5', 's11', 16.492422502470642, 1.4430869689661814)
# ('s11', 's6', 15.7175061635108, 1.3752817893071951)
# ('s6', 's11', 15.7175061635108, 1.3752817893071951)
# ('s11', 's8', 9.329523031752482, 0.8163332652783422)
# ('s8', 's11', 9.329523031752482, 0.8163332652783422)
# ('s11', 's9', 5.824087911424415, 0.5096076922496363)
# ('s9', 's11', 5.824087911424415, 0.5096076922496363)
# ('s11', 's10', 23.0893915034589, 2.020321756552654)
# ('s10', 's11', 23.0893915034589, 2.020321756552654)
# ('s13', 's7', 19.200000000000003, 1.6800000000000002)
# ('s7', 's13', 19.200000000000003, 1.6800000000000002)
# ('s14', 's2', 20.0, 1.7500000000000002)
# ('s2', 's14', 20.0, 1.7500000000000002)
# ('s15', 's3', 15.094369811290566, 1.3207573584879246)
# ('s3', 's15', 15.094369811290566, 1.3207573584879246)
# ('s16', 's1', 21.04471430074545, 1.841412501315227)
# ('s1', 's16', 21.04471430074545, 1.841412501315227)
# ('s16', 's14', 23.54230235129946, 2.0599514557387026)
# ('s14', 's16', 23.54230235129946, 2.0599514557387026)
# ('s17', 's1', 22.880559433720148, 2.002048950450513)
# ('s1', 's17', 22.880559433720148, 2.002048950450513)
# ('s18', 's7', 23.255106965997815, 2.034821859524809)
# ('s7', 's18', 23.255106965997815, 2.034821859524809)
# ('s18', 's13', 10.522357150372725, 0.9207062506576135)
# ('s13', 's18', 10.522357150372725, 0.9207062506576135)
# ('s19', 's12', 12.106196760337246, 1.0592922165295091)
# ('s12', 's19', 12.106196760337246, 1.0592922165295091)
# ('s19', 's17', 21.181123671797963, 1.8533483212823219)
# ('s17', 's19', 21.181123671797963, 1.8533483212823219)
# ('s20', 's2', 16.01998751560063, 1.4017489076150553)
# ('s2', 's20', 16.01998751560063, 1.4017489076150553)
# ('s20', 's9', 21.85040045399626, 1.911910039724673)
# ('s9', 's20', 21.85040045399626, 1.911910039724673)
# ('s20', 's10', 20.015993605114886, 1.7513994404475528)
# ('s10', 's20', 20.015993605114886, 1.7513994404475528)
# ('s20', 's14', 11.200000000000001, 0.9800000000000001)
# ('s14', 's20', 11.200000000000001, 0.9800000000000001)
# ('s21', 's4', 16.19876538505327, 1.4173919711921612)
# ('s4', 's21', 16.19876538505327, 1.4173919711921612)
# ('s21', 's5', 17.88854381999832, 1.565247584249853)
# ('s5', 's21', 17.88854381999832, 1.565247584249853)
# ('s21', 's6', 20.063897926375127, 1.7555910685578235)
# ('s6', 's21', 20.063897926375127, 1.7555910685578235)
# ('s21', 's7', 16.178998732925347, 1.415662389130968)
# ('s7', 's21', 16.178998732925347, 1.415662389130968)
# ('s21', 's10', 1.6, 0.14)
# ('s10', 's21', 1.6, 0.14)
# ('s21', 's11', 23.528705871764387, 2.0587617637793842)
# ('s11', 's21', 23.528705871764387, 2.0587617637793842)
# ('s21', 's18', 23.86629422428208, 2.088300744624682)
# ('s18', 's21', 23.86629422428208, 2.088300744624682)
# ('s21', 's20', 21.614809737770074, 1.8912958520548817)
# ('s20', 's21', 21.614809737770074, 1.8912958520548817)
# ('s22', 's12', 22.908513701242168, 2.0044949488586896)
# ('s12', 's22', 22.908513701242168, 2.0044949488586896)
# ('s22', 's15', 19.349418595916518, 1.6930741271426955)
# ('s15', 's22', 19.349418595916518, 1.6930741271426955)
# ('s23', 's2', 23.213789005675054, 2.0312065379965674)
# ('s2', 's23', 23.213789005675054, 2.0312065379965674)
# ('s23', 's10', 20.9990475974507, 1.8374166647769365)
# ('s10', 's23', 20.9990475974507, 1.8374166647769365)
# ('s23', 's14', 13.314653581674591, 1.165032188396527)
# ('s14', 's23', 13.314653581674591, 1.165032188396527)
# ('s23', 's16', 17.54536975956905, 1.5352198539622917)
# ('s16', 's23', 17.54536975956905, 1.5352198539622917)
# ('s23', 's20', 7.2, 0.6300000000000001)
# ('s20', 's23', 7.2, 0.6300000000000001)
# ('s23', 's21', 22.52820454452596, 1.9712178976460215)
# ('s21', 's23', 22.52820454452596, 1.9712178976460215)
# ('s24', 's1', 23.637258724310655, 2.068260138377182)
# ('s1', 's24', 23.637258724310655, 2.068260138377182)
# ('s24', 's14', 8.653323061113575, 0.7571657678474378)
# ('s14', 's24', 8.653323061113575, 0.7571657678474378)
# ('s24', 's16', 21.54065922853802, 1.8848076824970765)
# ('s16', 's24', 21.54065922853802, 1.8848076824970765)
# ('s24', 's17', 23.419649869287117, 2.049219363562623)
# ('s17', 's24', 23.419649869287117, 2.049219363562623)
# ('s24', 's20', 19.01578291840754, 1.66388100536066)
# ('s20', 's24', 19.01578291840754, 1.66388100536066)
# ('s24', 's23', 18.555861607589122, 1.6236378906640483)
# ('s23', 's24', 18.555861607589122, 1.6236378906640483)
# Packets:
# 5c0901ca-2b50-4c2c-b5cd-b50a1c9f82c0 (3.2361081268679586, 's16', 's23', 0)
# d80a413a-05a5-47da-92a4-1de32d2ccf8d (3.492599006445968, 's5', 's0', 0)
# ac943d62-da03-425f-94c4-91a801b00b84 (3.5694760438742428, 's7', 's8', 0)
# 9029e86e-379c-4bed-a9ae-c769adc1bb69 (3.6788221788926796, 's16', 's8', 1)
# 61045d7e-5108-4d52-80d7-379b3c3022d4 (3.789684688043619, 's1', 's17', 0)
# 9e150f14-6c88-46e0-b6b7-365a7ad57ca8 (4.620317835809088, 's16', 's19', 0)
# 79ebfd44-0dad-4f1b-958d-79fda6e2219b (5.172443979451737, 's14', 's6', 0)
# e71d2095-9c49-4a0b-bffe-4de3117b80d8 (5.880493712604133, 's22', 's16', 0)
# b2017409-8d00-4575-a22e-699816a6365e (6.442020741588216, 's1', 's5', 1)
# b27db023-9693-40bc-8414-785c5b2aef6b (7.12075394165862, 's22', 's20', 0)
# 92a5cb2a-02e6-4c7d-85d1-58ef8a0f9e7d (7.737499353202324, 's17', 's14', 0)
# 3db4dcd8-000c-471b-8aef-b7d71a3484ec (8.359384216909433, 's6', 's19', 0)
# 09b1f46f-03e8-4caf-93bc-c78ac5bdbfcb (8.444970530971748, 's1', 's3', 0)
# d06b847c-7016-421c-8688-f8615fd7d74e (8.631125605245368, 's1', 's5', 0)
# 6943e57c-1d62-42c9-a017-7addf7c26d17 (9.337478962746681, 's19', 's0', 0)
# 8f0bf70a-5e12-4564-9a54-1d6ea8364a50 (10.011461340684587, 's6', 's18', 0)
# 034abde1-e6f2-4322-aaa9-62d481ed63bc (10.826510022461457, 's17', 's18', 0)
# b10df997-9473-4df2-a230-c6c42a1680f2 (11.046950936334252, 's24', 's10', 0)
# 11a172b8-fc2f-4216-a537-c0d77c5c27b1 (11.409266758065407, 's17', 's19', 0)
# d93019d7-e54f-4e39-a58c-d0f666f9758a (11.902514869978194, 's1', 's16', 0)

# %%
env = LogisticsEnv()
state = env.reset()

# 创建代理
agent = Agent(env)

# 模拟几个时间步
i=0
done = False
while (not done):
    i+=1
    print(f"------------------------------------------------------STEP{i}------------------------------------------------------")
    actions = agent.choose_action()
    next_state, reward, done = env.step(actions)
    print(f"Time tick: {env.TimeTick}, Total reward: {reward}")

# 检查所有包是否已到达目的地
for package_id in env.packages:
    package = env.packages[package_id]
    if not package.done:
        print(f"Package {package_id} did not reach the destination.")
        break
else:
    print("All packages have reached the destination.")
# Out:
# Pack added to Node: s16;
# Package c0776743-a7a3-4d23-a0b7-87eab8f0df25 added, delay=2, src=s16, curr=s16, dst=s23, done=False, path=['s16', 's23']
# Pack added to Node: s5;
# Package fd9c5054-5b18-4990-b5df-bfe9856bcb01 added, delay=2, src=s5, curr=s5, dst=s0, done=False, path=['s5', 's0']
# Pack added to Node: s7;
# Package d4b246ad-7a2b-4fb0-bf8e-2c234e313772 added, delay=2, src=s7, curr=s7, dst=s8, done=False, path=['s7', 's4', 's8']
# Pack added to Node: s16;
# Package 3c07f007-4111-464e-a1f3-74a2c5dc2a34 added, delay=2, src=s16, curr=s16, dst=s8, done=False, path=['s16', 's23', 's2', 's8']
# Pack added to Node: s1;
# Package 12e7397a-6881-4c32-80d0-204e33dda476 added, delay=1, src=s1, curr=s1, dst=s17, done=False, path=['s1', 's17']
# Pack added to Node: s16;
# Package 4c6a07b2-70d6-47ec-8134-49c6b41840df added, delay=2, src=s16, curr=s16, dst=s19, done=False, path=['s16', 'c3', 's19']
# Pack added to Node: s14;
# Package bb5835ff-64fd-430a-a7c8-2ad45dc737fe added, delay=1, src=s14, curr=s14, dst=s6, done=False, path=['s14', 's20', 's9', 's6']
# Pack added to Node: s22;
# Package d0d702cb-979d-4e19-b0c6-29a80b7166d2 added, delay=1, src=s22, curr=s22, dst=s16, done=False, path=['s22', 's12', 'c3', 's16']
# Pack added to Node: s1;
# Package 114532a3-fdf2-4cd4-a169-b3754e3d7afa added, delay=1, src=s1, curr=s1, dst=s5, done=False, path=['s1', 's16', 's23', 's10', 's5']
# Pack added to Node: s22;
# Package f4115975-b42b-41a4-855d-1764cd860b39 added, delay=1, src=s22, curr=s22, dst=s20, done=False, path=['s22', 's15', 's3', 's9', 's20']
# Pack added to Node: s17;
# Package 5072e123-0fce-4fce-a3f2-d0a6551602fe added, delay=2, src=s17, curr=s17, dst=s14, done=False, path=['s17', 's24', 's14']
# Pack added to Node: s6;
# Package 6342fb67-5fc5-41e3-8341-d0378bf00503 added, delay=2, src=s6, curr=s6, dst=s19, done=False, path=['s6', 'c2', 'c3', 's19']
# Pack added to Node: s1;
# Package 75fef43c-be12-43db-aa92-0804bf360e8a added, delay=1, src=s1, curr=s1, dst=s3, done=False, path=['s1', 's16', 's14', 's2', 's3']
# Pack added to Node: s1;
# Package 71677223-0787-4419-ae96-a1cfae662484 added, delay=1, src=s1, curr=s1, dst=s5, done=False, path=['s1', 's16', 's23', 's10', 's5']
# Pack added to Node: s19;
# Package e1f7527b-10ef-49dd-bea2-238b58f1654f added, delay=2, src=s19, curr=s19, dst=s0, done=False, path=['s19', 's12', 's22', 's15', 's3', 's11', 's0']
# Pack added to Node: s6;
# Package 6ddd7192-dd17-4e9d-a5f7-58dec547c4b3 added, delay=2, src=s6, curr=s6, dst=s18, done=False, path=['s6', 's21', 's18']
# Pack added to Node: s17;
# Package edb5f748-9bb9-4ef2-8570-13f35ff83115 added, delay=2, src=s17, curr=s17, dst=s18, done=False, path=['s17', 's24', 's23', 's21', 's18']
# Pack added to Node: s24;
# Package 2760dd16-2b6e-4289-9d68-dc0a64028309 added, delay=1, src=s24, curr=s24, dst=s10, done=False, path=['s24', 's23', 's10']
# Pack added to Node: s17;
# Package 06eb0174-dc0d-4c2e-a7ef-7df4746abc74 added, delay=2, src=s17, curr=s17, dst=s19, done=False, path=['s17', 's19']
# Pack added to Node: s1;
# Package d776e115-0b60-455d-a8c7-0a2ae60741d6 added, delay=1, src=s1, curr=s1, dst=s16, done=False, path=['s1', 's16']
# Node(s0, (99, 33), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [])
# Node(s1, (18, 96), Throughput: 20, Delay: 1, Cost: 0.8, Packages: [UUID('12e7397a-6881-4c32-80d0-204e33dda476'), UUID('114532a3-fdf2-4cd4-a169-b3754e3d7afa'), UUID('75fef43c-be12-43db-aa92-0804bf360e8a'), UUID('71677223-0787-4419-ae96-a1cfae662484'), UUID('d776e115-0b60-455d-a8c7-0a2ae60741d6')])
# Node(s2, (54, 43), Throughput: 25, Delay: 1, Cost: 0.9, Packages: [])
# Node(s3, (56, 19), Throughput: 25, Delay: 1, Cost: 0.9, Packages: [])
# Node(s4, (91, 47), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [])
# Node(s5, (90, 44), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [UUID('fd9c5054-5b18-4990-b5df-bfe9856bcb01')])
# Node(s6, (90, 41), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [UUID('6342fb67-5fc5-41e3-8341-d0378bf00503'), UUID('6ddd7192-dd17-4e9d-a5f7-58dec547c4b3')])
# Node(s7, (100, 67), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [UUID('d4b246ad-7a2b-4fb0-bf8e-2c234e313772')])
# Node(s8, (77, 26), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [])
# Node(s9, (64, 38), Throughput: 20, Delay: 1, Cost: 0.8, Packages: [])
# Node(s10, (78, 64), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [])
# Node(s11, (71, 36), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [])
# Node(s12, (4, 32), Throughput: 20, Delay: 1, Cost: 0.8, Packages: [])
# Node(s13, (100, 91), Throughput: 20, Delay: 1, Cost: 0.8, Packages: [])
# Node(s14, (39, 63), Throughput: 25, Delay: 1, Cost: 0.9, Packages: [UUID('bb5835ff-64fd-430a-a7c8-2ad45dc737fe')])
# Node(s15, (40, 9), Throughput: 25, Delay: 1, Cost: 0.9, Packages: [])
# Node(s16, (44, 92), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [UUID('c0776743-a7a3-4d23-a0b7-87eab8f0df25'), UUID('3c07f007-4111-464e-a1f3-74a2c5dc2a34'), UUID('4c6a07b2-70d6-47ec-8134-49c6b41840df')])
# Node(s17, (1, 73), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [UUID('5072e123-0fce-4fce-a3f2-d0a6551602fe'), UUID('edb5f748-9bb9-4ef2-8570-13f35ff83115'), UUID('06eb0174-dc0d-4c2e-a7ef-7df4746abc74')])
# Node(s18, (87, 93), Throughput: 20, Delay: 1, Cost: 0.8, Packages: [])
# Node(s19, (6, 47), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [UUID('e1f7527b-10ef-49dd-bea2-238b58f1654f')])
# Node(s20, (53, 63), Throughput: 20, Delay: 1, Cost: 0.8, Packages: [])
# Node(s21, (80, 64), Throughput: 10, Delay: 2, Cost: 0.5, Packages: [])
# Node(s22, (16, 6), Throughput: 20, Delay: 1, Cost: 0.8, Packages: [UUID('d0d702cb-979d-4e19-b0c6-29a80b7166d2'), UUID('f4115975-b42b-41a4-855d-1764cd860b39')])
# Node(s23, (53, 72), Throughput: 15, Delay: 2, Cost: 0.6, Packages: [])
# Node(s24, (30, 69), Throughput: 25, Delay: 1, Cost: 0.9, Packages: [UUID('2760dd16-2b6e-4289-9d68-dc0a64028309')])
# Node(c0, (37, 11), Throughput: 125, Delay: 1, Cost: 0.5, Packages: [])
# Node(c1, (52, 55), Throughput: 175, Delay: 1, Cost: 0.5, Packages: [])
# Node(c2, (86, 46), Throughput: 175, Delay: 1, Cost: 0.5, Packages: [])
# Node(c3, (17, 68), Throughput: 100, Delay: 2, Cost: 0.5, Packages: [])
# Node(c4, (93, 92), Throughput: 125, Delay: 1, Cost: 0.5, Packages: [])
# Env reset. min_delay=1, TimeTick=0.0
# ------------------------------------------------------STEP1------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# Package: c0776743-a7a3-4d23-a0b7-87eab8f0df25 processing...
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# Package: fd9c5054-5b18-4990-b5df-bfe9856bcb01 processing...
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# Package: d4b246ad-7a2b-4fb0-bf8e-2c234e313772 processing...
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# Package: 3c07f007-4111-464e-a1f3-74a2c5dc2a34 processing...
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=['s1', 's17']
# is in Node: s1,
# package: 12e7397a-6881-4c32-80d0-204e33dda476 removed from Node: s1.
# Pack added to Route: s1->s17;
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# Package: 4c6a07b2-70d6-47ec-8134-49c6b41840df processing...
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=['s14', 's20']
# is in Node: s14,
# package: bb5835ff-64fd-430a-a7c8-2ad45dc737fe removed from Node: s14.
# Pack added to Route: s14->s20;
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=['s22', 's12']
# is in Node: s22,
# package: d0d702cb-979d-4e19-b0c6-29a80b7166d2 removed from Node: s22.
# Pack added to Route: s22->s12;
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=['s1', 's16']
# is in Node: s1,
# package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa removed from Node: s1.
# Pack added to Route: s1->s16;
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=['s22', 's15']
# is in Node: s22,
# package: f4115975-b42b-41a4-855d-1764cd860b39 removed from Node: s22.
# Pack added to Route: s22->s15;
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# Package: 5072e123-0fce-4fce-a3f2-d0a6551602fe processing...
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# Package: 6342fb67-5fc5-41e3-8341-d0378bf00503 processing...
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=['s1', 's16']
# is in Node: s1,
# package: 75fef43c-be12-43db-aa92-0804bf360e8a removed from Node: s1.
# Pack added to Route: s1->s16;
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=['s1', 's16']
# is in Node: s1,
# package: 71677223-0787-4419-ae96-a1cfae662484 removed from Node: s1.
# Pack added to Route: s1->s16;
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=None
# Package: e1f7527b-10ef-49dd-bea2-238b58f1654f processing...
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# Package: 6ddd7192-dd17-4e9d-a5f7-58dec547c4b3 processing...
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=['s24', 's23']
# is in Node: s24,
# package: 2760dd16-2b6e-4289-9d68-dc0a64028309 removed from Node: s24.
# Pack added to Route: s24->s23;
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# Package: 06eb0174-dc0d-4c2e-a7ef-7df4746abc74 processing...
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=['s1', 's16']
# is in Node: s1,
# package: d776e115-0b60-455d-a8c7-0a2ae60741d6 removed from Node: s1.
# Pack added to Route: s1->s16;
# the new min_delay: 1
# Time tick: 1.0, Total reward: -7.3999999999999995
# ------------------------------------------------------STEP2------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=['s16', 's23']
# is in Node: s16,
# package: c0776743-a7a3-4d23-a0b7-87eab8f0df25 removed from Node: s16.
# Pack added to Route: s16->s23;
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=['s5', 's0']
# is in Node: s5,
# package: fd9c5054-5b18-4990-b5df-bfe9856bcb01 removed from Node: s5.
# Pack added to Route: s5->s0;
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=['s7', 's4']
# is in Node: s7,
# package: d4b246ad-7a2b-4fb0-bf8e-2c234e313772 removed from Node: s7.
# Pack added to Route: s7->s4;
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=['s16', 's23']
# is in Node: s16,
# package: 3c07f007-4111-464e-a1f3-74a2c5dc2a34 removed from Node: s16.
# Pack added to Route: s16->s23;
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# Package: 12e7397a-6881-4c32-80d0-204e33dda476 processing...
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=['s16', 'c3']
# is in Node: s16,
# package: 4c6a07b2-70d6-47ec-8134-49c6b41840df removed from Node: s16.
# Pack added to Route: s16->c3;
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# Package: bb5835ff-64fd-430a-a7c8-2ad45dc737fe processing...
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# Package: d0d702cb-979d-4e19-b0c6-29a80b7166d2 processing...
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# Package: f4115975-b42b-41a4-855d-1764cd860b39 processing...
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=['s17', 's24']
# is in Node: s17,
# package: 5072e123-0fce-4fce-a3f2-d0a6551602fe removed from Node: s17.
# Pack added to Route: s17->s24;
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=['s6', 'c2']
# is in Node: s6,
# package: 6342fb67-5fc5-41e3-8341-d0378bf00503 removed from Node: s6.
# Pack added to Route: s6->c2;
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# Package: 75fef43c-be12-43db-aa92-0804bf360e8a processing...
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# Package: 71677223-0787-4419-ae96-a1cfae662484 processing...
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=['s19', 's12']
# is in Node: s19,
# package: e1f7527b-10ef-49dd-bea2-238b58f1654f removed from Node: s19.
# Pack added to Route: s19->s12;
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=['s6', 's21']
# is in Node: s6,
# package: 6ddd7192-dd17-4e9d-a5f7-58dec547c4b3 removed from Node: s6.
# Pack added to Route: s6->s21;
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=['s17', 's24']
# is in Node: s17,
# package: edb5f748-9bb9-4ef2-8570-13f35ff83115 removed from Node: s17.
# Pack added to Route: s17->s24;
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# Package: 2760dd16-2b6e-4289-9d68-dc0a64028309 processing...
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=['s17', 's19']
# is in Node: s17,
# package: 06eb0174-dc0d-4c2e-a7ef-7df4746abc74 removed from Node: s17.
# Pack added to Route: s17->s19;
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# Package: d776e115-0b60-455d-a8c7-0a2ae60741d6 processing...
# the new min_delay: 3.841874542459709
# Time tick: 2.0, Total reward: -13.4
# ------------------------------------------------------STEP3------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# Package: c0776743-a7a3-4d23-a0b7-87eab8f0df25 processing...
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# Package: fd9c5054-5b18-4990-b5df-bfe9856bcb01 processing...
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# Package: d4b246ad-7a2b-4fb0-bf8e-2c234e313772 processing...
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# Package: 3c07f007-4111-464e-a1f3-74a2c5dc2a34 processing...
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# Package: 12e7397a-6881-4c32-80d0-204e33dda476 processing...
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# Package: 4c6a07b2-70d6-47ec-8134-49c6b41840df processing...
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# Package: bb5835ff-64fd-430a-a7c8-2ad45dc737fe processing...
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# Package: d0d702cb-979d-4e19-b0c6-29a80b7166d2 processing...
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# Package: f4115975-b42b-41a4-855d-1764cd860b39 processing...
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# Package: 5072e123-0fce-4fce-a3f2-d0a6551602fe processing...
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=['s6', 'c2']
# is on Route: s6->c2,
# package: 6342fb67-5fc5-41e3-8341-d0378bf00503 removed from Route: s6->c2.
# Pack added to Node: c2;
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# Package: 75fef43c-be12-43db-aa92-0804bf360e8a processing...
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# Package: 71677223-0787-4419-ae96-a1cfae662484 processing...
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=None
# Package: e1f7527b-10ef-49dd-bea2-238b58f1654f processing...
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# Package: 6ddd7192-dd17-4e9d-a5f7-58dec547c4b3 processing...
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# Package: 2760dd16-2b6e-4289-9d68-dc0a64028309 processing...
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# Package: 06eb0174-dc0d-4c2e-a7ef-7df4746abc74 processing...
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# Package: d776e115-0b60-455d-a8c7-0a2ae60741d6 processing...
# the new min_delay: 1
# Time tick: 5.841874542459709, Total reward: -14.168374908491943
# ------------------------------------------------------STEP4------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# Package: c0776743-a7a3-4d23-a0b7-87eab8f0df25 processing...
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# Package: fd9c5054-5b18-4990-b5df-bfe9856bcb01 processing...
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# Package: d4b246ad-7a2b-4fb0-bf8e-2c234e313772 processing...
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# Package: 3c07f007-4111-464e-a1f3-74a2c5dc2a34 processing...
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# Package: 12e7397a-6881-4c32-80d0-204e33dda476 processing...
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# Package: 4c6a07b2-70d6-47ec-8134-49c6b41840df processing...
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# Package: bb5835ff-64fd-430a-a7c8-2ad45dc737fe processing...
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# Package: d0d702cb-979d-4e19-b0c6-29a80b7166d2 processing...
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# Package: f4115975-b42b-41a4-855d-1764cd860b39 processing...
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# Package: 5072e123-0fce-4fce-a3f2-d0a6551602fe processing...
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=['c2', 'c3']
# is in Node: c2,
# package: 6342fb67-5fc5-41e3-8341-d0378bf00503 removed from Node: c2.
# Pack added to Route: c2->c3;
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# Package: 75fef43c-be12-43db-aa92-0804bf360e8a processing...
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# Package: 71677223-0787-4419-ae96-a1cfae662484 processing...
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=None
# Package: e1f7527b-10ef-49dd-bea2-238b58f1654f processing...
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# Package: 6ddd7192-dd17-4e9d-a5f7-58dec547c4b3 processing...
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# Package: 2760dd16-2b6e-4289-9d68-dc0a64028309 processing...
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# Package: 06eb0174-dc0d-4c2e-a7ef-7df4746abc74 processing...
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# Package: d776e115-0b60-455d-a8c7-0a2ae60741d6 processing...
# the new min_delay: 5.358125457540292
# Time tick: 6.841874542459709, Total reward: -14.668374908491943
# ------------------------------------------------------STEP5------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# Package: c0776743-a7a3-4d23-a0b7-87eab8f0df25 processing...
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# Package: fd9c5054-5b18-4990-b5df-bfe9856bcb01 processing...
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# Package: d4b246ad-7a2b-4fb0-bf8e-2c234e313772 processing...
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# Package: 3c07f007-4111-464e-a1f3-74a2c5dc2a34 processing...
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# Package: 12e7397a-6881-4c32-80d0-204e33dda476 processing...
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# Package: 4c6a07b2-70d6-47ec-8134-49c6b41840df processing...
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=['s14', 's20']
# is on Route: s14->s20,
# package: bb5835ff-64fd-430a-a7c8-2ad45dc737fe removed from Route: s14->s20.
# Pack added to Node: s20;
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# Package: d0d702cb-979d-4e19-b0c6-29a80b7166d2 processing...
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# Package: f4115975-b42b-41a4-855d-1764cd860b39 processing...
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# Package: 5072e123-0fce-4fce-a3f2-d0a6551602fe processing...
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# Package: 6342fb67-5fc5-41e3-8341-d0378bf00503 processing...
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# Package: 75fef43c-be12-43db-aa92-0804bf360e8a processing...
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# Package: 71677223-0787-4419-ae96-a1cfae662484 processing...
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=None
# Package: e1f7527b-10ef-49dd-bea2-238b58f1654f processing...
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# Package: 6ddd7192-dd17-4e9d-a5f7-58dec547c4b3 processing...
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# Package: 2760dd16-2b6e-4289-9d68-dc0a64028309 processing...
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# Package: 06eb0174-dc0d-4c2e-a7ef-7df4746abc74 processing...
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# Package: d776e115-0b60-455d-a8c7-0a2ae60741d6 processing...
# the new min_delay: 1
# Time tick: 12.200000000000001, Total reward: -15.648374908491942
# ------------------------------------------------------STEP6------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# Package: c0776743-a7a3-4d23-a0b7-87eab8f0df25 processing...
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# Package: fd9c5054-5b18-4990-b5df-bfe9856bcb01 processing...
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# Package: d4b246ad-7a2b-4fb0-bf8e-2c234e313772 processing...
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# Package: 3c07f007-4111-464e-a1f3-74a2c5dc2a34 processing...
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# Package: 12e7397a-6881-4c32-80d0-204e33dda476 processing...
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# Package: 4c6a07b2-70d6-47ec-8134-49c6b41840df processing...
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=['s20', 's10']
# is in Node: s20,
# package: bb5835ff-64fd-430a-a7c8-2ad45dc737fe removed from Node: s20.
# Pack added to Route: s20->s10;
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# Package: d0d702cb-979d-4e19-b0c6-29a80b7166d2 processing...
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# Package: f4115975-b42b-41a4-855d-1764cd860b39 processing...
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# Package: 5072e123-0fce-4fce-a3f2-d0a6551602fe processing...
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# Package: 6342fb67-5fc5-41e3-8341-d0378bf00503 processing...
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# Package: 75fef43c-be12-43db-aa92-0804bf360e8a processing...
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# Package: 71677223-0787-4419-ae96-a1cfae662484 processing...
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=None
# Package: e1f7527b-10ef-49dd-bea2-238b58f1654f processing...
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# Package: 6ddd7192-dd17-4e9d-a5f7-58dec547c4b3 processing...
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# Package: 2760dd16-2b6e-4289-9d68-dc0a64028309 processing...
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# Package: 06eb0174-dc0d-4c2e-a7ef-7df4746abc74 processing...
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# Package: d776e115-0b60-455d-a8c7-0a2ae60741d6 processing...
# the new min_delay: 0.17013632284151647
# Time tick: 13.200000000000001, Total reward: -16.448374908491942
# ------------------------------------------------------STEP7------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# Package: c0776743-a7a3-4d23-a0b7-87eab8f0df25 processing...
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=['s5', 's0']
# is on Route: s5->s0,
# package: fd9c5054-5b18-4990-b5df-bfe9856bcb01 removed from Route: s5->s0.
# Pack added to Node: s0;
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# Package: d4b246ad-7a2b-4fb0-bf8e-2c234e313772 processing...
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# Package: 3c07f007-4111-464e-a1f3-74a2c5dc2a34 processing...
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# Package: 12e7397a-6881-4c32-80d0-204e33dda476 processing...
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# Package: 4c6a07b2-70d6-47ec-8134-49c6b41840df processing...
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# Package: bb5835ff-64fd-430a-a7c8-2ad45dc737fe processing...
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# Package: d0d702cb-979d-4e19-b0c6-29a80b7166d2 processing...
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# Package: f4115975-b42b-41a4-855d-1764cd860b39 processing...
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# Package: 5072e123-0fce-4fce-a3f2-d0a6551602fe processing...
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# Package: 6342fb67-5fc5-41e3-8341-d0378bf00503 processing...
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# Package: 75fef43c-be12-43db-aa92-0804bf360e8a processing...
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# Package: 71677223-0787-4419-ae96-a1cfae662484 processing...
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=None
# Package: e1f7527b-10ef-49dd-bea2-238b58f1654f processing...
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# Package: 6ddd7192-dd17-4e9d-a5f7-58dec547c4b3 processing...
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# Package: 2760dd16-2b6e-4289-9d68-dc0a64028309 processing...
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# Package: 06eb0174-dc0d-4c2e-a7ef-7df4746abc74 processing...
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# Package: d776e115-0b60-455d-a8c7-0a2ae60741d6 processing...
# the new min_delay: 0.7360604374957296
# Time tick: 13.370136322841518, Total reward: -17.443261836740575
# ------------------------------------------------------STEP8------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# Package: c0776743-a7a3-4d23-a0b7-87eab8f0df25 processing...
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# Package: d4b246ad-7a2b-4fb0-bf8e-2c234e313772 processing...
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# Package: 3c07f007-4111-464e-a1f3-74a2c5dc2a34 processing...
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# Package: 12e7397a-6881-4c32-80d0-204e33dda476 processing...
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# Package: 4c6a07b2-70d6-47ec-8134-49c6b41840df processing...
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# Package: bb5835ff-64fd-430a-a7c8-2ad45dc737fe processing...
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# Package: d0d702cb-979d-4e19-b0c6-29a80b7166d2 processing...
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# Package: f4115975-b42b-41a4-855d-1764cd860b39 processing...
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# Package: 5072e123-0fce-4fce-a3f2-d0a6551602fe processing...
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# Package: 6342fb67-5fc5-41e3-8341-d0378bf00503 processing...
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# Package: 75fef43c-be12-43db-aa92-0804bf360e8a processing...
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# Package: 71677223-0787-4419-ae96-a1cfae662484 processing...
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=['s19', 's12']
# is on Route: s19->s12,
# package: e1f7527b-10ef-49dd-bea2-238b58f1654f removed from Route: s19->s12.
# Pack added to Node: s12;
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# Package: 6ddd7192-dd17-4e9d-a5f7-58dec547c4b3 processing...
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# Package: 2760dd16-2b6e-4289-9d68-dc0a64028309 processing...
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# Package: 06eb0174-dc0d-4c2e-a7ef-7df4746abc74 processing...
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# Package: d776e115-0b60-455d-a8c7-0a2ae60741d6 processing...
# the new min_delay: 1
# Time tick: 14.106196760337248, Total reward: -16.907667125021455
# ------------------------------------------------------STEP9------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# Package: c0776743-a7a3-4d23-a0b7-87eab8f0df25 processing...
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# Package: d4b246ad-7a2b-4fb0-bf8e-2c234e313772 processing...
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# Package: 3c07f007-4111-464e-a1f3-74a2c5dc2a34 processing...
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# Package: 12e7397a-6881-4c32-80d0-204e33dda476 processing...
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# Package: 4c6a07b2-70d6-47ec-8134-49c6b41840df processing...
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# Package: bb5835ff-64fd-430a-a7c8-2ad45dc737fe processing...
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# Package: d0d702cb-979d-4e19-b0c6-29a80b7166d2 processing...
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# Package: f4115975-b42b-41a4-855d-1764cd860b39 processing...
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# Package: 5072e123-0fce-4fce-a3f2-d0a6551602fe processing...
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# Package: 6342fb67-5fc5-41e3-8341-d0378bf00503 processing...
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# Package: 75fef43c-be12-43db-aa92-0804bf360e8a processing...
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# Package: 71677223-0787-4419-ae96-a1cfae662484 processing...
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=['s12', 's22']
# is in Node: s12,
# package: e1f7527b-10ef-49dd-bea2-238b58f1654f removed from Node: s12.
# Pack added to Route: s12->s22;
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# Package: 6ddd7192-dd17-4e9d-a5f7-58dec547c4b3 processing...
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# Package: 2760dd16-2b6e-4289-9d68-dc0a64028309 processing...
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# Package: 06eb0174-dc0d-4c2e-a7ef-7df4746abc74 processing...
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# Package: d776e115-0b60-455d-a8c7-0a2ae60741d6 processing...
# the new min_delay: 4.4391729992318005
# Time tick: 15.106196760337248, Total reward: -17.707667125021455
# ------------------------------------------------------STEP10------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=['s16', 's23']
# is on Route: s16->s23,
# package: c0776743-a7a3-4d23-a0b7-87eab8f0df25 removed from Route: s16->s23.
# Pack added to Node: s23;
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=['s7', 's4']
# is on Route: s7->s4,
# package: d4b246ad-7a2b-4fb0-bf8e-2c234e313772 removed from Route: s7->s4.
# Pack added to Node: s4;
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=['s16', 's23']
# is on Route: s16->s23,
# package: 3c07f007-4111-464e-a1f3-74a2c5dc2a34 removed from Route: s16->s23.
# Pack added to Node: s23;
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# Package: 12e7397a-6881-4c32-80d0-204e33dda476 processing...
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# Package: 4c6a07b2-70d6-47ec-8134-49c6b41840df processing...
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# Package: bb5835ff-64fd-430a-a7c8-2ad45dc737fe processing...
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# Package: d0d702cb-979d-4e19-b0c6-29a80b7166d2 processing...
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# Package: f4115975-b42b-41a4-855d-1764cd860b39 processing...
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# Package: 5072e123-0fce-4fce-a3f2-d0a6551602fe processing...
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# Package: 6342fb67-5fc5-41e3-8341-d0378bf00503 processing...
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# Package: 75fef43c-be12-43db-aa92-0804bf360e8a processing...
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# Package: 71677223-0787-4419-ae96-a1cfae662484 processing...
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=None
# Package: e1f7527b-10ef-49dd-bea2-238b58f1654f processing...
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# Package: 6ddd7192-dd17-4e9d-a5f7-58dec547c4b3 processing...
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# Package: 2760dd16-2b6e-4289-9d68-dc0a64028309 processing...
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# Package: 06eb0174-dc0d-4c2e-a7ef-7df4746abc74 processing...
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# Package: d776e115-0b60-455d-a8c7-0a2ae60741d6 processing...
# the new min_delay: 0.010491848020073746
# Time tick: 19.54536975956905, Total reward: -22.31332668690833
# ------------------------------------------------------STEP11------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# Package: d4b246ad-7a2b-4fb0-bf8e-2c234e313772 processing...
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# Package: 3c07f007-4111-464e-a1f3-74a2c5dc2a34 processing...
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# Package: 12e7397a-6881-4c32-80d0-204e33dda476 processing...
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# Package: 4c6a07b2-70d6-47ec-8134-49c6b41840df processing...
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# Package: bb5835ff-64fd-430a-a7c8-2ad45dc737fe processing...
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# Package: d0d702cb-979d-4e19-b0c6-29a80b7166d2 processing...
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# Package: f4115975-b42b-41a4-855d-1764cd860b39 processing...
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# Package: 5072e123-0fce-4fce-a3f2-d0a6551602fe processing...
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# Package: 6342fb67-5fc5-41e3-8341-d0378bf00503 processing...
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# Package: 75fef43c-be12-43db-aa92-0804bf360e8a processing...
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# Package: 71677223-0787-4419-ae96-a1cfae662484 processing...
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=None
# Package: e1f7527b-10ef-49dd-bea2-238b58f1654f processing...
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# Package: 6ddd7192-dd17-4e9d-a5f7-58dec547c4b3 processing...
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=['s24', 's23']
# is on Route: s24->s23,
# package: 2760dd16-2b6e-4289-9d68-dc0a64028309 removed from Route: s24->s23.
# Pack added to Node: s23;
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# Package: 06eb0174-dc0d-4c2e-a7ef-7df4746abc74 processing...
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# Package: d776e115-0b60-455d-a8c7-0a2ae60741d6 processing...
# the new min_delay: 0.7935569883273947
# Time tick: 19.555861607589122, Total reward: -21.90174472361009
# ------------------------------------------------------STEP12------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# Package: d4b246ad-7a2b-4fb0-bf8e-2c234e313772 processing...
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# Package: 3c07f007-4111-464e-a1f3-74a2c5dc2a34 processing...
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# Package: 12e7397a-6881-4c32-80d0-204e33dda476 processing...
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# Package: 4c6a07b2-70d6-47ec-8134-49c6b41840df processing...
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# Package: bb5835ff-64fd-430a-a7c8-2ad45dc737fe processing...
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# Package: d0d702cb-979d-4e19-b0c6-29a80b7166d2 processing...
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=['s22', 's15']
# is on Route: s22->s15,
# package: f4115975-b42b-41a4-855d-1764cd860b39 removed from Route: s22->s15.
# Pack added to Node: s15;
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# Package: 5072e123-0fce-4fce-a3f2-d0a6551602fe processing...
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# Package: 6342fb67-5fc5-41e3-8341-d0378bf00503 processing...
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# Package: 75fef43c-be12-43db-aa92-0804bf360e8a processing...
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# Package: 71677223-0787-4419-ae96-a1cfae662484 processing...
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=None
# Package: e1f7527b-10ef-49dd-bea2-238b58f1654f processing...
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# Package: 6ddd7192-dd17-4e9d-a5f7-58dec547c4b3 processing...
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# Package: 2760dd16-2b6e-4289-9d68-dc0a64028309 processing...
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# Package: 06eb0174-dc0d-4c2e-a7ef-7df4746abc74 processing...
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# Package: d776e115-0b60-455d-a8c7-0a2ae60741d6 processing...
# the new min_delay: 1
# Time tick: 20.349418595916518, Total reward: -23.594818850752784
# ------------------------------------------------------STEP13------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# Package: d4b246ad-7a2b-4fb0-bf8e-2c234e313772 processing...
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# Package: 3c07f007-4111-464e-a1f3-74a2c5dc2a34 processing...
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# Package: 12e7397a-6881-4c32-80d0-204e33dda476 processing...
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# Package: 4c6a07b2-70d6-47ec-8134-49c6b41840df processing...
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# Package: bb5835ff-64fd-430a-a7c8-2ad45dc737fe processing...
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# Package: d0d702cb-979d-4e19-b0c6-29a80b7166d2 processing...
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=['s15', 's3']
# is in Node: s15,
# package: f4115975-b42b-41a4-855d-1764cd860b39 removed from Node: s15.
# Pack added to Route: s15->s3;
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# Package: 5072e123-0fce-4fce-a3f2-d0a6551602fe processing...
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# Package: 6342fb67-5fc5-41e3-8341-d0378bf00503 processing...
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# Package: 75fef43c-be12-43db-aa92-0804bf360e8a processing...
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# Package: 71677223-0787-4419-ae96-a1cfae662484 processing...
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=None
# Package: e1f7527b-10ef-49dd-bea2-238b58f1654f processing...
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# Package: 6ddd7192-dd17-4e9d-a5f7-58dec547c4b3 processing...
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# Package: 2760dd16-2b6e-4289-9d68-dc0a64028309 processing...
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# Package: 06eb0174-dc0d-4c2e-a7ef-7df4746abc74 processing...
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# Package: d776e115-0b60-455d-a8c7-0a2ae60741d6 processing...
# the new min_delay: 0.1959511636525315
# Time tick: 21.349418595916518, Total reward: -24.494818850752782
# ------------------------------------------------------STEP14------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=['s4', 's8']
# is in Node: s4,
# package: d4b246ad-7a2b-4fb0-bf8e-2c234e313772 removed from Node: s4.
# Pack added to Route: s4->s8;
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=['s23', 's2']
# is in Node: s23,
# package: 3c07f007-4111-464e-a1f3-74a2c5dc2a34 removed from Node: s23.
# Pack added to Route: s23->s2;
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# Package: 12e7397a-6881-4c32-80d0-204e33dda476 processing...
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# Package: 4c6a07b2-70d6-47ec-8134-49c6b41840df processing...
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# Package: bb5835ff-64fd-430a-a7c8-2ad45dc737fe processing...
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# Package: d0d702cb-979d-4e19-b0c6-29a80b7166d2 processing...
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# Package: f4115975-b42b-41a4-855d-1764cd860b39 processing...
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# Package: 5072e123-0fce-4fce-a3f2-d0a6551602fe processing...
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# Package: 6342fb67-5fc5-41e3-8341-d0378bf00503 processing...
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# Package: 75fef43c-be12-43db-aa92-0804bf360e8a processing...
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# Package: 71677223-0787-4419-ae96-a1cfae662484 processing...
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=None
# Package: e1f7527b-10ef-49dd-bea2-238b58f1654f processing...
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# Package: 6ddd7192-dd17-4e9d-a5f7-58dec547c4b3 processing...
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# Package: 2760dd16-2b6e-4289-9d68-dc0a64028309 processing...
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# Package: 06eb0174-dc0d-4c2e-a7ef-7df4746abc74 processing...
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# Package: d776e115-0b60-455d-a8c7-0a2ae60741d6 processing...
# the new min_delay: 0.010491848020073746
# Time tick: 21.54536975956905, Total reward: -25.594818850752784
# ------------------------------------------------------STEP15------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# Package: d4b246ad-7a2b-4fb0-bf8e-2c234e313772 processing...
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# Package: 3c07f007-4111-464e-a1f3-74a2c5dc2a34 processing...
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# Package: 12e7397a-6881-4c32-80d0-204e33dda476 processing...
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# Package: 4c6a07b2-70d6-47ec-8134-49c6b41840df processing...
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# Package: bb5835ff-64fd-430a-a7c8-2ad45dc737fe processing...
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# Package: d0d702cb-979d-4e19-b0c6-29a80b7166d2 processing...
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# Package: f4115975-b42b-41a4-855d-1764cd860b39 processing...
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# Package: 5072e123-0fce-4fce-a3f2-d0a6551602fe processing...
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# Package: 6342fb67-5fc5-41e3-8341-d0378bf00503 processing...
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# Package: 75fef43c-be12-43db-aa92-0804bf360e8a processing...
# ...
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# Package: f4115975-b42b-41a4-855d-1764cd860b39 processing...
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# Package: 75fef43c-be12-43db-aa92-0804bf360e8a processing...
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# Package: 71677223-0787-4419-ae96-a1cfae662484 processing...
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=['s3', 's8']
# is in Node: s3,
# package: e1f7527b-10ef-49dd-bea2-238b58f1654f removed from Node: s3.
# Pack added to Route: s3->s8;
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# the new min_delay: 1.3281124948874883
# Time tick: 75.4584988687865, Total reward: -49.614549190871315
# ------------------------------------------------------STEP65------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=['s9', 's20']
# is on Route: s9->s20,
# package: f4115975-b42b-41a4-855d-1764cd860b39 removed from Route: s9->s20.
# Pack added to Node: s20;
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# Package: 75fef43c-be12-43db-aa92-0804bf360e8a processing...
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# Package: 71677223-0787-4419-ae96-a1cfae662484 processing...
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=None
# Package: e1f7527b-10ef-49dd-bea2-238b58f1654f processing...
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# the new min_delay: 8.461566357596176
# Time tick: 76.786611363674, Total reward: -51.52645923059599
# ------------------------------------------------------STEP66------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=['s10', 's5']
# is in Node: s10,
# package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa removed from Node: s10.
# Pack added to Route: s10->s5;
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# Package: 75fef43c-be12-43db-aa92-0804bf360e8a processing...
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=['s10', 's5']
# is on Route: s10->s5,
# package: 71677223-0787-4419-ae96-a1cfae662484 removed from Route: s10->s5.
# Pack added to Node: s5;
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=None
# Package: e1f7527b-10ef-49dd-bea2-238b58f1654f processing...
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# the new min_delay: 1.822246670787063
# Time tick: 85.24817772127017, Total reward: -43.8902972668312
# ------------------------------------------------------STEP67------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=['s2', 's3']
# is on Route: s2->s3,
# package: 75fef43c-be12-43db-aa92-0804bf360e8a removed from Route: s2->s3.
# Pack added to Node: s3;
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=None
# Package: e1f7527b-10ef-49dd-bea2-238b58f1654f processing...
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# the new min_delay: 6.096829373672197
# Time tick: 87.07042439205723, Total reward: -36.32940495725097
# ------------------------------------------------------STEP68------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=['s3', 's8']
# is on Route: s3->s8,
# package: e1f7527b-10ef-49dd-bea2-238b58f1654f removed from Route: s3->s8.
# Pack added to Node: s8;
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# the new min_delay: 2
# Time tick: 93.16725376572943, Total reward: -27.985258876428475
# ------------------------------------------------------STEP69------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=['s8', 's0']
# is in Node: s8,
# package: e1f7527b-10ef-49dd-bea2-238b58f1654f removed from Node: s8.
# Pack added to Route: s8->s0;
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# Package: edb5f748-9bb9-4ef2-8570-13f35ff83115 processing...
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# the new min_delay: 0.20275647995485357
# Time tick: 95.16725376572943, Total reward: -28.585258876428476
# ------------------------------------------------------STEP70------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# Package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa processing...
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=None
# Package: e1f7527b-10ef-49dd-bea2-238b58f1654f processing...
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=['s21', 's18']
# is on Route: s21->s18,
# package: edb5f748-9bb9-4ef2-8570-13f35ff83115 removed from Route: s21->s18.
# Pack added to Node: s18;
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# the new min_delay: 8.53721353909085
# Time tick: 95.37001024568428, Total reward: -30.67355962105316
# ------------------------------------------------------STEP71------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=['s10', 's5']
# is on Route: s10->s5,
# package: 114532a3-fdf2-4cd4-a169-b3754e3d7afa removed from Route: s10->s5.
# Pack added to Node: s5;
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=None
# Package: e1f7527b-10ef-49dd-bea2-238b58f1654f processing...
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# the new min_delay: 9.72946418993861
# Time tick: 103.90722378477514, Total reward: -21.973850255112467
# ------------------------------------------------------STEP72------------------------------------------------------
# STEP:::PacakgeID=c0776743-a7a3-4d23-a0b7-87eab8f0df25, Action=None
# STEP:::PacakgeID=fd9c5054-5b18-4990-b5df-bfe9856bcb01, Action=None
# STEP:::PacakgeID=d4b246ad-7a2b-4fb0-bf8e-2c234e313772, Action=None
# STEP:::PacakgeID=3c07f007-4111-464e-a1f3-74a2c5dc2a34, Action=None
# STEP:::PacakgeID=12e7397a-6881-4c32-80d0-204e33dda476, Action=None
# STEP:::PacakgeID=4c6a07b2-70d6-47ec-8134-49c6b41840df, Action=None
# STEP:::PacakgeID=bb5835ff-64fd-430a-a7c8-2ad45dc737fe, Action=None
# STEP:::PacakgeID=d0d702cb-979d-4e19-b0c6-29a80b7166d2, Action=None
# STEP:::PacakgeID=114532a3-fdf2-4cd4-a169-b3754e3d7afa, Action=None
# STEP:::PacakgeID=f4115975-b42b-41a4-855d-1764cd860b39, Action=None
# STEP:::PacakgeID=5072e123-0fce-4fce-a3f2-d0a6551602fe, Action=None
# STEP:::PacakgeID=6342fb67-5fc5-41e3-8341-d0378bf00503, Action=None
# STEP:::PacakgeID=75fef43c-be12-43db-aa92-0804bf360e8a, Action=None
# STEP:::PacakgeID=71677223-0787-4419-ae96-a1cfae662484, Action=None
# STEP:::PacakgeID=e1f7527b-10ef-49dd-bea2-238b58f1654f, Action=['s8', 's0']
# is on Route: s8->s0,
# package: e1f7527b-10ef-49dd-bea2-238b58f1654f removed from Route: s8->s0.
# Pack added to Node: s0;
# STEP:::PacakgeID=6ddd7192-dd17-4e9d-a5f7-58dec547c4b3, Action=None
# STEP:::PacakgeID=edb5f748-9bb9-4ef2-8570-13f35ff83115, Action=None
# STEP:::PacakgeID=2760dd16-2b6e-4289-9d68-dc0a64028309, Action=None
# STEP:::PacakgeID=06eb0174-dc0d-4c2e-a7ef-7df4746abc74, Action=None
# STEP:::PacakgeID=d776e115-0b60-455d-a8c7-0a2ae60741d6, Action=None
# the new min_delay: inf
# Time tick: 113.63668797471375, Total reward: -13.843210197787453
# All packages have reached the destination.
